# %% [markdown]
# # Parsed the files that contain the retrieved nodes for the different methods and prepares them to be anotated by chatgpt

# %%
sorted_path = 'Retrieved Nodes/full_sorted_k4_d6/'
unsorted_path = 'Retrieved Nodes/full_unsorted_k4_d6'

# %%
import os
import re

def parse_files_in_directory(directory_path):
    parsed_data_list = []
    triplet_pattern = re.compile(r'\[(.*?)\]: (.*?) --\[(.*?)\]-> (.*?) ([0-9.]+)')

    # Get all filenames in the directory
    filenames = [f for f in os.listdir(directory_path) if os.path.isfile(os.path.join(directory_path, f))]

    # Filter filenames that match the pattern 'n.txt' where n is an integer
    file_pattern = re.compile(r'(\d+)\.txt$')
    numbered_files = []
    for f in filenames:
        match = file_pattern.match(f)
        if match:
            number = int(match.group(1))
            numbered_files.append((number, f))

    # Sort the files based on the extracted number
    numbered_files.sort(key=lambda x: x[0])

    # Process files in the sorted order
    for number, filename in numbered_files:
        filepath = os.path.join(directory_path, filename)

        # Try reading the file with UTF-8 encoding
        try:
            with open(filepath, 'r', encoding='utf-8') as file:
                lines = [line.strip() for line in file if line.strip()]
        except UnicodeDecodeError:
            # Fall back to Latin-1 encoding if UTF-8 fails
            with open(filepath, 'r', encoding='latin-1') as file:
                lines = [line.strip() for line in file if line.strip()]
        except Exception as e:
            print(f"Error reading file {filename}: {e}")
            continue

        if not lines:
            continue

        iterator = iter(lines)
        data = {'question': None, 'seeds': [], 'triplets': []}

        try:
            # Extract the question
            data['question'] = next(iterator)

            # Skip the 'None' line if it exists
            current_line = next(iterator)
            if current_line.lower() == 'none':
                pass
            else:
                # If 'None' line is missing, we need to process the current line
                if current_line.startswith('Seed:'):
                    data['seeds'].append(current_line[len('Seed:'):].strip())
                else:
                    # If the line is not a seed, reset the iterator
                    iterator = iter([current_line] + list(iterator))

            # Extract seed nodes
            for line in iterator:
                if line.startswith('Seed:'):
                    data['seeds'].append(line[len('Seed:'):].strip())
                else:
                    # Break if the line doesn't start with 'Seed:'
                    break

            # Extract triplets
            for line in iterator:
                match = triplet_pattern.match(line)
                if match:
                    data['triplets'].append({
                        'seed': match.group(1),
                        'head': match.group(2),
                        'relation': match.group(3),
                        'tail': match.group(4),
                        'score': float(match.group(5))
                    })
        except StopIteration:
            pass  # Handle files that may not have complete content

        parsed_data_list.append(data)

    return parsed_data_list

# %%
parsed_sorted_data = parse_files_in_directory(sorted_path)
parsed_unsorted_data = parse_files_in_directory(unsorted_path)

# %%
def create_clean_entry(entry):
    clean_entry = {'question': entry['question'], 'triplets': []}
    seen_triplets = set()

    for triplet in entry.get('triplets', []):
        # Create a tuple of (head, relation, tail) to identify duplicates
        triplet_key = (triplet['head'], triplet['relation'], triplet['tail'])

        if triplet_key not in seen_triplets:
            seen_triplets.add(triplet_key)
            # Exclude the 'seed' key, and create an 'id' from head-relation-tail
            clean_triplet = {
                'head': triplet['head'],
                'relation': triplet['relation'],
                'tail': triplet['tail'],
                'score': triplet['score'],
                'id': f"{triplet['head']}-{triplet['relation']}-{triplet['tail']}"
            }
            clean_entry['triplets'].append(clean_triplet)

    return clean_entry

# Example usage
clean_sorted_data = [create_clean_entry(entry) for entry in parsed_sorted_data]
clean_unsorted_data = [create_clean_entry(entry) for entry in parsed_unsorted_data]

# %%
# print lengths of the two lists
print(len(clean_sorted_data))
print(len(clean_unsorted_data))
# Out:
# 116
# 116

# %%
def combine_clean_entries(clean_sorted_data, clean_unsorted_data):
    combined_data = []
    
    # Assuming that clean_sorted_data and clean_unsorted_data have the same length
    # and that entries correspond to the same question
    for sorted_entry, unsorted_entry in zip(clean_sorted_data, clean_unsorted_data):
        combined_entry = {'question': sorted_entry['question'], 'triplets': []}
        seen_triplets = set()
        
        # First, add triplets from sorted_entry
        for triplet in sorted_entry.get('triplets', []):
            triplet_id = triplet['id']
            if triplet_id not in seen_triplets:
                seen_triplets.add(triplet_id)
                
                # Copy the triplet without the 'score' field
                new_triplet = {key: value for key, value in triplet.items() if key != 'score'}
                combined_entry['triplets'].append(new_triplet)
        
        # Then, add triplets from unsorted_entry, if not already added
        for triplet in unsorted_entry.get('triplets', []):
            triplet_id = triplet['id']
            if triplet_id not in seen_triplets:
                seen_triplets.add(triplet_id)
                
                # Copy the triplet without the 'score' field
                new_triplet = {key: value for key, value in triplet.items() if key != 'score'}
                combined_entry['triplets'].append(new_triplet)
        
        combined_data.append(combined_entry)
    
    return combined_data

# %%
combined_data =  combine_clean_entries(clean_sorted_data, clean_unsorted_data)

# %%
#SET OPEN AI API KEY 

import openai
import json
import os

openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
print(os.getenv("OPENAI_API_KEY"))
# Out:
# None

# %%
from pydantic import BaseModel, Field
from typing import List
from openai import OpenAI

# Initialize the OpenAI client

client = OpenAI(api_key="Api key goes here")

class TripletRanking(BaseModel):
    triplet_id: str = Field(..., description="The unique identifier of the triplet.")
    rank: int = Field(..., description="The rank assigned to the triplet (1 is most relevant).")
    relevant: int = Field(..., description="1 if the triplet is relevant to the query, 0 if not.")

class RankingResult(BaseModel):
    rankings: List[TripletRanking]

def create_prompt(entry):
    prompt_template = """
I am testing a knowledge graph retrieval system. The knowledge graph contains entities and relations extracted from New Zealand Transport Agency documents. I have retrieved some triplets from the graph, and I need your help to rank them.

Please do the following:

- Given the query and the list of triplets, return the rank of each triplet according to how relevant you think it is to answer the query.
- For each triplet, also indicate whether it is relevant to the query (1 for relevant, 0 for not relevant).
- Provide your answer in the format:

{{
  "rankings": [
    {{
      "triplet_id": "<triplet_id>",
      "rank": <rank>,
      "relevant": <1 or 0>
    }},
    ...
  ]
}}

- The 'triplet_id' corresponds to the unique identifier of the triplet.
- The 'rank' indicates the relevance ranking you assign (1 is most relevant).
- 'relevant' is 1 if the triplet is relevant, 0 if not.

For example:

- Query: "What is the speed limit in Auckland?"

- Triplets:

1: id: "Auckland-has speed limit-50 km/h", triplet: "Auckland -has speed limit-> 50 km/h"
2: id: "New Zealand-increased sales-Motorcycles", triplet: "New Zealand -increased sales-> Motorcycles"
3: id: "Wellington-has speed limit-40 km/h", triplet: "Wellington -has speed limit-> 40 km/h"
4: id: "Auckland driving rules-provides information-Speed limits", triplet: "Auckland driving rules -provides information-> Speed limits"

- Output:

{{
  "rankings": [
    {{
      "triplet_id": "Auckland-has speed limit-50 km/h",
      "rank": 1,
      "relevant": 1
    }},
    {{
      "triplet_id": "Auckland driving rules-provides information-Speed limits",
      "rank": 2,
      "relevant": 1
    }},
    {{
      "triplet_id": "Wellington-has speed limit-40 km/h",
      "rank": 3,
      "relevant": 0
    }},
    {{
      "triplet_id": "New Zealand-increased sales-Motorcycles",
      "rank": 4,
      "relevant": 0
    }}
  ]
}}

- **Important:** Do not include any additional text or explanations in your response. Only output the JSON object as specified.
- **Important:** Output a valid JSON object with keys and strings properly quoted (use double quotes).
- Make sure to include an entry for every triplet provided.
- Make sure the output has the same total number of entries as the number of triplets provided, this is crucial for evaluation.

Here is the query:

{query}

Here are the triplets:

{triplets}
""".strip()

    query = entry['question']
    triplets_list = entry.get('triplets', [])
    triplets_formatted = ''
    for i, triplet in enumerate(triplets_list, start=1):
        triplet_id = triplet['id']
        head = triplet['head']
        relation = triplet['relation']
        tail = triplet['tail']
        triplets_formatted += f'{i}: id: "{triplet_id}", triplet: "{head} -{relation}-> {tail}"\n'

    prompt = prompt_template.format(query=query, triplets=triplets_formatted)
    return prompt

# Example entry (replace with your actual data)
entry = combined_data[0]


# Generate the prompt
prompt = create_prompt(entry)

# Call the OpenAI API
completion = client.beta.chat.completions.parse(
    model="gpt-4o-2024-08-06",  # Replace with the actual model you are using
    messages=[
        {"role": "user", "content": prompt}
    ],
    response_format=RankingResult,
    temperature=0,  # For deterministic output
)

# Get the parsed result
ranking_result = completion.choices[0].message.parsed

# Print the results
for ranking in ranking_result.rankings:
    print(f"Triplet ID: {ranking.triplet_id}")
    print(f"Rank: {ranking.rank}")
    print(f"Relevant: {ranking.relevant}\n")
# Out:
# Triplet ID: State highway network-Managed by-Waka kotahi nz transport agency
# Rank: 1
# Relevant: 1
#
# Triplet ID: New zealand transport agency-Manages-State highway network
# Rank: 2
# Relevant: 1
#
# Triplet ID: New zealand transport agency-Is responsible for-State highway network
# Rank: 3
# Relevant: 1
#
# Triplet ID: New zealand transport agency-Is responsible for-Managing state highway network
# Rank: 4
# Relevant: 1
#
# Triplet ID: Traffic management systems-Critical in-Managing the increasing demand for road space
# Rank: 5
# Relevant: 0
#
# Triplet ID: State highway network-Aimed to create-Cohesive system of major roads
# Rank: 6
# Relevant: 0
#
# Triplet ID: Road network-Most widely used-Mode of transport
# Rank: 7
# Relevant: 0
#
# Triplet ID: Transport demand forecasting-Involves-Socio-economic indicators
# Rank: 8
# Relevant: 0
#
# Triplet ID: Transport demand forecasting-Is-Critical aspect of transportation planning
# Rank: 9
# Relevant: 0
#
# Triplet ID: Transport demand forecasting-Involves-Statistical models
# Rank: 10
# Relevant: 0
#
# Triplet ID: Transport demand forecasting-Estimates-Future travel patterns
# Rank: 11
# Relevant: 0
#
# Triplet ID: Transport demand forecasting-Involves-Historical data
# Rank: 12
# Relevant: 0
#
# Triplet ID: Transport demand forecasting-Estimates-Demand for various transport services
# Rank: 13
# Relevant: 0
#
# Triplet ID: Transport demand management-Is-Set of strategies
# Rank: 14
# Relevant: 0
#
# Triplet ID: Teia-Governed by-Resource management act
# Rank: 15
# Relevant: 0
#
# Triplet ID: Teia-Evaluates-Potential effects of transport projects
# Rank: 16
# Relevant: 0
#
# Triplet ID: Teia-Includes-Economic factors
# Rank: 17
# Relevant: 0
#
# Triplet ID: Regional transport planning-Considers-Economic factors
# Rank: 18
# Relevant: 0
#
# Triplet ID: Regional transport planning-Aims to-Meet mobility needs of communities
# Rank: 19
# Relevant: 0
#
# Triplet ID: Regional transport planning-Is-Critical component
# Rank: 20
# Relevant: 0
#
# Triplet ID: Regional transport planning-Considers-Environmental factors
# Rank: 21
# Relevant: 0
#
# Triplet ID: Environmental factors-Explore-How weather conditions influence road user behavior
# Rank: 22
# Relevant: 0
#
# Triplet ID: Environmental factors-Explore-How road infrastructure quality influences road user behavior
# Rank: 23
# Relevant: 0
#
# Triplet ID: Regional transport planning-Considers-Social factors
# Rank: 24
# Relevant: 0
#
# Triplet ID: Teia-Includes-Social factors
# Rank: 25
# Relevant: 0
#
# Triplet ID: Land transport management act 2003-Governs-Regional transport planning
# Rank: 26
# Relevant: 0
#
# Triplet ID: Land transport management act 2003-Aims to-Provide framework for sustainable development
# Rank: 27
# Relevant: 0
#
# Triplet ID: Land transport management act 2003-Provides for-Establishment of national land transport fund
# Rank: 28
# Relevant: 0
#
# Triplet ID: Land transport management act 2003-Enacted on-1 july
# Rank: 29
# Relevant: 0
#
# Triplet ID: Land transport management act 2003-Is-Key piece of legislation
# Rank: 30
# Relevant: 0
#
# Triplet ID: Land transport management act 2003-Has been updated-To incorporate principles of sustainability
# Rank: 31
# Relevant: 0
#
# Triplet ID: Land transport management act 2003-Has undergone-Several amendments to address emerging transport challenges
# Rank: 32
# Relevant: 0
#
# Triplet ID: Land transport management act 2003-Mandates-Involvement of various stakeholders in planning and decision-making processes
# Rank: 33
# Relevant: 0
#
# Triplet ID: Land transport management act 2003-Establishes-Framework for development of regional land transport plans
# Rank: 34
# Relevant: 0
#
# Triplet ID: Land transport management act 2003-Emphasizes-Importance of integrating land transport planning with land use planning
# Rank: 35
# Relevant: 0
#
# Triplet ID: National land transport programme-Established under-Land transport management act
# Rank: 36
# Relevant: 0
#
# Triplet ID: Wellington regional public transport plan-Established under-Land transport management act
# Rank: 37
# Relevant: 0
#
# Triplet ID: National land transport fund-Established under-Land transport management act
# Rank: 38
# Relevant: 0
#
# Triplet ID: Waka kotahi nz transport agency-Established under-Land transport management act
# Rank: 39
# Relevant: 0
#
# Triplet ID: Waka kotahi-Established under-Land transport management act
# Rank: 40
# Relevant: 0
#
# Triplet ID: New zealand-Has-Land transport management act
# Rank: 41
# Relevant: 0
#
# Triplet ID: Land transport management act 2003-Marked-Shift towards integrated transport planning
# Rank: 42
# Relevant: 0
#
# Triplet ID: Land transport management act 2003-Governs-Public transport services
# Rank: 43
# Relevant: 0

# %%
len(combined_data[114:116])
# Out:
# 2

# %%
from tqdm import tqdm

# Initialize a list to store all the ranking results
all_ranking_results = []

# Loop through all the entries in combined_data with a progress bar
for entry in tqdm(combined_data, desc="Processing entries"):
    # Generate the prompt for the current entry
    prompt = create_prompt(entry)

    # Call the OpenAI API
    completion = client.beta.chat.completions.parse(
        model="gpt-4o-2024-08-06",  # Replace with the actual model you are using
        messages=[
            {"role": "user", "content": prompt}
        ],
        response_format=RankingResult,
        temperature=0,  # For deterministic output
    )

    # Get the parsed result
    ranking_result = completion.choices[0].message.parsed

    # Append the current ranking result to the list
    all_ranking_results.append(ranking_result)

# Now, `all_ranking_results` contains the ranking results for all entries in `combined_data`
# Out:
# Processing entries:   4%|▍         | 5/116 [02:02<45:11, 24.43s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[490], line 12
#       9 prompt = create_prompt(entry)
#      11 # Call the OpenAI API
# ---> 12 completion = client.beta.chat.completions.parse(
#      13     model="gpt-4o-2024-08-06",  # Replace with the actual model you are using
#      14     messages=[
#      15         {"role": "user", "content": prompt}
#      16     ],
#      17     response_format=RankingResult,
#      18     temperature=0,  # For deterministic output
#      19 )
#      21 # Get the parsed result
#      22 ranking_result = completion.choices[0].message.parsed
#
# File /opt/anaconda3/envs/ml/lib/python3.11/site-packages/openai/resources/beta/chat/completions.py:150, in Completions.parse(self, messages, model, response_format, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, n, parallel_tool_calls, presence_penalty, seed, service_tier, stop, store, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     143 def parser(raw_completion: ChatCompletion) -> ParsedChatCompletion[ResponseFormatT]:
#     144     return _parse_chat_completion(
#     145         response_format=response_format,
#     146         chat_completion=raw_completion,
#     147         input_tools=tools,
#     148     )
# --> 150 return self._post(
#     151     "/chat/completions",
#     152     body=maybe_transform(
#     153         {
#     154             "messages": messages,
#     155             "model": model,
#     156             "frequency_penalty": frequency_penalty,
#     157             "function_call": function_call,
#     158             "functions": functions,
#     159             "logit_bias": logit_bias,
#     160             "logprobs": logprobs,
#     161             "max_completion_tokens": max_completion_tokens,
#     162             "max_tokens": max_tokens,
#     163             "metadata": metadata,
#     164             "n": n,
#     165             "parallel_tool_calls": parallel_tool_calls,
#     166             "presence_penalty": presence_penalty,
#     167             "response_format": _type_to_response_format(response_format),
#     168             "seed": seed,
#     169             "service_tier": service_tier,
#     170             "stop": stop,
#     171             "store": store,
#     172             "stream": False,
#     173             "stream_options": stream_options,
#     174             "temperature": temperature,
#     175             "tool_choice": tool_choice,
#     176             "tools": tools,
#     177             "top_logprobs": top_logprobs,
#     178             "top_p": top_p,
#     179             "user": user,
#     180         },
#     181         completion_create_params.CompletionCreateParams,
#     182     ),
#     183     options=make_request_options(
#     184         extra_headers=extra_headers,
#     185         extra_query=extra_query,
#     186         extra_body=extra_body,
#     187         timeout=timeout,
#     188         post_parser=parser,
#     189     ),
#     190     # we turn the `ChatCompletion` instance into a `ParsedChatCompletion`
#     191     # in the `parser` function above
#     192     cast_to=cast(Type[ParsedChatCompletion[ResponseFormatT]], ChatCompletion),
#     193     stream=False,
#     194 )
#
# File /opt/anaconda3/envs/ml/lib/python3.11/site-packages/openai/_base_client.py:1277, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1263 def post(
#    1264     self,
#    1265     path: str,
#    (...)
#    1272     stream_cls: type[_StreamT] | None = None,
#    1273 ) -> ResponseT | _StreamT:
#    1274     opts = FinalRequestOptions.construct(
#    1275         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1276     )
# -> 1277     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /opt/anaconda3/envs/ml/lib/python3.11/site-packages/openai/_base_client.py:954, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     951 else:
#     952     retries_taken = 0
# --> 954 return self._request(
#     955     cast_to=cast_to,
#     956     options=options,
#     957     stream=stream,
#     958     stream_cls=stream_cls,
#     959     retries_taken=retries_taken,
#     960 )
#
# File /opt/anaconda3/envs/ml/lib/python3.11/site-packages/openai/_base_client.py:990, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     987 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     989 try:
# --> 990     response = self._client.send(
#     991         request,
#     992         stream=stream or self._should_stream_response_body(request=request),
#     993         **kwargs,
#     994     )
#     995 except httpx.TimeoutException as err:
#     996     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File /opt/anaconda3/envs/ml/lib/python3.11/site-packages/httpx/_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File /opt/anaconda3/envs/ml/lib/python3.11/site-packages/httpx/_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File /opt/anaconda3/envs/ml/lib/python3.11/site-packages/httpx/_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File /opt/anaconda3/envs/ml/lib/python3.11/site-packages/httpx/_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File /opt/anaconda3/envs/ml/lib/python3.11/site-packages/httpx/_transports/default.py:236, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#     240 return Response(
#     241     status_code=resp.status,
#     242     headers=resp.headers,
#     243     stream=ResponseStream(resp.stream),
#     244     extensions=resp.extensions,
#     245 )
#
# File /opt/anaconda3/envs/ml/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File /opt/anaconda3/envs/ml/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File /opt/anaconda3/envs/ml/lib/python3.11/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File /opt/anaconda3/envs/ml/lib/python3.11/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File /opt/anaconda3/envs/ml/lib/python3.11/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File /opt/anaconda3/envs/ml/lib/python3.11/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File /opt/anaconda3/envs/ml/lib/python3.11/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File /opt/anaconda3/envs/ml/lib/python3.11/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File /opt/anaconda3/envs/ml/lib/python3.11/ssl.py:1295, in SSLSocket.recv(self, buflen, flags)
#    1291     if flags != 0:
#    1292         raise ValueError(
#    1293             "non-zero flags not allowed in calls to recv() on %s" %
#    1294             self.__class__)
# -> 1295     return self.read(buflen)
#    1296 else:
#    1297     return super().recv(buflen, flags)
#
# File /opt/anaconda3/envs/ml/lib/python3.11/ssl.py:1168, in SSLSocket.read(self, len, buffer)
#    1166         return self._sslobj.read(len, buffer)
#    1167     else:
# -> 1168         return self._sslobj.read(len)
#    1169 except SSLError as x:
#    1170     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
# add empty entries to ranking_results until it is length 200
while len(all_ranking_results) < 116:
    all_ranking_results.append(RankingResult(rankings=[]))

# %%
# Save the ranking results as a pickle file
import pickle

with open('ranking_results_sp_cot/ranking_results_d1.pkl', 'wb') as file:
    pickle.dump(all_ranking_results, file)

# %%
all_ranking_results = pickle.load(open('ranking_results_sp_cot/ranking_results_d6.pkl', 'rb'))
print(len(all_ranking_results))
# Out:
# 116

# %%
# Step 2: Identify and Clean Incomplete Entries
print("\nIdentifying and cleaning incomplete entries...")

incomplete_entries = []

for i, (rank_result, data_entry) in enumerate(zip(all_ranking_results, combined_data)):
    if rank_result is None:
        incomplete_entries.append(i)
        #print
        continue  # No rankings available, mark as incomplete

    # Create a set of valid triplet IDs from the original data
    valid_triplet_ids = {triplet['id'] for triplet in data_entry['triplets']}
    
    # Remove any rankings with triplet_ids not present in the original data
    cleaned_rankings_dict = {}
    for ranking in rank_result.rankings:
        if ranking.triplet_id in valid_triplet_ids:
            # If triplet_id already exists, decide which one to keep (e.g., keep the first occurrence)
            if ranking.triplet_id not in cleaned_rankings_dict:
                cleaned_rankings_dict[ranking.triplet_id] = ranking
            else:
                # Optionally, you can implement logic to decide which duplicate to keep
                # For simplicity, we're keeping the first occurrence
                continue
    
    # Convert the dictionary back to a list
    cleaned_rankings = list(cleaned_rankings_dict.values())
    
    # Update the rankings in all_ranking_results with the cleaned rankings
    all_ranking_results[i].rankings = cleaned_rankings
    
    # Now, compare the lengths to identify incomplete entries
    if len(cleaned_rankings) != len(data_entry['triplets']):
        # print which one is missing data
        if len(cleaned_rankings) < len(data_entry['triplets']):
            print(f"Entry {i} is missing data.")
            
        incomplete_entries.append(i)

print(f"Found {len(incomplete_entries)} incomplete entries after cleaning.")
# Out:
# Identifying and cleaning incomplete entries...
# Found 0 incomplete entries after cleaning.

# %%
all_ranking_results[106].rankings[0].triplet_id
combined_data[106]['triplets'][0]['id']

# loop over that entry (57) and figure out which id from combined_data is missing in all_ranking_results
for triplet in combined_data[106]['triplets']:
    triplet_id = triplet['id']
    found = False
    for ranking in all_ranking_results[106].rankings:
        if ranking.triplet_id == triplet_id:
            found = True
            break
    if not found:
        print(f"Triplet ID {triplet_id} is missing in the rankings.")

# do the vice versa
for ranking in all_ranking_results[106].rankings:
    triplet_id = ranking.triplet_id
    found = False
    for triplet in combined_data[106]['triplets']:
        if triplet['id'] == triplet_id:
            found = True
            break
    if not found:
        print(f"Triplet ID {triplet_id} is missing in the data.")
# Out:
# Triplet ID Waka kotahi-Has-Road to zero  strategy is missing in the rankings.

# %%
print(len(all_ranking_results[106].rankings))
print(len(combined_data[106]['triplets']))
# Out:
# 36
# 37

# %%
# modify the entry in all_rankings that has the id Triplet ID Waka kotahi-Has-Road to zero  strategy is missing in the rankings.
# so that it has the id  Triplet ID Waka kotahi-Has-Road to zero strategy is missing in the data.

# Find the index of all_rankongs that has id Triplet ID Waka kotahi-Has-Road to zero strategy
entry_index = None

for i, ranking in enumerate(all_ranking_results):
    entry_within = None
    for j, triplet in enumerate(ranking.rankings):
        if triplet.triplet_id == 'Waka kotahi-Has-Road to zero strategy':
            entry_index = i
            entry_within = j
            break
    if entry_index is not None:
        break
entry_within
# Out:
# 36

# %%
all_ranking_results[106].rankings[36].triplet_id = "Waka kotahi-Has-Road to zero  strategy"

# %%
# find entry in all_ranking_results that has the id Triplet ID Toitū Te Taiao-FOCUSES-reducing corporate emissions
for i, rank_result in enumerate(all_ranking_results):
    for j, ranking in enumerate(rank_result.rankings):
        if ranking.triplet_id == 'Toitū Te Taiao-FOCUSES-reducing corporate emissions':
            print(f"Found in entry {j}")
            break
# Out:
# Found in entry 1

# %%
combined_data[37]['triplets'][0]['id']
# Out:
# 'Transport in new zealand-Has-Automated data collection'

# %%
def create_correction_prompt(entry, existing_rankings):
    correction_prompt_template = """
I previously ranked the following triplets for the query:

{query}

Existing Rankings:
{existing_rankings}

However, some triplets were missing from the rankings. Please assign ranks to the missing triplets. Use decimal ranks (e.g., 2.5) to place them between existing ranks or whole numbers if they should be last. Ensure that the final rankings include all triplets with consistent formatting.

Missing Triplets:
{missing_triplets}

Provide your answer in the following JSON format, **only** for the missing triplets:

{{
  "rankings": [
    {{
      "triplet_id": "<triplet_id>",
      "rank": <rank>,
      "relevant": <1 or 0>
    }},
    ...
  ]
}}
""".strip()
    
    query = entry['question']
    existing_rankings_formatted = ''
    for ranking in existing_rankings:
        existing_rankings_formatted += f'{{"triplet_id": "{ranking.triplet_id}", "rank": {ranking.rank}, "relevant": {ranking.relevant}}},\n'
    
    # Remove the trailing comma and newline
    existing_rankings_formatted = existing_rankings_formatted.rstrip(',\n')
    
    # Identify missing triplets
    existing_triplet_ids = {r.triplet_id for r in existing_rankings}
    missing_triplets = [
        triplet for triplet in entry['triplets']
        if triplet['id'] not in existing_triplet_ids
    ]

    
    if not missing_triplets:
        return None  # No missing triplets to correct
    
    missing_triplets_formatted = ''
    for triplet in missing_triplets:
        missing_triplets_formatted += f'{{"triplet_id": "{triplet["id"]}"}} ,\n'
    
    # Remove the trailing comma and newline
    missing_triplets_formatted = missing_triplets_formatted.rstrip(',\n')
    
    correction_prompt = correction_prompt_template.format(
        query=query,
        existing_rankings=existing_rankings_formatted,
        missing_triplets=missing_triplets_formatted
    )
    
    return correction_prompt

# %%
from tqdm import tqdm
import json

# Step 1: Identify Incomplete Entries
incomplete_entries = [
    i for i, (rank_result, data_entry) in enumerate(zip(all_ranking_results, combined_data))
    if rank_result is None or len(rank_result.rankings) != len(data_entry['triplets'])
]

print(f"Found {len(incomplete_entries)} incomplete entries.")

# Step 2: Rerun Incomplete Entries with Correction Prompts
if incomplete_entries:
    print("\nRerunning incomplete entries with correction prompts...")
    for i in tqdm(incomplete_entries, desc="Rerunning incomplete entries"):
        entry = combined_data[i]
        existing_rankings = all_ranking_results[i].rankings if all_ranking_results[i] else []
        
        # Create the correction prompt
        correction_prompt = create_correction_prompt(entry, existing_rankings)
        
        if not correction_prompt:
            # No missing triplets to correct
            continue
        
        try:
            # Call the OpenAI API with the correction prompt
            correction_completion = client.beta.chat.completions.parse(
                model="gpt-4o-2024-08-06",
                messages=[{"role": "user", "content": correction_prompt}],
                response_format=RankingResult,
                temperature=0,
            )
            new_ranking_result = correction_completion.choices[0].message.parsed
            
            # Merge the new rankings with existing ones
            if all_ranking_results[i] is None:
                all_ranking_results[i] = new_ranking_result
            else:
                # Create a dictionary to avoid duplicate triplet_ids
                combined_rankings_dict = {r.triplet_id: r for r in all_ranking_results[i].rankings}
                for new_ranking in new_ranking_result.rankings:
                    combined_rankings_dict[new_ranking.triplet_id] = new_ranking  # Overwrite or add
                
                # Convert back to a list and sort by rank
                combined_rankings_sorted = sorted(combined_rankings_dict.values(), key=lambda x: x.rank)
                
                # Assign the sorted rankings back
                all_ranking_results[i].rankings = combined_rankings_sorted
            
            # Verify if rerun was successful
            if len(all_ranking_results[i].rankings) == len(entry['triplets']):
                print(f"Successfully corrected entry at index {i}")
            else:
                print(f"Still incomplete after correction at index {i}")
        except Exception as e:
            print(f"Error correcting entry at index {i}: {e}")

    # Step 3: Final Check for Remaining Incomplete Entries
    remaining_incomplete = [
        i for i, (rank_result, data_entry) in enumerate(zip(all_ranking_results, combined_data))
        if rank_result is None or len(rank_result.rankings) != len(data_entry['triplets'])
    ]

    if remaining_incomplete:
        print(f"\n{len(remaining_incomplete)} entries are still incomplete after correction:")
        for i in remaining_incomplete:
            print(f" - Index {i}")
        # Optionally, save these to a file for manual review
        mismatches = [
            {
                'index': i, 
                'missing_rankings': len(combined_data[i]['triplets']) - (len(all_ranking_results[i].rankings) if all_ranking_results[i] else 0)
            }
            for i in remaining_incomplete
        ]

        with open('remaining_incomplete_entries.json', 'w') as f:
            json.dump(mismatches, f, indent=4)
        
        print("\nRemaining incomplete entries have been saved to 'remaining_incomplete_entries.json' for further review.")
    else:
        print("\nAll incomplete entries have been successfully corrected and completed.")
else:
    print("No incomplete entries found.")
# Out:
# Found 16 incomplete entries.
#
# Rerunning incomplete entries with correction prompts...
# Rerunning incomplete entries:   6%|▋         | 1/16 [00:01<00:15,  1.06s/it]
# Successfully corrected entry at index 15
# Rerunning incomplete entries:  12%|█▎        | 2/16 [00:03<00:29,  2.07s/it]
# Successfully corrected entry at index 28
# Rerunning incomplete entries:  19%|█▉        | 3/16 [00:05<00:24,  1.91s/it]
# Successfully corrected entry at index 37
# Rerunning incomplete entries:  25%|██▌       | 4/16 [00:06<00:18,  1.57s/it]
# Successfully corrected entry at index 44
# Rerunning incomplete entries:  31%|███▏      | 5/16 [00:07<00:15,  1.44s/it]
# Successfully corrected entry at index 52
# Rerunning incomplete entries:  38%|███▊      | 6/16 [00:09<00:16,  1.65s/it]
# Successfully corrected entry at index 54
# Rerunning incomplete entries:  44%|████▍     | 7/16 [00:10<00:13,  1.44s/it]
# Successfully corrected entry at index 57
# Rerunning incomplete entries:  50%|█████     | 8/16 [00:11<00:10,  1.31s/it]
# Successfully corrected entry at index 62
# Rerunning incomplete entries:  56%|█████▋    | 9/16 [00:12<00:08,  1.22s/it]
# Successfully corrected entry at index 63
# Rerunning incomplete entries:  62%|██████▎   | 10/16 [00:13<00:07,  1.17s/it]
# Successfully corrected entry at index 68
# Rerunning incomplete entries:  69%|██████▉   | 11/16 [00:14<00:05,  1.08s/it]
# Successfully corrected entry at index 78
# Rerunning incomplete entries:  75%|███████▌  | 12/16 [00:16<00:04,  1.20s/it]
# Successfully corrected entry at index 81
# Rerunning incomplete entries:  81%|████████▏ | 13/16 [00:17<00:03,  1.26s/it]
# Successfully corrected entry at index 85
# Rerunning incomplete entries:  88%|████████▊ | 14/16 [00:18<00:02,  1.14s/it]
# Successfully corrected entry at index 90
# Rerunning incomplete entries:  94%|█████████▍| 15/16 [00:19<00:01,  1.08s/it]
# Successfully corrected entry at index 93
# Rerunning incomplete entries: 100%|██████████| 16/16 [00:20<00:00,  1.28s/it]
# Successfully corrected entry at index 100
#
# All incomplete entries have been successfully corrected and completed.

# %%
# Step 3: Rerun Incomplete Entries
if incomplete_entries:
    print("\nRerunning incomplete entries...")
    for i in tqdm(incomplete_entries, desc="Rerunning incomplete entries"):
        entry = combined_data[i]
        prompt = create_prompt(entry)
        try:
            completion = client.beta.chat.completions.parse(
                model="gpt-4o-2024-08-06",
                messages=[{"role": "user", "content": prompt}],
                response_format=RankingResult,
                temperature=0,
            )
            new_ranking_result = completion.choices[0].message.parsed

            # Replace the incomplete ranking_result with the new one
            all_ranking_results[i] = new_ranking_result

            # Verify if rerun was successful
            if len(new_ranking_result.rankings) == len(entry['triplets']):
                print(f"Successfully reran entry at index {i}")
            else:
                print(f"Still incomplete after rerunning entry at index {i}")
        except Exception as e:
            print(f"Error rerunning entry at index {i}: {e}")
            # Optionally, decide how to handle errors (e.g., keep as None or append to a failed list)

    # Step 4: Optional - Check for Remaining Incomplete Entries
    remaining_incomplete = [
        i for i, (rank_result, data_entry) in enumerate(zip(all_ranking_results, combined_data))
        if rank_result is None or len(rank_result.rankings) != len(data_entry['triplets'])
    ]

# %%
all_ranking_results

# %%
# Out:
# 114

# %%
def normalize_ranks(rankings):
    """
    Converts decimal ranks to integer ranks by sorting and reassigning ranks.
    Prints a message if any decimal ranks were found and corrected.
    
    Parameters:
    - rankings (List[TripletRanking]): The list of rankings to normalize.
    
    Returns:
    - List[TripletRanking]: The list with normalized integer ranks.
    """
    has_decimal = any(r.rank != int(r.rank) for r in rankings)
    
    # Sort the rankings by current rank
    sorted_rankings = sorted(rankings, key=lambda x: x.rank)
    
    # Assign integer ranks based on sorted order
    for idx, ranking in enumerate(sorted_rankings, start=1):
        ranking.rank = idx
    
    if has_decimal:
        print("Decimal ranks detected and normalized.")
    
    return sorted_rankings

from tqdm import tqdm

# Normalize ranks for all ranking results
for ranking_result in tqdm(all_ranking_results, desc="Normalizing ranks"):
    if ranking_result and ranking_result.rankings:
        ranking_result.rankings = normalize_ranks(ranking_result.rankings)
# Out:
# Normalizing ranks: 100%|██████████| 116/116 [00:00<00:00, 18415.57it/s]

# %%
def add_rank_and_relevance_for_index(clean_sorted_entry, ranking_result):
    mismatches = []
    # Loop through each triplet in clean_sorted_entry
    for triplet in clean_sorted_entry['triplets']:
        triplet_id = triplet['id']
        found = False

        # Loop through rankings in ranking_result and match by id
        for ranking in ranking_result.rankings:
            if triplet_id == ranking.triplet_id:
                # Add rank and relevance to the triplet
                triplet['rank'] = ranking.rank
                triplet['relevant'] = ranking.relevant
                found = True
                break

        # If no matching id is found, store the triplet
        if not found:
            mismatches.append(triplet)

    return clean_sorted_entry, mismatches

# %%
# Assuming clean_sorted_data, clean_unsorted_data, and all_ranking_results are defined

# Process clean_sorted_data and collect mismatches
clean_sorted_data_with_ranking, sorted_mismatches_raw = zip(*[
    add_rank_and_relevance_for_index(entry, ranking_result) 
    for entry, ranking_result in zip(clean_sorted_data, all_ranking_results)
])

# Process clean_unsorted_data and collect mismatches
clean_unsorted_data_with_ranking, unsorted_mismatches_raw = zip(*[
    add_rank_and_relevance_for_index(entry, ranking_result) 
    for entry, ranking_result in zip(clean_unsorted_data, all_ranking_results)
])

# Convert mismatches into a list of dictionaries with indices
sorted_mismatches = [
    {'index': idx, 'missing': mismatches} 
    for idx, mismatches in enumerate(sorted_mismatches_raw) if mismatches
]

unsorted_mismatches = [
    {'index': idx, 'missing': mismatches} 
    for idx, mismatches in enumerate(unsorted_mismatches_raw) if mismatches
]

# %%
clean_sorted_data_with_ranking
# Out:
# ({'question': 'Who manages the State Highway network in the country known for its critical approach to transport demand forecasting, utilizing statistical models and socio-economic indicators to predict future travel patterns?',
#   'triplets': [{'head': 'Resource management act 1991',
#     'relation': 'Plays',
#     'tail': 'Significant role in shaping transport infrastructure',
#     'score': 0.8373398184776306,
#     'id': 'Resource management act 1991-Plays-Significant role in shaping transport infrastructure',
#     'rank': 13,
#     'relevant': 0},
#    {'head': 'Resource management act 1991',
#     'relation': 'Recognizes',
#     'tail': "Transport as critical component of nation's infrastructure",
#     'score': 0.8328390717506409,
#     'id': "Resource management act 1991-Recognizes-Transport as critical component of nation's infrastructure",
#     'rank': 14,
#     'relevant': 0},
#    {'head': 'Resource management act 1991',
#     'relation': 'Subject',
#     'tail': 'Debate regarding effectiveness in addressing challenges of modern transport needs',
#     'score': 0.830618679523468,
#     'id': 'Resource management act 1991-Subject-Debate regarding effectiveness in addressing challenges of modern transport needs',
#     'rank': 15,
#     'relevant': 0},
#    {'head': 'Resource management act 1991',
#     'relation': 'Recognizes',
#     'tail': 'Transport as critical component',
#     'score': 0.8261200189590454,
#     'id': 'Resource management act 1991-Recognizes-Transport as critical component',
#     'rank': 16,
#     'relevant': 0},
#    {'head': 'Resource management act 1991',
#     'relation': 'Cornerstone',
#     'tail': "New zealand's approach to managing transport",
#     'score': 0.8220652937889099,
#     'id': "Resource management act 1991-Cornerstone-New zealand's approach to managing transport",
#     'rank': 17,
#     'relevant': 0},
#    {'head': 'Resource management act 1991',
#     'relation': 'Praised for',
#     'tail': 'Promoting integrated approach to transport planning',
#     'score': 0.8126389980316162,
#     'id': 'Resource management act 1991-Praised for-Promoting integrated approach to transport planning',
#     'rank': 18,
#     'relevant': 0},
#    {'head': 'Transport demand forecasting',
#     'relation': 'Involves',
#     'tail': 'Socio-economic indicators',
#     'score': 0.8820364475250244,
#     'id': 'Transport demand forecasting-Involves-Socio-economic indicators',
#     'rank': 6,
#     'relevant': 1},
#    {'head': 'Transport demand forecasting',
#     'relation': 'Is',
#     'tail': 'Critical aspect of transportation planning',
#     'score': 0.8725880980491638,
#     'id': 'Transport demand forecasting-Is-Critical aspect of transportation planning',
#     'rank': 9,
#     'relevant': 0},
#    {'head': 'Transport demand forecasting',
#     'relation': 'Involves',
#     'tail': 'Statistical models',
#     'score': 0.8614435791969299,
#     'id': 'Transport demand forecasting-Involves-Statistical models',
#     'rank': 7,
#     'relevant': 1},
#    {'head': 'Transport demand forecasting',
#     'relation': 'Estimates',
#     'tail': 'Future travel patterns',
#     'score': 0.8473142385482788,
#     'id': 'Transport demand forecasting-Estimates-Future travel patterns',
#     'rank': 8,
#     'relevant': 1},
#    {'head': 'Transport demand forecasting',
#     'relation': 'Involves',
#     'tail': 'Historical data',
#     'score': 0.841994047164917,
#     'id': 'Transport demand forecasting-Involves-Historical data',
#     'rank': 10,
#     'relevant': 0},
#    {'head': 'Transport demand forecasting',
#     'relation': 'Estimates',
#     'tail': 'Demand for various transport services',
#     'score': 0.8376253247261047,
#     'id': 'Transport demand forecasting-Estimates-Demand for various transport services',
#     'rank': 11,
#     'relevant': 0},
#    {'head': 'New zealand transport agency',
#     'relation': 'Is responsible for',
#     'tail': 'Managing state highway network',
#     'score': 0.8575925827026367,
#     'id': 'New zealand transport agency-Is responsible for-Managing state highway network',
#     'rank': 2,
#     'relevant': 1},
#    {'head': 'New zealand transport agency',
#     'relation': 'Manages',
#     'tail': 'State highway network',
#     'score': 0.8481019735336304,
#     'id': 'New zealand transport agency-Manages-State highway network',
#     'rank': 1,
#     'relevant': 1},
#    {'head': 'New zealand transport agency',
#     'relation': 'Is responsible for',
#     'tail': 'State highway network',
#     'score': 0.8457592725753784,
#     'id': 'New zealand transport agency-Is responsible for-State highway network',
#     'rank': 3,
#     'relevant': 1},
#    {'head': 'New zealand transport agency',
#     'relation': 'Plays',
#     'tail': 'Pivotal role in conducting forecasts',
#     'score': 0.8428968191146851,
#     'id': 'New zealand transport agency-Plays-Pivotal role in conducting forecasts',
#     'rank': 5,
#     'relevant': 1},
#    {'head': 'New zealand transport agency',
#     'relation': 'Tasked with',
#     'tail': 'Overseeing the maintenance and development of the state highway network',
#     'score': 0.841880738735199,
#     'id': 'New zealand transport agency-Tasked with-Overseeing the maintenance and development of the state highway network',
#     'rank': 4,
#     'relevant': 1},
#    {'head': 'Traffic management systems',
#     'relation': 'Governed by',
#     'tail': 'New zealand transport agency',
#     'score': 0.8415231704711914,
#     'id': 'Traffic management systems-Governed by-New zealand transport agency',
#     'rank': 12,
#     'relevant': 0},
#    {'head': 'Public transport network planning',
#     'relation': 'Is',
#     'tail': 'Critical aspect of urban and regional development',
#     'score': 0.8401920795440674,
#     'id': 'Public transport network planning-Is-Critical aspect of urban and regional development',
#     'rank': 19,
#     'relevant': 0}]},
#  {'question': 'What is the abbreviation commonly used for the initiative that the New Zealand government has launched to develop dedicated cycling infrastructure in New Zealand?',
#   'triplets': [{'head': 'North island',
#     'relation': 'Has',
#     'tail': 'Growing emphasis on sustainable transport options',
#     'score': 0.7718919515609741,
#     'id': 'North island-Has-Growing emphasis on sustainable transport options',
#     'rank': 49,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Invested in cycling infrastructure',
#     'score': 0.8836433291435242,
#     'id': 'New zealand-Has-Invested in cycling infrastructure',
#     'rank': 1,
#     'relevant': 1},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Government initiatives',
#     'score': 0.8774043917655945,
#     'id': 'New zealand-Has-Government initiatives',
#     'rank': 4,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Infrastructure development',
#     'score': 0.8766574859619141,
#     'id': 'New zealand-Has-Infrastructure development',
#     'rank': 5,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Faces',
#     'tail': 'Challenges in expanding its cycling infrastructure',
#     'score': 0.8755258321762085,
#     'id': 'New zealand-Faces-Challenges in expanding its cycling infrastructure',
#     'rank': 6,
#     'relevant': 0},
#    {'head': 'New zealand transport agency',
#     'relation': 'Plays',
#     'tail': 'A crucial role in funding and promoting cycling infrastructure projects',
#     'score': 0.8729434609413147,
#     'id': 'New zealand transport agency-Plays-A crucial role in funding and promoting cycling infrastructure projects',
#     'rank': 2,
#     'relevant': 1},
#    {'head': 'Auckland transport',
#     'relation': 'Implemented',
#     'tail': 'Cycling infrastructure projects',
#     'score': 0.8680109977722168,
#     'id': 'Auckland transport-Implemented-Cycling infrastructure projects',
#     'rank': 7,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Transport infrastructure development',
#     'score': 0.8679700493812561,
#     'id': 'New zealand-Has-Transport infrastructure development',
#     'rank': 8,
#     'relevant': 0},
#    {'head': 'Projects',
#     'relation': 'Include',
#     'tail': 'Development of cycling infrastructure',
#     'score': 0.8605217337608337,
#     'id': 'Projects-Include-Development of cycling infrastructure',
#     'rank': 3,
#     'relevant': 1},
#    {'head': 'State highway network',
#     'relation': 'Managed by',
#     'tail': 'Waka kotahi nz transport agency',
#     'score': 0.8284339904785156,
#     'id': 'State highway network-Managed by-Waka kotahi nz transport agency',
#     'rank': 9,
#     'relevant': 0},
#    {'head': 'Road construction standards',
#     'relation': 'Governed by',
#     'tail': 'Waka kotahi nz transport agency',
#     'score': 0.8276388645172119,
#     'id': 'Road construction standards-Governed by-Waka kotahi nz transport agency',
#     'rank': 10,
#     'relevant': 0},
#    {'head': 'National land transport programme',
#     'relation': 'Developed by',
#     'tail': 'Waka kotahi nz transport agency',
#     'score': 0.8236346244812012,
#     'id': 'National land transport programme-Developed by-Waka kotahi nz transport agency',
#     'rank': 11,
#     'relevant': 0},
#    {'head': 'Waka kotahi nz transport agency',
#     'relation': 'Advocates for',
#     'tail': 'Active transport modes',
#     'score': 0.8230215311050415,
#     'id': 'Waka kotahi nz transport agency-Advocates for-Active transport modes',
#     'rank': 12,
#     'relevant': 0},
#    {'head': 'Waka kotahi nz transport agency',
#     'relation': 'Involved in',
#     'tail': 'Enhancing resilience of infrastructure',
#     'score': 0.8224135637283325,
#     'id': 'Waka kotahi nz transport agency-Involved in-Enhancing resilience of infrastructure',
#     'rank': 13,
#     'relevant': 0},
#    {'head': 'Waka kotahi nz transport agency',
#     'relation': 'Develops',
#     'tail': 'Projects',
#     'score': 0.8177381157875061,
#     'id': 'Waka kotahi nz transport agency-Develops-Projects',
#     'rank': 14,
#     'relevant': 0},
#    {'head': 'New zealand electric vehicle programme',
#     'relation': 'Is',
#     'tail': 'Government initiative',
#     'score': 0.8730065226554871,
#     'id': 'New zealand electric vehicle programme-Is-Government initiative',
#     'rank': 15,
#     'relevant': 0},
#    {'head': 'National cycling policy',
#     'relation': 'Part of',
#     'tail': "New zealand's commitment",
#     'score': 0.862525224685669,
#     'id': "National cycling policy-Part of-New zealand's commitment",
#     'rank': 16,
#     'relevant': 0},
#    {'head': 'New zealand electric vehicle programme',
#     'relation': 'Part of',
#     'tail': "New zealand's commitment",
#     'score': 0.8326377868652344,
#     'id': "New zealand electric vehicle programme-Part of-New zealand's commitment",
#     'rank': 17,
#     'relevant': 0},
#    {'head': 'New zealand electric vehicle programme',
#     'relation': 'Objective',
#     'tail': 'Enhancing the availability of charging infrastructure',
#     'score': 0.8325090408325195,
#     'id': 'New zealand electric vehicle programme-Objective-Enhancing the availability of charging infrastructure',
#     'rank': 18,
#     'relevant': 0},
#    {'head': 'New zealand electric vehicle programme',
#     'relation': 'Objective',
#     'tail': 'Increasing the number of electric vehicles on new zealand roads',
#     'score': 0.8263366222381592,
#     'id': 'New zealand electric vehicle programme-Objective-Increasing the number of electric vehicles on new zealand roads',
#     'rank': 19,
#     'relevant': 0},
#    {'head': 'New zealand electric vehicle programme',
#     'relation': 'Goal',
#     'tail': 'Transitioning to a more sustainable transport system',
#     'score': 0.8161503076553345,
#     'id': 'New zealand electric vehicle programme-Goal-Transitioning to a more sustainable transport system',
#     'rank': 20,
#     'relevant': 0},
#    {'head': 'Auckland western ring route',
#     'relation': 'Reflects',
#     'tail': "New zealand's commitment",
#     'score': 0.8140708208084106,
#     'id': "Auckland western ring route-Reflects-New zealand's commitment",
#     'rank': 21,
#     'relevant': 0}]},
#  {'question': 'What suburb does Te Ara I Whiti (Lightpath) connect to from the city that is home to the Te Ara I Whiti (Lightpath) project, which has transformed underutilized spaces into vibrant cycling and pedestrian pathways, CBD?',
#   'triplets': [{'head': 'Onehunga',
#     'relation': 'Has',
#     'tail': 'Dedicated cycle lanes and pedestrian pathways',
#     'score': 0.779625415802002,
#     'id': 'Onehunga-Has-Dedicated cycle lanes and pedestrian pathways',
#     'rank': 10,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Promotes',
#     'tail': 'Active transport',
#     'score': 0.7649909257888794,
#     'id': 'New zealand-Promotes-Active transport',
#     'rank': 24,
#     'relevant': 0},
#    {'head': 'Onehunga',
#     'relation': 'Is',
#     'tail': 'Suburb located approximately',
#     'score': 12.0,
#     'id': 'Onehunga-Is-Suburb located approximately',
#     'rank': 14,
#     'relevant': 0},
#    {'head': 'Onehunga',
#     'relation': 'Has',
#     'tail': 'Seen significant improvements in cycling and walking infrastructure',
#     'score': 0.7572973370552063,
#     'id': 'Onehunga-Has-Seen significant improvements in cycling and walking infrastructure',
#     'rank': 11,
#     'relevant': 0},
#    {'head': 'Onehunga',
#     'relation': 'Contributes to',
#     'tail': "City's goals of reducing carbon emissions and enhancing public health",
#     'score': 0.7444372773170471,
#     'id': "Onehunga-Contributes to-City's goals of reducing carbon emissions and enhancing public health",
#     'rank': 12,
#     'relevant': 0},
#    {'head': 'Onehunga',
#     'relation': 'Has',
#     'tail': 'Integration of bus and rail services',
#     'score': 0.7384935617446899,
#     'id': 'Onehunga-Has-Integration of bus and rail services',
#     'rank': 13,
#     'relevant': 0},
#    {'head': 'Te ara i whiti',
#     'relation': 'Links',
#     'tail': 'Auckland cbd',
#     'score': 0.8644683361053467,
#     'id': 'Te ara i whiti-Links-Auckland cbd',
#     'rank': 2,
#     'relevant': 1},
#    {'head': 'Te ara i whiti',
#     'relation': 'Is',
#     'tail': 'Lightpath',
#     'score': 0.8454588651657104,
#     'id': 'Te ara i whiti-Is-Lightpath',
#     'rank': 6,
#     'relevant': 1},
#    {'head': 'Te ara i whiti',
#     'relation': 'Part of',
#     'tail': 'Auckland cycle network',
#     'score': 0.8362159132957458,
#     'id': 'Te ara i whiti-Part of-Auckland cycle network',
#     'rank': 4,
#     'relevant': 1},
#    {'head': 'Te ara i whiti',
#     'relation': 'Located in',
#     'tail': 'Auckland',
#     'score': 0.8239569067955017,
#     'id': 'Te ara i whiti-Located in-Auckland',
#     'rank': 3,
#     'relevant': 1},
#    {'head': 'Auckland',
#     'relation': 'Has',
#     'tail': 'Pedestrian pathways',
#     'score': 0.8233243227005005,
#     'id': 'Auckland-Has-Pedestrian pathways',
#     'rank': 28,
#     'relevant': 0},
#    {'head': 'Te ara i whiti',
#     'relation': 'Constructed on',
#     'tail': 'Former railway corridor',
#     'score': 0.8218223452568054,
#     'id': 'Te ara i whiti-Constructed on-Former railway corridor',
#     'rank': 7,
#     'relevant': 1},
#    {'head': 'Auckland',
#     'relation': 'Connected to',
#     'tail': 'Surrounding suburbs and regions',
#     'score': 0.8139963150024414,
#     'id': 'Auckland-Connected to-Surrounding suburbs and regions',
#     'rank': 8,
#     'relevant': 1},
#    {'head': 'Western line',
#     'relation': 'Connects',
#     'tail': 'Commuters to cbd',
#     'score': 0.8123621940612793,
#     'id': 'Western line-Connects-Commuters to cbd',
#     'rank': 34,
#     'relevant': 0},
#    {'head': 'Eastern line',
#     'relation': 'Connects',
#     'tail': 'Commuters to cbd',
#     'score': 0.8025721907615662,
#     'id': 'Eastern line-Connects-Commuters to cbd',
#     'rank': 35,
#     'relevant': 0},
#    {'head': 'Southern line',
#     'relation': 'Connects',
#     'tail': 'Commuters to cbd',
#     'score': 0.7966413497924805,
#     'id': 'Southern line-Connects-Commuters to cbd',
#     'rank': 36,
#     'relevant': 0},
#    {'head': 'Western line',
#     'relation': 'Is',
#     'tail': 'Primary rail corridor',
#     'score': 0.7505043745040894,
#     'id': 'Western line-Is-Primary rail corridor',
#     'rank': 37,
#     'relevant': 0},
#    {'head': 'Eastern line',
#     'relation': 'Is',
#     'tail': 'Primary rail corridor',
#     'score': 0.735020101070404,
#     'id': 'Eastern line-Is-Primary rail corridor',
#     'rank': 38,
#     'relevant': 0},
#    {'head': 'Southern line',
#     'relation': 'Is',
#     'tail': 'Primary rail corridor',
#     'score': 0.7346377372741699,
#     'id': 'Southern line-Is-Primary rail corridor',
#     'rank': 39,
#     'relevant': 0},
#    {'head': 'Onehunga',
#     'relation': 'Has',
#     'tail': 'Multiple routes linking it to surrounding suburbs and the auckland cbd',
#     'score': 0.8053060173988342,
#     'id': 'Onehunga-Has-Multiple routes linking it to surrounding suburbs and the auckland cbd',
#     'rank': 9,
#     'relevant': 0}]},
#  {'question': 'Which island does the city in New Zealand known for its Metlink services, which focus on providing comprehensive coverage across the region, the capital city of New Zealand, belong to?',
#   'triplets': [{'head': 'Auckland',
#     'relation': 'Has',
#     'tail': 'Comprehensive public transport networks',
#     'score': 0.8161145448684692,
#     'id': 'Auckland-Has-Comprehensive public transport networks',
#     'rank': 9,
#     'relevant': 0},
#    {'head': 'Christchurch',
#     'relation': 'Has',
#     'tail': 'Comprehensive public transport networks',
#     'score': 0.8131680488586426,
#     'id': 'Christchurch-Has-Comprehensive public transport networks',
#     'rank': 10,
#     'relevant': 0},
#    {'head': 'Christchurch',
#     'relation': 'Linked to',
#     'tail': 'Dunedin',
#     'score': 0.8105871081352234,
#     'id': 'Christchurch-Linked to-Dunedin',
#     'rank': 11,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Public transport',
#     'score': 0.8093971014022827,
#     'id': 'New zealand-Has-Public transport',
#     'rank': 12,
#     'relevant': 0},
#    {'head': 'Wellington',
#     'relation': 'Has',
#     'tail': 'Comprehensive public transport networks',
#     'score': 0.8090918064117432,
#     'id': 'Wellington-Has-Comprehensive public transport networks',
#     'rank': 5,
#     'relevant': 1},
#    {'head': 'Christchurch',
#     'relation': 'Located in',
#     'tail': 'South island',
#     'score': 0.8076204061508179,
#     'id': 'Christchurch-Located in-South island',
#     'rank': 13,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Cities',
#     'score': 0.8396409749984741,
#     'id': 'New zealand-Has-Cities',
#     'rank': 14,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Characterized by',
#     'tail': 'Mix of services',
#     'score': 0.837095320224762,
#     'id': 'New zealand-Characterized by-Mix of services',
#     'rank': 15,
#     'relevant': 0},
#    {'head': 'Air new zealand',
#     'relation': 'Plays crucial role in',
#     'tail': "Connecting new zealand's remote regions with major urban centers",
#     'score': 0.8327395915985107,
#     'id': "Air new zealand-Plays crucial role in-Connecting new zealand's remote regions with major urban centers",
#     'rank': 16,
#     'relevant': 0},
#    {'head': 'Auckland',
#     'relation': 'Is',
#     'tail': 'Largest city in new zealand',
#     'score': 0.8325598239898682,
#     'id': 'Auckland-Is-Largest city in new zealand',
#     'rank': 17,
#     'relevant': 0},
#    {'head': 'Auckland',
#     'relation': 'Serves',
#     'tail': 'New zealand',
#     'score': 0.8321657776832581,
#     'id': 'Auckland-Serves-New zealand',
#     'rank': 18,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Urban centers',
#     'score': 0.8302180171012878,
#     'id': 'New zealand-Has-Urban centers',
#     'rank': 19,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Numerous islands',
#     'score': 0.828586995601654,
#     'id': 'New zealand-Has-Numerous islands',
#     'rank': 20,
#     'relevant': 0},
#    {'head': 'Wellington',
#     'relation': 'Has',
#     'tail': 'Metlink',
#     'score': 0.8530012369155884,
#     'id': 'Wellington-Has-Metlink',
#     'rank': 2,
#     'relevant': 1},
#    {'head': 'Wellington',
#     'relation': 'Has',
#     'tail': 'Metlink brand',
#     'score': 0.8522277474403381,
#     'id': 'Wellington-Has-Metlink brand',
#     'rank': 3,
#     'relevant': 1},
#    {'head': 'Wellington',
#     'relation': 'Is',
#     'tail': 'Capital city of new zealand',
#     'score': 0.8464573621749878,
#     'id': 'Wellington-Is-Capital city of new zealand',
#     'rank': 1,
#     'relevant': 1},
#    {'head': 'Wellington',
#     'relation': 'Metlink brand',
#     'tail': 'Serves as the umbrella for its operations',
#     'score': 0.8272332549095154,
#     'id': 'Wellington-Metlink brand-Serves as the umbrella for its operations',
#     'rank': 4,
#     'relevant': 1},
#    {'head': 'Wellington',
#     'relation': 'Connected to',
#     'tail': 'Other major urban centers',
#     'score': 0.8139540553092957,
#     'id': 'Wellington-Connected to-Other major urban centers',
#     'rank': 6,
#     'relevant': 0},
#    {'head': 'Wellington northern corridor',
#     'relation': 'Connects',
#     'tail': 'Northern regions of the north island',
#     'score': 0.812394917011261,
#     'id': 'Wellington northern corridor-Connects-Northern regions of the north island',
#     'rank': 7,
#     'relevant': 0},
#    {'head': 'Wellington',
#     'relation': 'Has',
#     'tail': 'Bus network covering city and surrounding suburbs',
#     'score': 0.810408890247345,
#     'id': 'Wellington-Has-Bus network covering city and surrounding suburbs',
#     'rank': 8,
#     'relevant': 0},
#    {'head': 'Auckland',
#     'relation': 'Has',
#     'tail': 'City rail link',
#     'score': 0.8262525200843811,
#     'id': 'Auckland-Has-City rail link',
#     'rank': 21,
#     'relevant': 0},
#    {'head': 'Auckland',
#     'relation': 'Has',
#     'tail': 'Bus network with extensive coverage',
#     'score': 0.825740396976471,
#     'id': 'Auckland-Has-Bus network with extensive coverage',
#     'rank': 22,
#     'relevant': 0},
#    {'head': 'Auckland',
#     'relation': 'Connected to',
#     'tail': 'Surrounding suburbs and regions',
#     'score': 0.8228137493133545,
#     'id': 'Auckland-Connected to-Surrounding suburbs and regions',
#     'rank': 23,
#     'relevant': 0},
#    {'head': 'Auckland',
#     'relation': 'Is',
#     'tail': 'Major transport hub',
#     'score': 0.8225505352020264,
#     'id': 'Auckland-Is-Major transport hub',
#     'rank': 24,
#     'relevant': 0}]},
#  {'question': 'What year did the initiative that aims to achieve a significant reduction in road deaths and serious injuries by promoting a "Safe System" approach to road safety, known as "Road to Zero," launch in New Zealand?',
#   'triplets': [{'head': 'Road to zero',
#     'relation': 'Aims to reduce',
#     'tail': 'Road fatalities',
#     'score': 0.9006589651107788,
#     'id': 'Road to zero-Aims to reduce-Road fatalities',
#     'rank': 8,
#     'relevant': 0},
#    {'head': 'Road to zero',
#     'relation': 'Aims to reduce',
#     'tail': 'Serious injuries',
#     'score': 0.8969175219535828,
#     'id': 'Road to zero-Aims to reduce-Serious injuries',
#     'rank': 9,
#     'relevant': 0},
#    {'head': 'Road to zero',
#     'relation': 'Aim',
#     'tail': 'Reduce road fatalities and serious injuries to zero by',
#     'score': 2050.0,
#     'id': 'Road to zero-Aim-Reduce road fatalities and serious injuries to zero by',
#     'rank': 10,
#     'relevant': 0},
#    {'head': 'Road to zero',
#     'relation': 'Emphasizes',
#     'tail': 'Importance of vehicle safety',
#     'score': 0.8715617656707764,
#     'id': 'Road to zero-Emphasizes-Importance of vehicle safety',
#     'rank': 11,
#     'relevant': 0},
#    {'head': 'Road to zero',
#     'relation': 'Reflects',
#     'tail': 'Commitment to creating safe transport system',
#     'score': 0.8692113161087036,
#     'id': 'Road to zero-Reflects-Commitment to creating safe transport system',
#     'rank': 12,
#     'relevant': 0},
#    {'head': 'Road to zero',
#     'relation': 'Emphasizes',
#     'tail': 'Road infrastructure improvements',
#     'score': 0.8473979830741882,
#     'id': 'Road to zero-Emphasizes-Road infrastructure improvements',
#     'rank': 13,
#     'relevant': 0},
#    {'head': 'Road to zero strategy',
#     'relation': 'Aims',
#     'tail': 'Eliminate road deaths and serious injuries',
#     'score': 0.900111198425293,
#     'id': 'Road to zero strategy-Aims-Eliminate road deaths and serious injuries',
#     'rank': 14,
#     'relevant': 0},
#    {'head': 'Road to zero strategy',
#     'relation': 'Aims to',
#     'tail': 'Eliminate road fatalities and serious injuries by',
#     'score': 2050.0,
#     'id': 'Road to zero strategy-Aims to-Eliminate road fatalities and serious injuries by',
#     'rank': 15,
#     'relevant': 0},
#    {'head': 'Road to zero strategy',
#     'relation': 'Sets goal',
#     'tail': 'Reducing road deaths and serious injuries to zero by',
#     'score': 2050.0,
#     'id': 'Road to zero strategy-Sets goal-Reducing road deaths and serious injuries to zero by',
#     'rank': 16,
#     'relevant': 0},
#    {'head': 'Road to zero strategy',
#     'relation': 'Aligns with',
#     'tail': "New zealand's commitment to reducing greenhouse gas emissions",
#     'score': 0.8694576025009155,
#     'id': "Road to zero strategy-Aligns with-New zealand's commitment to reducing greenhouse gas emissions",
#     'rank': 17,
#     'relevant': 0},
#    {'head': 'Road safety strategy',
#     'relation': 'Launched',
#     'tail': '2019',
#     'score': 0.8618295192718506,
#     'id': 'Road safety strategy-Launched-2019',
#     'rank': 2,
#     'relevant': 1},
#    {'head': 'Road to zero strategy',
#     'relation': 'Launched',
#     'tail': '2019',
#     'score': 0.8572276830673218,
#     'id': 'Road to zero strategy-Launched-2019',
#     'rank': 1,
#     'relevant': 1},
#    {'head': 'Road to zero strategy',
#     'relation': 'Aligns with',
#     'tail': "Global best practices and united nations' sustainable development goals",
#     'score': 0.8380827903747559,
#     'id': "Road to zero strategy-Aligns with-Global best practices and united nations' sustainable development goals",
#     'rank': 18,
#     'relevant': 0},
#    {'head': 'Safer journeys strategy',
#     'relation': 'Marked',
#     'tail': "Significant shift in new zealand's approach to road safety",
#     'score': 0.8818174004554749,
#     'id': "Safer journeys strategy-Marked-Significant shift in new zealand's approach to road safety",
#     'rank': 19,
#     'relevant': 0},
#    {'head': 'Safer journeys strategy',
#     'relation': 'Focused on',
#     'tail': 'Safer road use',
#     'score': 0.854165256023407,
#     'id': 'Safer journeys strategy-Focused on-Safer road use',
#     'rank': 20,
#     'relevant': 0},
#    {'head': 'Safer journeys strategy',
#     'relation': 'Focused on',
#     'tail': 'Safer roads and roadsides',
#     'score': 0.852825939655304,
#     'id': 'Safer journeys strategy-Focused on-Safer roads and roadsides',
#     'rank': 21,
#     'relevant': 0},
#    {'head': 'Safer journeys strategy',
#     'relation': 'Focused on',
#     'tail': 'Safer vehicles',
#     'score': 0.8389161825180054,
#     'id': 'Safer journeys strategy-Focused on-Safer vehicles',
#     'rank': 22,
#     'relevant': 0},
#    {'head': 'Road transport safety',
#     'relation': 'Focus on',
#     'tail': 'Safer vehicles',
#     'score': 0.8302736282348633,
#     'id': 'Road transport safety-Focus on-Safer vehicles',
#     'rank': 23,
#     'relevant': 0},
#    {'head': 'Safer journeys strategy',
#     'relation': 'Focused on',
#     'tail': 'Safer speeds',
#     'score': 0.8276400566101074,
#     'id': 'Safer journeys strategy-Focused on-Safer speeds',
#     'rank': 24,
#     'relevant': 0},
#    {'head': 'Safer journeys strategy',
#     'relation': 'Focused on',
#     'tail': 'Four key areas',
#     'score': 0.8172357082366943,
#     'id': 'Safer journeys strategy-Focused on-Four key areas',
#     'rank': 25,
#     'relevant': 0},
#    {'head': 'Road to zero',
#     'relation': 'Aims',
#     'tail': 'Achieve vision of zero deaths and serious injuries',
#     'score': 0.902812123298645,
#     'id': 'Road to zero-Aims-Achieve vision of zero deaths and serious injuries',
#     'rank': 26,
#     'relevant': 0}]},
#  {'question': 'In what year did the Onehunga Line get reintroduced, enhancing the connection between the two locations connected by the first railway line constructed in New Zealand in 1873?',
#   'triplets': [{'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Developing rail network',
#     'score': 0.8471730947494507,
#     'id': 'New zealand-Has-Developing rail network',
#     'rank': 10,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Railways',
#     'score': 0.8412001132965088,
#     'id': 'New zealand-Has-Railways',
#     'rank': 11,
#     'relevant': 0},
#    {'head': 'Auckland',
#     'relation': 'Has',
#     'tail': 'Rail network with several lines',
#     'score': 0.8382218480110168,
#     'id': 'Auckland-Has-Rail network with several lines',
#     'rank': 9,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Composed of',
#     'tail': 'Rail networks',
#     'score': 0.8351947069168091,
#     'id': 'New zealand-Composed of-Rail networks',
#     'rank': 12,
#     'relevant': 0},
#    {'head': 'Auckland',
#     'relation': 'Has',
#     'tail': 'Rail network',
#     'score': 0.8333912491798401,
#     'id': 'Auckland-Has-Rail network',
#     'rank': 8,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Rail transport',
#     'score': 0.8331774473190308,
#     'id': 'New zealand-Has-Rail transport',
#     'rank': 13,
#     'relevant': 0},
#    {'head': 'Onehunga line',
#     'relation': 'Connects',
#     'tail': 'Onehunga to the wider auckland rail network',
#     'score': 0.8747345805168152,
#     'id': 'Onehunga line-Connects-Onehunga to the wider auckland rail network',
#     'rank': 3,
#     'relevant': 1},
#    {'head': 'Onehunga line',
#     'relation': 'Has',
#     'tail': 'Been instrumental in promoting public transport use',
#     'score': 0.8333762288093567,
#     'id': 'Onehunga line-Has-Been instrumental in promoting public transport use',
#     'rank': 14,
#     'relevant': 0},
#    {'head': 'Onehunga line',
#     'relation': 'Has',
#     'tail': 'Been instrumental in alleviating road congestion',
#     'score': 0.8332298994064331,
#     'id': 'Onehunga line-Has-Been instrumental in alleviating road congestion',
#     'rank': 15,
#     'relevant': 0},
#    {'head': 'Onehunga line',
#     'relation': 'Has',
#     'tail': 'Been instrumental in reducing travel times for commuters',
#     'score': 0.82525634765625,
#     'id': 'Onehunga line-Has-Been instrumental in reducing travel times for commuters',
#     'rank': 16,
#     'relevant': 0},
#    {'head': 'Railway line',
#     'relation': 'Opened',
#     'tail': '1873',
#     'score': 0.8641853332519531,
#     'id': 'Railway line-Opened-1873',
#     'rank': 2,
#     'relevant': 1},
#    {'head': 'New zealand',
#     'relation': 'Had',
#     'tail': 'First railway line between auckland and onehunga in',
#     'score': 1873.0,
#     'id': 'New zealand-Had-First railway line between auckland and onehunga in',
#     'rank': 1,
#     'relevant': 1}]},
#  {'question': "What major arterial route enhances accessibility between Auckland and Onehunga, particularly for travel to one of the major airports in New Zealand's transport infrastructure as of 2023?",
#   'triplets': [{'head': 'Auckland airport',
#     'relation': 'Is',
#     'tail': 'Undergoing significant expansion',
#     'score': 0.867223858833313,
#     'id': 'Auckland airport-Is-Undergoing significant expansion',
#     'rank': 13,
#     'relevant': 0},
#    {'head': 'Auckland airport',
#     'relation': 'Plays',
#     'tail': "Crucial role in new zealand's transport infrastructure",
#     'score': 0.8630920648574829,
#     'id': "Auckland airport-Plays-Crucial role in new zealand's transport infrastructure",
#     'rank': 14,
#     'relevant': 0},
#    {'head': 'Auckland airport',
#     'relation': 'Has',
#     'tail': 'Undergone significant expansion and modernization',
#     'score': 0.8628732562065125,
#     'id': 'Auckland airport-Has-Undergone significant expansion and modernization',
#     'rank': 15,
#     'relevant': 0},
#    {'head': 'Auckland airport',
#     'relation': 'Well-connected',
#     'tail': 'Wider transport network of new zealand',
#     'score': 0.8628103733062744,
#     'id': 'Auckland airport-Well-connected-Wider transport network of new zealand',
#     'rank': 16,
#     'relevant': 0},
#    {'head': 'Auckland airport',
#     'relation': 'Equipped with',
#     'tail': 'Modern amenities',
#     'score': 0.8599750995635986,
#     'id': 'Auckland airport-Equipped with-Modern amenities',
#     'rank': 17,
#     'relevant': 0},
#    {'head': 'Auckland',
#     'relation': 'Has',
#     'tail': 'International airport',
#     'score': 0.8586162328720093,
#     'id': 'Auckland-Has-International airport',
#     'rank': 18,
#     'relevant': 0},
#    {'head': 'State highway 20',
#     'relation': 'Facilitates',
#     'tail': 'Access to auckland airport and other regions of the north island',
#     'score': 0.8455373048782349,
#     'id': 'State highway 20-Facilitates-Access to auckland airport and other regions of the north island',
#     'rank': 1,
#     'relevant': 1},
#    {'head': 'Auckland western ring route',
#     'relation': 'Key component',
#     'tail': "Auckland's broader transport strategy",
#     'score': 0.834848165512085,
#     'id': "Auckland western ring route-Key component-Auckland's broader transport strategy",
#     'rank': 2,
#     'relevant': 1},
#    {'head': 'Auckland western ring route',
#     'relation': 'Is',
#     'tail': 'Significant transport corridor',
#     'score': 0.8333609104156494,
#     'id': 'Auckland western ring route-Is-Significant transport corridor',
#     'rank': 3,
#     'relevant': 1},
#    {'head': 'Auckland western ring route',
#     'relation': 'Anticipates',
#     'tail': 'Improved public transport links',
#     'score': 0.830819308757782,
#     'id': 'Auckland western ring route-Anticipates-Improved public transport links',
#     'rank': 7,
#     'relevant': 0},
#    {'head': 'Auckland western ring route',
#     'relation': 'Supports',
#     'tail': 'Urban transport',
#     'score': 0.8286157846450806,
#     'id': 'Auckland western ring route-Supports-Urban transport',
#     'rank': 6,
#     'relevant': 0},
#    {'head': 'Auckland western ring route',
#     'relation': 'Provides',
#     'tail': 'More efficient transport option',
#     'score': 0.826379120349884,
#     'id': 'Auckland western ring route-Provides-More efficient transport option',
#     'rank': 4,
#     'relevant': 1},
#    {'head': 'Auckland western ring route',
#     'relation': 'Anticipates',
#     'tail': 'Further enhancements',
#     'score': 0.8248204588890076,
#     'id': 'Auckland western ring route-Anticipates-Further enhancements',
#     'rank': 8,
#     'relevant': 0},
#    {'head': 'Onehunga',
#     'relation': 'Is',
#     'tail': 'Served by the auckland public transport network',
#     'score': 0.8893288373947144,
#     'id': 'Onehunga-Is-Served by the auckland public transport network',
#     'rank': 19,
#     'relevant': 0},
#    {'head': 'Onehunga',
#     'relation': 'Is',
#     'tail': 'Strategically located near major arterial routes',
#     'score': 0.8761754631996155,
#     'id': 'Onehunga-Is-Strategically located near major arterial routes',
#     'rank': 5,
#     'relevant': 1},
#    {'head': 'Onehunga',
#     'relation': 'Has',
#     'tail': 'Multiple routes linking it to surrounding suburbs and the auckland cbd',
#     'score': 0.867659866809845,
#     'id': 'Onehunga-Has-Multiple routes linking it to surrounding suburbs and the auckland cbd',
#     'rank': 9,
#     'relevant': 0},
#    {'head': 'Onehunga',
#     'relation': 'Has',
#     'tail': 'Integration of bus and rail services',
#     'score': 0.8547335267066956,
#     'id': 'Onehunga-Has-Integration of bus and rail services',
#     'rank': 10,
#     'relevant': 0},
#    {'head': 'Onehunga',
#     'relation': 'Is',
#     'tail': 'Suburb located approximately',
#     'score': 12.0,
#     'id': 'Onehunga-Is-Suburb located approximately',
#     'rank': 20,
#     'relevant': 0},
#    {'head': 'Onehunga',
#     'relation': 'Has',
#     'tail': 'Encouraged more sustainable travel options',
#     'score': 0.8419249057769775,
#     'id': 'Onehunga-Has-Encouraged more sustainable travel options',
#     'rank': 11,
#     'relevant': 0},
#    {'head': 'Onehunga',
#     'relation': 'Has',
#     'tail': 'Seen significant improvements in cycling and walking infrastructure',
#     'score': 0.8407048583030701,
#     'id': 'Onehunga-Has-Seen significant improvements in cycling and walking infrastructure',
#     'rank': 12,
#     'relevant': 0},
#    {'head': 'Auckland airport',
#     'relation': 'Key player',
#     'tail': 'Future of transport in new zealand',
#     'score': 0.8787257671356201,
#     'id': 'Auckland airport-Key player-Future of transport in new zealand',
#     'rank': 21,
#     'relevant': 0}]},
#  {'question': 'Which city is linked to the urban area in New Zealand that has experienced significant investment in public transport infrastructure alongside Auckland and Wellington by State Highway 1 to the north?',
#   'triplets': [{'head': 'Wellington northern corridor',
#     'relation': 'Links with',
#     'tail': 'State highway',
#     'score': 1.0,
#     'id': 'Wellington northern corridor-Links with-State highway',
#     'rank': 5,
#     'relevant': 1},
#    {'head': 'Wellington',
#     'relation': 'Focused on',
#     'tail': 'Enhancing its transport infrastructure',
#     'score': 0.8669570088386536,
#     'id': 'Wellington-Focused on-Enhancing its transport infrastructure',
#     'rank': 11,
#     'relevant': 0},
#    {'head': 'Wellington',
#     'relation': 'Relies heavily on',
#     'tail': 'Public transport',
#     'score': 0.8667759895324707,
#     'id': 'Wellington-Relies heavily on-Public transport',
#     'rank': 12,
#     'relevant': 0},
#    {'head': 'Wellington',
#     'relation': 'Has',
#     'tail': 'Comprehensive public transport networks',
#     'score': 0.8653692603111267,
#     'id': 'Wellington-Has-Comprehensive public transport networks',
#     'rank': 13,
#     'relevant': 0},
#    {'head': 'Wellington',
#     'relation': 'Serves as',
#     'tail': 'Vital transport hub',
#     'score': 0.8653260469436646,
#     'id': 'Wellington-Serves as-Vital transport hub',
#     'rank': 14,
#     'relevant': 0},
#    {'head': 'Wellington',
#     'relation': 'Has',
#     'tail': 'Public transport services',
#     'score': 0.863973081111908,
#     'id': 'Wellington-Has-Public transport services',
#     'rank': 15,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Transport infrastructure investment',
#     'score': 0.9011587500572205,
#     'id': 'New zealand-Has-Transport infrastructure investment',
#     'rank': 16,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Urban-centric transport system',
#     'score': 0.8887932300567627,
#     'id': 'New zealand-Has-Urban-centric transport system',
#     'rank': 17,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Transport infrastructure',
#     'score': 0.8873845338821411,
#     'id': 'New zealand-Has-Transport infrastructure',
#     'rank': 18,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Transport infrastructure development',
#     'score': 0.887237548828125,
#     'id': 'New zealand-Has-Transport infrastructure development',
#     'rank': 19,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Public transport development',
#     'score': 0.8839156627655029,
#     'id': 'New zealand-Has-Public transport development',
#     'rank': 20,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Transport projects',
#     'score': 0.8823251724243164,
#     'id': 'New zealand-Has-Transport projects',
#     'rank': 21,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Transport infrastructure funding',
#     'score': 0.881171464920044,
#     'id': 'New zealand-Has-Transport infrastructure funding',
#     'rank': 22,
#     'relevant': 0},
#    {'head': 'Road infrastructure projects',
#     'relation': 'Play crucial role in',
#     'tail': "New zealand's transport network",
#     'score': 0.8776376843452454,
#     'id': "Road infrastructure projects-Play crucial role in-New zealand's transport network",
#     'rank': 23,
#     'relevant': 0},
#    {'head': 'Auckland transport alignment project',
#     'relation': 'Focuses on',
#     'tail': 'Aligning transport investments',
#     'score': 0.8630427718162537,
#     'id': 'Auckland transport alignment project-Focuses on-Aligning transport investments',
#     'rank': 24,
#     'relevant': 0},
#    {'head': 'Auckland transport alignment project',
#     'relation': 'Focuses',
#     'tail': 'On enhancing road infrastructure',
#     'score': 0.8624625205993652,
#     'id': 'Auckland transport alignment project-Focuses-On enhancing road infrastructure',
#     'rank': 25,
#     'relevant': 0},
#    {'head': 'Auckland transport alignment project',
#     'relation': 'Focuses',
#     'tail': 'On improving public transport',
#     'score': 0.8576145172119141,
#     'id': 'Auckland transport alignment project-Focuses-On improving public transport',
#     'rank': 26,
#     'relevant': 0},
#    {'head': 'Auckland transport alignment project',
#     'relation': 'Focuses on',
#     'tail': 'Development of comprehensive transport network',
#     'score': 0.8551918864250183,
#     'id': 'Auckland transport alignment project-Focuses on-Development of comprehensive transport network',
#     'rank': 27,
#     'relevant': 0},
#    {'head': 'Auckland transport alignment project',
#     'relation': 'Encompasses',
#     'tail': 'Range of projects',
#     'score': 0.8525838255882263,
#     'id': 'Auckland transport alignment project-Encompasses-Range of projects',
#     'rank': 28,
#     'relevant': 0},
#    {'head': 'Auckland transport alignment project',
#     'relation': 'Focuses on',
#     'tail': 'Addressing transport challenges in auckland',
#     'score': 0.8512289524078369,
#     'id': 'Auckland transport alignment project-Focuses on-Addressing transport challenges in auckland',
#     'rank': 29,
#     'relevant': 0},
#    {'head': 'Auckland transport alignment project',
#     'relation': 'Is',
#     'tail': 'Strategic initiative',
#     'score': 0.8462114334106445,
#     'id': 'Auckland transport alignment project-Is-Strategic initiative',
#     'rank': 30,
#     'relevant': 0}]},
#  {'question': 'In what year did the project that aims to develop a high-quality public transport corridor in Wellington begin?',
#   'triplets': [{'head': 'Wellington public transport plan',
#     'relation': 'Initiated in response to',
#     'tail': 'Increasing urbanization',
#     'score': 0.882498025894165,
#     'id': 'Wellington public transport plan-Initiated in response to-Increasing urbanization',
#     'rank': 1,
#     'relevant': 0},
#    {'head': 'Wellington public transport plan',
#     'relation': 'Represents',
#     'tail': 'Significant step towards creating sustainable and user-friendly public transport system',
#     'score': 0.8819208145141602,
#     'id': 'Wellington public transport plan-Represents-Significant step towards creating sustainable and user-friendly public transport system',
#     'rank': 2,
#     'relevant': 0},
#    {'head': 'Wellington public transport plan',
#     'relation': 'Outlines',
#     'tail': 'Comprehensive approach',
#     'score': 0.8812780380249023,
#     'id': 'Wellington public transport plan-Outlines-Comprehensive approach',
#     'rank': 3,
#     'relevant': 0},
#    {'head': 'Wellington public transport plan',
#     'relation': 'Aimed at',
#     'tail': 'Promoting sustainability',
#     'score': 0.880703330039978,
#     'id': 'Wellington public transport plan-Aimed at-Promoting sustainability',
#     'rank': 4,
#     'relevant': 0},
#    {'head': 'Wellington public transport plan',
#     'relation': 'Is',
#     'tail': 'Strategic framework',
#     'score': 0.8795210123062134,
#     'id': 'Wellington public transport plan-Is-Strategic framework',
#     'rank': 5,
#     'relevant': 0},
#    {'head': 'Wellington regional public transport plan',
#     'relation': 'Is',
#     'tail': 'Strategic framework',
#     'score': 0.877652645111084,
#     'id': 'Wellington regional public transport plan-Is-Strategic framework',
#     'rank': 6,
#     'relevant': 0},
#    {'head': 'Wellington northern corridor',
#     'relation': 'Aims to',
#     'tail': "Meet the evolving needs of new zealand's transport system",
#     'score': 0.892913281917572,
#     'id': "Wellington northern corridor-Aims to-Meet the evolving needs of new zealand's transport system",
#     'rank': 7,
#     'relevant': 0},
#    {'head': 'Wellington',
#     'relation': 'Has',
#     'tail': 'Comprehensive public transport networks',
#     'score': 0.8759836554527283,
#     'id': 'Wellington-Has-Comprehensive public transport networks',
#     'rank': 8,
#     'relevant': 0},
#    {'head': 'Wellington',
#     'relation': 'Has',
#     'tail': 'Public transport services',
#     'score': 0.8745676875114441,
#     'id': 'Wellington-Has-Public transport services',
#     'rank': 9,
#     'relevant': 0},
#    {'head': 'Wellington',
#     'relation': 'Has',
#     'tail': 'Well-integrated transport system',
#     'score': 0.8744156956672668,
#     'id': 'Wellington-Has-Well-integrated transport system',
#     'rank': 10,
#     'relevant': 0},
#    {'head': 'Wellington',
#     'relation': 'Focused on',
#     'tail': 'Enhancing its transport infrastructure',
#     'score': 0.8736780285835266,
#     'id': 'Wellington-Focused on-Enhancing its transport infrastructure',
#     'rank': 11,
#     'relevant': 0},
#    {'head': 'Sustainable urban transport',
#     'relation': 'Key component',
#     'tail': 'Wellington',
#     'score': 0.8695807456970215,
#     'id': 'Sustainable urban transport-Key component-Wellington',
#     'rank': 12,
#     'relevant': 0},
#    {'head': 'Wellington northern corridor',
#     'relation': 'Is',
#     'tail': 'Key transport route',
#     'score': 0.8695229291915894,
#     'id': 'Wellington northern corridor-Is-Key transport route',
#     'rank': 13,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Transport projects',
#     'score': 0.8684442043304443,
#     'id': 'New zealand-Has-Transport projects',
#     'rank': 14,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Public transport development',
#     'score': 0.8676924109458923,
#     'id': 'New zealand-Has-Public transport development',
#     'rank': 15,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Public transport integration',
#     'score': 0.8607476353645325,
#     'id': 'New zealand-Has-Public transport integration',
#     'rank': 16,
#     'relevant': 0},
#    {'head': 'Auckland',
#     'relation': 'Has',
#     'tail': 'Transport projects',
#     'score': 0.8602539300918579,
#     'id': 'Auckland-Has-Transport projects',
#     'rank': 17,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Transport infrastructure development',
#     'score': 0.8599637746810913,
#     'id': 'New zealand-Has-Transport infrastructure development',
#     'rank': 18,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Public transport network planning',
#     'score': 0.8597931861877441,
#     'id': 'New zealand-Has-Public transport network planning',
#     'rank': 19,
#     'relevant': 0},
#    {'head': 'Wellington',
#     'relation': 'Has',
#     'tail': 'Initiatives',
#     'score': 0.8562711477279663,
#     'id': 'Wellington-Has-Initiatives',
#     'rank': 20,
#     'relevant': 0}]},
#  {'question': 'Which line does the major transport infrastructure project in New Zealand, which aims to improve rail connectivity and reduce congestion in Auckland, connect to at Britomart Station?',
#   'triplets': [{'head': 'Auckland transport alignment project',
#     'relation': 'Aims to',
#     'tail': 'Reduce congestion',
#     'score': 0.8695691227912903,
#     'id': 'Auckland transport alignment project-Aims to-Reduce congestion',
#     'rank': 8,
#     'relevant': 0},
#    {'head': 'Auckland transport alignment project',
#     'relation': 'Focuses',
#     'tail': 'On enhancing road infrastructure',
#     'score': 0.8682559728622437,
#     'id': 'Auckland transport alignment project-Focuses-On enhancing road infrastructure',
#     'rank': 9,
#     'relevant': 0},
#    {'head': 'Auckland transport alignment project',
#     'relation': 'Aims to',
#     'tail': 'Create unified transport network',
#     'score': 0.8629523515701294,
#     'id': 'Auckland transport alignment project-Aims to-Create unified transport network',
#     'rank': 10,
#     'relevant': 0},
#    {'head': 'Auckland transport alignment project',
#     'relation': 'Aims to',
#     'tail': 'Improve efficiency and effectiveness of transport system',
#     'score': 0.8603688478469849,
# ...
#     'relation': 'Is',
#     'tail': 'Second-busiest airport in new zealand',
#     'score': 0.8753463625907898,
#     'id': 'Christchurch international airport-Is-Second-busiest airport in new zealand',
#     'rank': 1,
#     'relevant': 1},
#    {'head': 'Christchurch',
#     'relation': 'Has',
#     'tail': 'Second-busiest airport in new zealand',
#     'score': 0.872168779373169,
#     'id': 'Christchurch-Has-Second-busiest airport in new zealand',
#     'rank': 2,
#     'relevant': 1},
#    {'head': 'Auckland',
#     'relation': 'Has',
#     'tail': 'Public transport system',
#     'score': 0.8715581893920898,
#     'id': 'Auckland-Has-Public transport system',
#     'rank': 15,
#     'relevant': 0},
#    {'head': 'Auckland',
#     'relation': 'Has',
#     'tail': 'Comprehensive public transport networks',
#     'score': 0.8670401573181152,
#     'id': 'Auckland-Has-Comprehensive public transport networks',
#     'rank': 16,
#     'relevant': 0},
#    {'head': 'Christchurch international airport',
#     'relation': 'Is',
#     'tail': 'Second-busiest airport',
#     'score': 0.864715576171875,
#     'id': 'Christchurch international airport-Is-Second-busiest airport',
#     'rank': 14,
#     'relevant': 0},
#    {'head': 'Auckland',
#     'relation': 'Has',
#     'tail': 'Buses',
#     'score': 0.8631771802902222,
#     'id': 'Auckland-Has-Buses',
#     'rank': 17,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Public transport',
#     'score': 0.855236291885376,
#     'id': 'New zealand-Has-Public transport',
#     'rank': 18,
#     'relevant': 0}]},
#  {'question': 'Which country did the airline that initially operated trans-Tasman flights to in 1940 connect to for tourism and business travel, alongside major cities in New Zealand and Asia, alongside the urban area in New Zealand that has experienced significant investment in public transport infrastructure alongside Auckland and Wellington?',
#   'triplets': [{'head': 'Auckland airport',
#     'relation': 'Vital',
#     'tail': 'Hub for tourism and business travel',
#     'score': 0.8601557016372681,
#     'id': 'Auckland airport-Vital-Hub for tourism and business travel',
#     'rank': 2,
#     'relevant': 1},
#    {'head': 'Auckland airport',
#     'relation': 'Plays',
#     'tail': "Crucial role in new zealand's transport infrastructure",
#     'score': 0.859595000743866,
#     'id': "Auckland airport-Plays-Crucial role in new zealand's transport infrastructure",
#     'rank': 3,
#     'relevant': 1},
#    {'head': 'Auckland airport',
#     'relation': 'Supporting',
#     'tail': 'Local economy and tourism industry',
#     'score': 0.8570446968078613,
#     'id': 'Auckland airport-Supporting-Local economy and tourism industry',
#     'rank': 4,
#     'relevant': 1},
#    {'head': 'Auckland airport',
#     'relation': 'Connecting',
#     'tail': 'Country to the rest of the world',
#     'score': 0.8521264791488647,
#     'id': 'Auckland airport-Connecting-Country to the rest of the world',
#     'rank': 5,
#     'relevant': 1},
#    {'head': 'Auckland airport',
#     'relation': 'Facilitates',
#     'tail': 'Domestic and international travel',
#     'score': 0.8515406847000122,
#     'id': 'Auckland airport-Facilitates-Domestic and international travel',
#     'rank': 6,
#     'relevant': 1},
#    {'head': 'Auckland airport',
#     'relation': 'Serves',
#     'tail': 'Domestic and international flights',
#     'score': 0.851431667804718,
#     'id': 'Auckland airport-Serves-Domestic and international flights',
#     'rank': 7,
#     'relevant': 1},
#    {'head': 'Teal',
#     'relation': 'Initially operating',
#     'tail': 'Trans-tasman flights between new zealand and australia',
#     'score': 0.875971794128418,
#     'id': 'Teal-Initially operating-Trans-tasman flights between new zealand and australia',
#     'rank': 1,
#     'relevant': 1},
#    {'head': 'Air new zealand',
#     'relation': 'Operates',
#     'tail': 'Numerous routes connecting major cities and regional centers',
#     'score': 0.8753840923309326,
#     'id': 'Air new zealand-Operates-Numerous routes connecting major cities and regional centers',
#     'rank': 8,
#     'relevant': 1},
#    {'head': 'Air new zealand',
#     'relation': 'Established in',
#     'tail': '1940',
#     'score': 0.8750410079956055,
#     'id': 'Air new zealand-Established in-1940',
#     'rank': 9,
#     'relevant': 1},
#    {'head': 'Air new zealand',
#     'relation': 'Plays crucial role in',
#     'tail': "Connecting new zealand's remote regions with major urban centers",
#     'score': 0.8676568269729614,
#     'id': "Air new zealand-Plays crucial role in-Connecting new zealand's remote regions with major urban centers",
#     'rank': 10,
#     'relevant': 1},
#    {'head': 'Air new zealand',
#     'relation': 'Contributes significantly to',
#     'tail': "Country's economy and connectivity",
#     'score': 0.8641636371612549,
#     'id': "Air new zealand-Contributes significantly to-Country's economy and connectivity",
#     'rank': 11,
#     'relevant': 1},
#    {'head': 'Air new zealand',
#     'relation': 'Is',
#     'tail': 'Flagship airline of new zealand',
#     'score': 0.8531244993209839,
#     'id': 'Air new zealand-Is-Flagship airline of new zealand',
#     'rank': 12,
#     'relevant': 1},
#    {'head': 'Air new zealand',
#     'relation': 'Remains',
#     'tail': "Cornerstone of new zealand's transport infrastructure",
#     'score': 0.851710855960846,
#     'id': "Air new zealand-Remains-Cornerstone of new zealand's transport infrastructure",
#     'rank': 13,
#     'relevant': 1},
#    {'head': 'Wellington international airport',
#     'relation': 'Provides',
#     'tail': 'Domestic flights to major cities across new zealand',
#     'score': 0.8632847666740417,
#     'id': 'Wellington international airport-Provides-Domestic flights to major cities across new zealand',
#     'rank': 14,
#     'relevant': 1},
#    {'head': 'Wellington international airport',
#     'relation': 'Provides',
#     'tail': 'International flights to australia and the south pacific',
#     'score': 0.8583430051803589,
#     'id': 'Wellington international airport-Provides-International flights to australia and the south pacific',
#     'rank': 15,
#     'relevant': 1},
#    {'head': 'Wellington international airport',
#     'relation': 'Known for',
#     'tail': 'Unique location',
#     'score': 0.8400535583496094,
#     'id': 'Wellington international airport-Known for-Unique location',
#     'rank': 16,
#     'relevant': 0},
#    {'head': 'Wellington international airport',
#     'relation': 'Is',
#     'tail': 'Primary airport serving the city',
#     'score': 0.8377350568771362,
#     'id': 'Wellington international airport-Is-Primary airport serving the city',
#     'rank': 17,
#     'relevant': 0},
#    {'head': 'Wellington international airport',
#     'relation': 'Situated on',
#     'tail': 'Narrow strip of land between the hills and the sea',
#     'score': 0.8257229924201965,
#     'id': 'Wellington international airport-Situated on-Narrow strip of land between the hills and the sea',
#     'rank': 18,
#     'relevant': 0},
#    {'head': 'Wellington international airport',
#     'relation': 'Located',
#     'tail': 'Just',
#     'score': 8.0,
#     'id': 'Wellington international airport-Located-Just',
#     'rank': 19,
#     'relevant': 0},
#    {'head': 'Wellington international airport',
#     'relation': 'Presents challenges for',
#     'tail': 'Both takeoff and landing',
#     'score': 0.8080945014953613,
#     'id': 'Wellington international airport-Presents challenges for-Both takeoff and landing',
#     'rank': 20,
#     'relevant': 0},
#    {'head': 'Port of wellington',
#     'relation': 'Facilitates',
#     'tail': 'Both passenger and freight transport across the cook strait',
#     'score': 0.8303159475326538,
#     'id': 'Port of wellington-Facilitates-Both passenger and freight transport across the cook strait',
#     'rank': 21,
#     'relevant': 0},
#    {'head': 'Port of wellington',
#     'relation': 'Connects',
#     'tail': 'Wellington to the south island',
#     'score': 0.8179738521575928,
#     'id': 'Port of wellington-Connects-Wellington to the south island',
#     'rank': 22,
#     'relevant': 0},
#    {'head': 'Port of wellington',
#     'relation': 'Is',
#     'tail': 'One of the busiest ports in new zealand',
#     'score': 0.813212513923645,
#     'id': 'Port of wellington-Is-One of the busiest ports in new zealand',
#     'rank': 23,
#     'relevant': 0},
#    {'head': 'Port of wellington',
#     'relation': 'Serves as',
#     'tail': 'Departure point for ferries',
#     'score': 0.8077861070632935,
#     'id': 'Port of wellington-Serves as-Departure point for ferries',
#     'rank': 24,
#     'relevant': 0},
#    {'head': 'Port of wellington',
#     'relation': 'Handles',
#     'tail': 'Variety of cargo',
#     'score': 0.8069910407066345,
#     'id': 'Port of wellington-Handles-Variety of cargo',
#     'rank': 25,
#     'relevant': 0}]},
#  {'question': 'What significant engineering challenge associated with the key transport corridor critical for freight and passenger movement and running through the North Island, completed in the year the major railway line in New Zealand is being upgraded to enhance its capacity and efficiency for sustainable transport, is known for its unique spiral design?',
#   'triplets': [{'head': 'Austroads',
#     'relation': 'Plays',
#     'tail': 'Significant role in shaping transport infrastructure and policy in new zealand',
#     'score': 0.8465326428413391,
#     'id': 'Austroads-Plays-Significant role in shaping transport infrastructure and policy in new zealand',
#     'rank': 5,
#     'relevant': 0},
#    {'head': 'Austroads',
#     'relation': 'Collaborates with',
#     'tail': 'New zealand transport agency (nzta',
#     'score': 0.8093392848968506,
#     'id': 'Austroads-Collaborates with-New zealand transport agency (nzta',
#     'rank': 6,
#     'relevant': 0},
#    {'head': 'Austroads',
#     'relation': 'Is',
#     'tail': 'Collective of australian and new zealand road transport and traffic agencies',
#     'score': 0.7922015190124512,
#     'id': 'Austroads-Is-Collective of australian and new zealand road transport and traffic agencies',
#     'rank': 7,
#     'relevant': 0},
#    {'head': 'Austroads',
#     'relation': 'Conducts',
#     'tail': 'Extensive research and development projects',
#     'score': 0.7718237638473511,
#     'id': 'Austroads-Conducts-Extensive research and development projects',
#     'rank': 8,
#     'relevant': 0},
#    {'head': 'Austroads',
#     'relation': 'Engages in',
#     'tail': 'International collaborations to align initiatives with global best practices',
#     'score': 0.7564767003059387,
#     'id': 'Austroads-Engages in-International collaborations to align initiatives with global best practices',
#     'rank': 9,
#     'relevant': 0},
#    {'head': 'Austroads',
#     'relation': 'Founded in',
#     'tail': '1990',
#     'score': 0.7261661887168884,
#     'id': 'Austroads-Founded in-1990',
#     'rank': 10,
#     'relevant': 0},
#    {'head': 'New zealand government',
#     'relation': 'Supported',
#     'tail': 'Adoption of sustainable transport technologies',
#     'score': 0.8407054543495178,
#     'id': 'New zealand government-Supported-Adoption of sustainable transport technologies',
#     'rank': 11,
#     'relevant': 0},
#    {'head': 'New zealand government',
#     'relation': 'Improve',
#     'tail': 'Overall transport experience',
#     'score': 0.8402334451675415,
#     'id': 'New zealand government-Improve-Overall transport experience',
#     'rank': 12,
#     'relevant': 0},
#    {'head': 'Road safety education',
#     'relation': 'Is',
#     'tail': "Critical component of new zealand's transport strategy",
#     'score': 0.8351141214370728,
#     'id': "Road safety education-Is-Critical component of new zealand's transport strategy",
#     'rank': 13,
#     'relevant': 0},
#    {'head': 'Auckland transport',
#     'relation': 'Actively involved in',
#     'tail': 'Community engagement',
#     'score': 0.8343073129653931,
#     'id': 'Auckland transport-Actively involved in-Community engagement',
#     'rank': 14,
#     'relevant': 0},
#    {'head': 'Sustainable transport solutions',
#     'relation': 'Includes',
#     'tail': 'Cycling',
#     'score': 0.8279963731765747,
#     'id': 'Sustainable transport solutions-Includes-Cycling',
#     'rank': 15,
#     'relevant': 0},
#    {'head': 'New zealand government',
#     'relation': 'Prioritizes',
#     'tail': 'Transport research',
#     'score': 0.8272744417190552,
#     'id': 'New zealand government-Prioritizes-Transport research',
#     'rank': 16,
#     'relevant': 0},
#    {'head': 'Nzta',
#     'relation': 'Actively exploring',
#     'tail': 'Enhancing traffic management capabilities',
#     'score': 0.8268737196922302,
#     'id': 'Nzta-Actively exploring-Enhancing traffic management capabilities',
#     'rank': 17,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Transport planning',
#     'score': 0.8634418249130249,
#     'id': 'New zealand-Has-Transport planning',
#     'rank': 18,
#     'relevant': 0},
#    {'head': 'Auckland transport',
#     'relation': 'Remains',
#     'tail': 'Forefront of addressing challenges',
#     'score': 0.8586375117301941,
#     'id': 'Auckland transport-Remains-Forefront of addressing challenges',
#     'rank': 19,
#     'relevant': 0},
#    {'head': 'Auckland transport',
#     'relation': 'Implemented',
#     'tail': 'Cycling infrastructure projects',
#     'score': 0.8506833910942078,
#     'id': 'Auckland transport-Implemented-Cycling infrastructure projects',
#     'rank': 20,
#     'relevant': 0},
#    {'head': 'Auckland transport',
#     'relation': 'Focused on',
#     'tail': 'Promoting active transport modes',
#     'score': 0.8490039706230164,
#     'id': 'Auckland transport-Focused on-Promoting active transport modes',
#     'rank': 21,
#     'relevant': 0},
#    {'head': 'Auckland transport',
#     'relation': 'Committed to',
#     'tail': 'Providing sustainable transport options',
#     'score': 0.8488008379936218,
#     'id': 'Auckland transport-Committed to-Providing sustainable transport options',
#     'rank': 22,
#     'relevant': 0},
#    {'head': 'Auckland transport',
#     'relation': 'Plays',
#     'tail': 'Crucial role',
#     'score': 0.8472338914871216,
#     'id': 'Auckland transport-Plays-Crucial role',
#     'rank': 23,
#     'relevant': 0},
#    {'head': 'Auckland transport',
#     'relation': 'Remains',
#     'tail': 'Forefront of addressing opportunities',
#     'score': 0.8449376821517944,
#     'id': 'Auckland transport-Remains-Forefront of addressing opportunities',
#     'rank': 24,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Faces challenges',
#     'tail': 'The need for sustainable transport solutions',
#     'score': 0.8824827671051025,
#     'id': 'New zealand-Faces challenges-The need for sustainable transport solutions',
#     'rank': 25,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Faces',
#     'tail': 'Unique challenges in transportation',
#     'score': 0.8784781098365784,
#     'id': 'New zealand-Faces-Unique challenges in transportation',
#     'rank': 26,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Growing emphasis on sustainable transport solutions',
#     'score': 0.8751609921455383,
#     'id': 'New zealand-Has-Growing emphasis on sustainable transport solutions',
#     'rank': 27,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Sustainable transport initiatives',
#     'score': 0.8734918236732483,
#     'id': 'New zealand-Has-Sustainable transport initiatives',
#     'rank': 28,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Transport infrastructure development',
#     'score': 0.8722070455551147,
#     'id': 'New zealand-Has-Transport infrastructure development',
#     'rank': 29,
#     'relevant': 0},
#    {'head': 'Wellington northern corridor',
#     'relation': 'Accommodates',
#     'tail': 'Sustainable transport options',
#     'score': 0.8712188005447388,
#     'id': 'Wellington northern corridor-Accommodates-Sustainable transport options',
#     'rank': 1,
#     'relevant': 1},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Transport system innovation',
#     'score': 0.8709776997566223,
#     'id': 'New zealand-Has-Transport system innovation',
#     'rank': 30,
#     'relevant': 0}]})

# %%
clean_sorted_data_with_ranking
# Out:
# ({'question': 'Who manages the State Highway network in the country known for its critical approach to transport demand forecasting, utilizing statistical models and socio-economic indicators to predict future travel patterns?',
#   'triplets': [{'head': 'Resource management act 1991',
#     'relation': 'Plays',
#     'tail': 'Significant role in shaping transport infrastructure',
#     'score': 0.8373398184776306,
#     'id': 'Resource management act 1991-Plays-Significant role in shaping transport infrastructure',
#     'rank': 13,
#     'relevant': 0},
#    {'head': 'Resource management act 1991',
#     'relation': 'Recognizes',
#     'tail': "Transport as critical component of nation's infrastructure",
#     'score': 0.8328390717506409,
#     'id': "Resource management act 1991-Recognizes-Transport as critical component of nation's infrastructure",
#     'rank': 14,
#     'relevant': 0},
#    {'head': 'Resource management act 1991',
#     'relation': 'Subject',
#     'tail': 'Debate regarding effectiveness in addressing challenges of modern transport needs',
#     'score': 0.830618679523468,
#     'id': 'Resource management act 1991-Subject-Debate regarding effectiveness in addressing challenges of modern transport needs',
#     'rank': 15,
#     'relevant': 0},
#    {'head': 'Resource management act 1991',
#     'relation': 'Recognizes',
#     'tail': 'Transport as critical component',
#     'score': 0.8261200189590454,
#     'id': 'Resource management act 1991-Recognizes-Transport as critical component',
#     'rank': 16,
#     'relevant': 0},
#    {'head': 'Resource management act 1991',
#     'relation': 'Cornerstone',
#     'tail': "New zealand's approach to managing transport",
#     'score': 0.8220652937889099,
#     'id': "Resource management act 1991-Cornerstone-New zealand's approach to managing transport",
#     'rank': 17,
#     'relevant': 0},
#    {'head': 'Resource management act 1991',
#     'relation': 'Praised for',
#     'tail': 'Promoting integrated approach to transport planning',
#     'score': 0.8126389980316162,
#     'id': 'Resource management act 1991-Praised for-Promoting integrated approach to transport planning',
#     'rank': 18,
#     'relevant': 0},
#    {'head': 'Transport demand forecasting',
#     'relation': 'Involves',
#     'tail': 'Socio-economic indicators',
#     'score': 0.8820364475250244,
#     'id': 'Transport demand forecasting-Involves-Socio-economic indicators',
#     'rank': 6,
#     'relevant': 1},
#    {'head': 'Transport demand forecasting',
#     'relation': 'Is',
#     'tail': 'Critical aspect of transportation planning',
#     'score': 0.8725880980491638,
#     'id': 'Transport demand forecasting-Is-Critical aspect of transportation planning',
#     'rank': 9,
#     'relevant': 0},
#    {'head': 'Transport demand forecasting',
#     'relation': 'Involves',
#     'tail': 'Statistical models',
#     'score': 0.8614435791969299,
#     'id': 'Transport demand forecasting-Involves-Statistical models',
#     'rank': 7,
#     'relevant': 1},
#    {'head': 'Transport demand forecasting',
#     'relation': 'Estimates',
#     'tail': 'Future travel patterns',
#     'score': 0.8473142385482788,
#     'id': 'Transport demand forecasting-Estimates-Future travel patterns',
#     'rank': 8,
#     'relevant': 1},
#    {'head': 'Transport demand forecasting',
#     'relation': 'Involves',
#     'tail': 'Historical data',
#     'score': 0.841994047164917,
#     'id': 'Transport demand forecasting-Involves-Historical data',
#     'rank': 10,
#     'relevant': 0},
#    {'head': 'Transport demand forecasting',
#     'relation': 'Estimates',
#     'tail': 'Demand for various transport services',
#     'score': 0.8376253247261047,
#     'id': 'Transport demand forecasting-Estimates-Demand for various transport services',
#     'rank': 11,
#     'relevant': 0},
#    {'head': 'New zealand transport agency',
#     'relation': 'Is responsible for',
#     'tail': 'Managing state highway network',
#     'score': 0.8575925827026367,
#     'id': 'New zealand transport agency-Is responsible for-Managing state highway network',
#     'rank': 2,
#     'relevant': 1},
#    {'head': 'New zealand transport agency',
#     'relation': 'Manages',
#     'tail': 'State highway network',
#     'score': 0.8481019735336304,
#     'id': 'New zealand transport agency-Manages-State highway network',
#     'rank': 1,
#     'relevant': 1},
#    {'head': 'New zealand transport agency',
#     'relation': 'Is responsible for',
#     'tail': 'State highway network',
#     'score': 0.8457592725753784,
#     'id': 'New zealand transport agency-Is responsible for-State highway network',
#     'rank': 3,
#     'relevant': 1},
#    {'head': 'New zealand transport agency',
#     'relation': 'Plays',
#     'tail': 'Pivotal role in conducting forecasts',
#     'score': 0.8428968191146851,
#     'id': 'New zealand transport agency-Plays-Pivotal role in conducting forecasts',
#     'rank': 5,
#     'relevant': 1},
#    {'head': 'New zealand transport agency',
#     'relation': 'Tasked with',
#     'tail': 'Overseeing the maintenance and development of the state highway network',
#     'score': 0.841880738735199,
#     'id': 'New zealand transport agency-Tasked with-Overseeing the maintenance and development of the state highway network',
#     'rank': 4,
#     'relevant': 1},
#    {'head': 'Traffic management systems',
#     'relation': 'Governed by',
#     'tail': 'New zealand transport agency',
#     'score': 0.8415231704711914,
#     'id': 'Traffic management systems-Governed by-New zealand transport agency',
#     'rank': 12,
#     'relevant': 0},
#    {'head': 'Public transport network planning',
#     'relation': 'Is',
#     'tail': 'Critical aspect of urban and regional development',
#     'score': 0.8401920795440674,
#     'id': 'Public transport network planning-Is-Critical aspect of urban and regional development',
#     'rank': 19,
#     'relevant': 0}]},
#  {'question': 'What is the abbreviation commonly used for the initiative that the New Zealand government has launched to develop dedicated cycling infrastructure in New Zealand?',
#   'triplets': [{'head': 'North island',
#     'relation': 'Has',
#     'tail': 'Growing emphasis on sustainable transport options',
#     'score': 0.7718919515609741,
#     'id': 'North island-Has-Growing emphasis on sustainable transport options',
#     'rank': 49,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Invested in cycling infrastructure',
#     'score': 0.8836433291435242,
#     'id': 'New zealand-Has-Invested in cycling infrastructure',
#     'rank': 1,
#     'relevant': 1},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Government initiatives',
#     'score': 0.8774043917655945,
#     'id': 'New zealand-Has-Government initiatives',
#     'rank': 4,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Infrastructure development',
#     'score': 0.8766574859619141,
#     'id': 'New zealand-Has-Infrastructure development',
#     'rank': 5,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Faces',
#     'tail': 'Challenges in expanding its cycling infrastructure',
#     'score': 0.8755258321762085,
#     'id': 'New zealand-Faces-Challenges in expanding its cycling infrastructure',
#     'rank': 6,
#     'relevant': 0},
#    {'head': 'New zealand transport agency',
#     'relation': 'Plays',
#     'tail': 'A crucial role in funding and promoting cycling infrastructure projects',
#     'score': 0.8729434609413147,
#     'id': 'New zealand transport agency-Plays-A crucial role in funding and promoting cycling infrastructure projects',
#     'rank': 2,
#     'relevant': 1},
#    {'head': 'Auckland transport',
#     'relation': 'Implemented',
#     'tail': 'Cycling infrastructure projects',
#     'score': 0.8680109977722168,
#     'id': 'Auckland transport-Implemented-Cycling infrastructure projects',
#     'rank': 7,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Transport infrastructure development',
#     'score': 0.8679700493812561,
#     'id': 'New zealand-Has-Transport infrastructure development',
#     'rank': 8,
#     'relevant': 0},
#    {'head': 'Projects',
#     'relation': 'Include',
#     'tail': 'Development of cycling infrastructure',
#     'score': 0.8605217337608337,
#     'id': 'Projects-Include-Development of cycling infrastructure',
#     'rank': 3,
#     'relevant': 1},
#    {'head': 'State highway network',
#     'relation': 'Managed by',
#     'tail': 'Waka kotahi nz transport agency',
#     'score': 0.8284339904785156,
#     'id': 'State highway network-Managed by-Waka kotahi nz transport agency',
#     'rank': 9,
#     'relevant': 0},
#    {'head': 'Road construction standards',
#     'relation': 'Governed by',
#     'tail': 'Waka kotahi nz transport agency',
#     'score': 0.8276388645172119,
#     'id': 'Road construction standards-Governed by-Waka kotahi nz transport agency',
#     'rank': 10,
#     'relevant': 0},
#    {'head': 'National land transport programme',
#     'relation': 'Developed by',
#     'tail': 'Waka kotahi nz transport agency',
#     'score': 0.8236346244812012,
#     'id': 'National land transport programme-Developed by-Waka kotahi nz transport agency',
#     'rank': 11,
#     'relevant': 0},
#    {'head': 'Waka kotahi nz transport agency',
#     'relation': 'Advocates for',
#     'tail': 'Active transport modes',
#     'score': 0.8230215311050415,
#     'id': 'Waka kotahi nz transport agency-Advocates for-Active transport modes',
#     'rank': 12,
#     'relevant': 0},
#    {'head': 'Waka kotahi nz transport agency',
#     'relation': 'Involved in',
#     'tail': 'Enhancing resilience of infrastructure',
#     'score': 0.8224135637283325,
#     'id': 'Waka kotahi nz transport agency-Involved in-Enhancing resilience of infrastructure',
#     'rank': 13,
#     'relevant': 0},
#    {'head': 'Waka kotahi nz transport agency',
#     'relation': 'Develops',
#     'tail': 'Projects',
#     'score': 0.8177381157875061,
#     'id': 'Waka kotahi nz transport agency-Develops-Projects',
#     'rank': 14,
#     'relevant': 0},
#    {'head': 'New zealand electric vehicle programme',
#     'relation': 'Is',
#     'tail': 'Government initiative',
#     'score': 0.8730065226554871,
#     'id': 'New zealand electric vehicle programme-Is-Government initiative',
#     'rank': 15,
#     'relevant': 0},
#    {'head': 'National cycling policy',
#     'relation': 'Part of',
#     'tail': "New zealand's commitment",
#     'score': 0.862525224685669,
#     'id': "National cycling policy-Part of-New zealand's commitment",
#     'rank': 16,
#     'relevant': 0},
#    {'head': 'New zealand electric vehicle programme',
#     'relation': 'Part of',
#     'tail': "New zealand's commitment",
#     'score': 0.8326377868652344,
#     'id': "New zealand electric vehicle programme-Part of-New zealand's commitment",
#     'rank': 17,
#     'relevant': 0},
#    {'head': 'New zealand electric vehicle programme',
#     'relation': 'Objective',
#     'tail': 'Enhancing the availability of charging infrastructure',
#     'score': 0.8325090408325195,
#     'id': 'New zealand electric vehicle programme-Objective-Enhancing the availability of charging infrastructure',
#     'rank': 18,
#     'relevant': 0},
#    {'head': 'New zealand electric vehicle programme',
#     'relation': 'Objective',
#     'tail': 'Increasing the number of electric vehicles on new zealand roads',
#     'score': 0.8263366222381592,
#     'id': 'New zealand electric vehicle programme-Objective-Increasing the number of electric vehicles on new zealand roads',
#     'rank': 19,
#     'relevant': 0},
#    {'head': 'New zealand electric vehicle programme',
#     'relation': 'Goal',
#     'tail': 'Transitioning to a more sustainable transport system',
#     'score': 0.8161503076553345,
#     'id': 'New zealand electric vehicle programme-Goal-Transitioning to a more sustainable transport system',
#     'rank': 20,
#     'relevant': 0},
#    {'head': 'Auckland western ring route',
#     'relation': 'Reflects',
#     'tail': "New zealand's commitment",
#     'score': 0.8140708208084106,
#     'id': "Auckland western ring route-Reflects-New zealand's commitment",
#     'rank': 21,
#     'relevant': 0}]},
#  {'question': 'What suburb does Te Ara I Whiti (Lightpath) connect to from the city that is home to the Te Ara I Whiti (Lightpath) project, which has transformed underutilized spaces into vibrant cycling and pedestrian pathways, CBD?',
#   'triplets': [{'head': 'Onehunga',
#     'relation': 'Has',
#     'tail': 'Dedicated cycle lanes and pedestrian pathways',
#     'score': 0.779625415802002,
#     'id': 'Onehunga-Has-Dedicated cycle lanes and pedestrian pathways',
#     'rank': 10,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Promotes',
#     'tail': 'Active transport',
#     'score': 0.7649909257888794,
#     'id': 'New zealand-Promotes-Active transport',
#     'rank': 24,
#     'relevant': 0},
#    {'head': 'Onehunga',
#     'relation': 'Is',
#     'tail': 'Suburb located approximately',
#     'score': 12.0,
#     'id': 'Onehunga-Is-Suburb located approximately',
#     'rank': 14,
#     'relevant': 0},
#    {'head': 'Onehunga',
#     'relation': 'Has',
#     'tail': 'Seen significant improvements in cycling and walking infrastructure',
#     'score': 0.7572973370552063,
#     'id': 'Onehunga-Has-Seen significant improvements in cycling and walking infrastructure',
#     'rank': 11,
#     'relevant': 0},
#    {'head': 'Onehunga',
#     'relation': 'Contributes to',
#     'tail': "City's goals of reducing carbon emissions and enhancing public health",
#     'score': 0.7444372773170471,
#     'id': "Onehunga-Contributes to-City's goals of reducing carbon emissions and enhancing public health",
#     'rank': 12,
#     'relevant': 0},
#    {'head': 'Onehunga',
#     'relation': 'Has',
#     'tail': 'Integration of bus and rail services',
#     'score': 0.7384935617446899,
#     'id': 'Onehunga-Has-Integration of bus and rail services',
#     'rank': 13,
#     'relevant': 0},
#    {'head': 'Te ara i whiti',
#     'relation': 'Links',
#     'tail': 'Auckland cbd',
#     'score': 0.8644683361053467,
#     'id': 'Te ara i whiti-Links-Auckland cbd',
#     'rank': 2,
#     'relevant': 1},
#    {'head': 'Te ara i whiti',
#     'relation': 'Is',
#     'tail': 'Lightpath',
#     'score': 0.8454588651657104,
#     'id': 'Te ara i whiti-Is-Lightpath',
#     'rank': 6,
#     'relevant': 1},
#    {'head': 'Te ara i whiti',
#     'relation': 'Part of',
#     'tail': 'Auckland cycle network',
#     'score': 0.8362159132957458,
#     'id': 'Te ara i whiti-Part of-Auckland cycle network',
#     'rank': 4,
#     'relevant': 1},
#    {'head': 'Te ara i whiti',
#     'relation': 'Located in',
#     'tail': 'Auckland',
#     'score': 0.8239569067955017,
#     'id': 'Te ara i whiti-Located in-Auckland',
#     'rank': 3,
#     'relevant': 1},
#    {'head': 'Auckland',
#     'relation': 'Has',
#     'tail': 'Pedestrian pathways',
#     'score': 0.8233243227005005,
#     'id': 'Auckland-Has-Pedestrian pathways',
#     'rank': 28,
#     'relevant': 0},
#    {'head': 'Te ara i whiti',
#     'relation': 'Constructed on',
#     'tail': 'Former railway corridor',
#     'score': 0.8218223452568054,
#     'id': 'Te ara i whiti-Constructed on-Former railway corridor',
#     'rank': 7,
#     'relevant': 1},
#    {'head': 'Auckland',
#     'relation': 'Connected to',
#     'tail': 'Surrounding suburbs and regions',
#     'score': 0.8139963150024414,
#     'id': 'Auckland-Connected to-Surrounding suburbs and regions',
#     'rank': 8,
#     'relevant': 1},
#    {'head': 'Western line',
#     'relation': 'Connects',
#     'tail': 'Commuters to cbd',
#     'score': 0.8123621940612793,
#     'id': 'Western line-Connects-Commuters to cbd',
#     'rank': 34,
#     'relevant': 0},
#    {'head': 'Eastern line',
#     'relation': 'Connects',
#     'tail': 'Commuters to cbd',
#     'score': 0.8025721907615662,
#     'id': 'Eastern line-Connects-Commuters to cbd',
#     'rank': 35,
#     'relevant': 0},
#    {'head': 'Southern line',
#     'relation': 'Connects',
#     'tail': 'Commuters to cbd',
#     'score': 0.7966413497924805,
#     'id': 'Southern line-Connects-Commuters to cbd',
#     'rank': 36,
#     'relevant': 0},
#    {'head': 'Western line',
#     'relation': 'Is',
#     'tail': 'Primary rail corridor',
#     'score': 0.7505043745040894,
#     'id': 'Western line-Is-Primary rail corridor',
#     'rank': 37,
#     'relevant': 0},
#    {'head': 'Eastern line',
#     'relation': 'Is',
#     'tail': 'Primary rail corridor',
#     'score': 0.735020101070404,
#     'id': 'Eastern line-Is-Primary rail corridor',
#     'rank': 38,
#     'relevant': 0},
#    {'head': 'Southern line',
#     'relation': 'Is',
#     'tail': 'Primary rail corridor',
#     'score': 0.7346377372741699,
#     'id': 'Southern line-Is-Primary rail corridor',
#     'rank': 39,
#     'relevant': 0},
#    {'head': 'Onehunga',
#     'relation': 'Has',
#     'tail': 'Multiple routes linking it to surrounding suburbs and the auckland cbd',
#     'score': 0.8053060173988342,
#     'id': 'Onehunga-Has-Multiple routes linking it to surrounding suburbs and the auckland cbd',
#     'rank': 9,
#     'relevant': 0}]},
#  {'question': 'Which island does the city in New Zealand known for its Metlink services, which focus on providing comprehensive coverage across the region, the capital city of New Zealand, belong to?',
#   'triplets': [{'head': 'Auckland',
#     'relation': 'Has',
#     'tail': 'Comprehensive public transport networks',
#     'score': 0.8161145448684692,
#     'id': 'Auckland-Has-Comprehensive public transport networks',
#     'rank': 9,
#     'relevant': 0},
#    {'head': 'Christchurch',
#     'relation': 'Has',
#     'tail': 'Comprehensive public transport networks',
#     'score': 0.8131680488586426,
#     'id': 'Christchurch-Has-Comprehensive public transport networks',
#     'rank': 10,
#     'relevant': 0},
#    {'head': 'Christchurch',
#     'relation': 'Linked to',
#     'tail': 'Dunedin',
#     'score': 0.8105871081352234,
#     'id': 'Christchurch-Linked to-Dunedin',
#     'rank': 11,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Public transport',
#     'score': 0.8093971014022827,
#     'id': 'New zealand-Has-Public transport',
#     'rank': 12,
#     'relevant': 0},
#    {'head': 'Wellington',
#     'relation': 'Has',
#     'tail': 'Comprehensive public transport networks',
#     'score': 0.8090918064117432,
#     'id': 'Wellington-Has-Comprehensive public transport networks',
#     'rank': 5,
#     'relevant': 1},
#    {'head': 'Christchurch',
#     'relation': 'Located in',
#     'tail': 'South island',
#     'score': 0.8076204061508179,
#     'id': 'Christchurch-Located in-South island',
#     'rank': 13,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Cities',
#     'score': 0.8396409749984741,
#     'id': 'New zealand-Has-Cities',
#     'rank': 14,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Characterized by',
#     'tail': 'Mix of services',
#     'score': 0.837095320224762,
#     'id': 'New zealand-Characterized by-Mix of services',
#     'rank': 15,
#     'relevant': 0},
#    {'head': 'Air new zealand',
#     'relation': 'Plays crucial role in',
#     'tail': "Connecting new zealand's remote regions with major urban centers",
#     'score': 0.8327395915985107,
#     'id': "Air new zealand-Plays crucial role in-Connecting new zealand's remote regions with major urban centers",
#     'rank': 16,
#     'relevant': 0},
#    {'head': 'Auckland',
#     'relation': 'Is',
#     'tail': 'Largest city in new zealand',
#     'score': 0.8325598239898682,
#     'id': 'Auckland-Is-Largest city in new zealand',
#     'rank': 17,
#     'relevant': 0},
#    {'head': 'Auckland',
#     'relation': 'Serves',
#     'tail': 'New zealand',
#     'score': 0.8321657776832581,
#     'id': 'Auckland-Serves-New zealand',
#     'rank': 18,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Urban centers',
#     'score': 0.8302180171012878,
#     'id': 'New zealand-Has-Urban centers',
#     'rank': 19,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Numerous islands',
#     'score': 0.828586995601654,
#     'id': 'New zealand-Has-Numerous islands',
#     'rank': 20,
#     'relevant': 0},
#    {'head': 'Wellington',
#     'relation': 'Has',
#     'tail': 'Metlink',
#     'score': 0.8530012369155884,
#     'id': 'Wellington-Has-Metlink',
#     'rank': 2,
#     'relevant': 1},
#    {'head': 'Wellington',
#     'relation': 'Has',
#     'tail': 'Metlink brand',
#     'score': 0.8522277474403381,
#     'id': 'Wellington-Has-Metlink brand',
#     'rank': 3,
#     'relevant': 1},
#    {'head': 'Wellington',
#     'relation': 'Is',
#     'tail': 'Capital city of new zealand',
#     'score': 0.8464573621749878,
#     'id': 'Wellington-Is-Capital city of new zealand',
#     'rank': 1,
#     'relevant': 1},
#    {'head': 'Wellington',
#     'relation': 'Metlink brand',
#     'tail': 'Serves as the umbrella for its operations',
#     'score': 0.8272332549095154,
#     'id': 'Wellington-Metlink brand-Serves as the umbrella for its operations',
#     'rank': 4,
#     'relevant': 1},
#    {'head': 'Wellington',
#     'relation': 'Connected to',
#     'tail': 'Other major urban centers',
#     'score': 0.8139540553092957,
#     'id': 'Wellington-Connected to-Other major urban centers',
#     'rank': 6,
#     'relevant': 0},
#    {'head': 'Wellington northern corridor',
#     'relation': 'Connects',
#     'tail': 'Northern regions of the north island',
#     'score': 0.812394917011261,
#     'id': 'Wellington northern corridor-Connects-Northern regions of the north island',
#     'rank': 7,
#     'relevant': 0},
#    {'head': 'Wellington',
#     'relation': 'Has',
#     'tail': 'Bus network covering city and surrounding suburbs',
#     'score': 0.810408890247345,
#     'id': 'Wellington-Has-Bus network covering city and surrounding suburbs',
#     'rank': 8,
#     'relevant': 0},
#    {'head': 'Auckland',
#     'relation': 'Has',
#     'tail': 'City rail link',
#     'score': 0.8262525200843811,
#     'id': 'Auckland-Has-City rail link',
#     'rank': 21,
#     'relevant': 0},
#    {'head': 'Auckland',
#     'relation': 'Has',
#     'tail': 'Bus network with extensive coverage',
#     'score': 0.825740396976471,
#     'id': 'Auckland-Has-Bus network with extensive coverage',
#     'rank': 22,
#     'relevant': 0},
#    {'head': 'Auckland',
#     'relation': 'Connected to',
#     'tail': 'Surrounding suburbs and regions',
#     'score': 0.8228137493133545,
#     'id': 'Auckland-Connected to-Surrounding suburbs and regions',
#     'rank': 23,
#     'relevant': 0},
#    {'head': 'Auckland',
#     'relation': 'Is',
#     'tail': 'Major transport hub',
#     'score': 0.8225505352020264,
#     'id': 'Auckland-Is-Major transport hub',
#     'rank': 24,
#     'relevant': 0}]},
#  {'question': 'What year did the initiative that aims to achieve a significant reduction in road deaths and serious injuries by promoting a "Safe System" approach to road safety, known as "Road to Zero," launch in New Zealand?',
#   'triplets': [{'head': 'Road to zero',
#     'relation': 'Aims to reduce',
#     'tail': 'Road fatalities',
#     'score': 0.9006589651107788,
#     'id': 'Road to zero-Aims to reduce-Road fatalities',
#     'rank': 8,
#     'relevant': 0},
#    {'head': 'Road to zero',
#     'relation': 'Aims to reduce',
#     'tail': 'Serious injuries',
#     'score': 0.8969175219535828,
#     'id': 'Road to zero-Aims to reduce-Serious injuries',
#     'rank': 9,
#     'relevant': 0},
#    {'head': 'Road to zero',
#     'relation': 'Aim',
#     'tail': 'Reduce road fatalities and serious injuries to zero by',
#     'score': 2050.0,
#     'id': 'Road to zero-Aim-Reduce road fatalities and serious injuries to zero by',
#     'rank': 10,
#     'relevant': 0},
#    {'head': 'Road to zero',
#     'relation': 'Emphasizes',
#     'tail': 'Importance of vehicle safety',
#     'score': 0.8715617656707764,
#     'id': 'Road to zero-Emphasizes-Importance of vehicle safety',
#     'rank': 11,
#     'relevant': 0},
#    {'head': 'Road to zero',
#     'relation': 'Reflects',
#     'tail': 'Commitment to creating safe transport system',
#     'score': 0.8692113161087036,
#     'id': 'Road to zero-Reflects-Commitment to creating safe transport system',
#     'rank': 12,
#     'relevant': 0},
#    {'head': 'Road to zero',
#     'relation': 'Emphasizes',
#     'tail': 'Road infrastructure improvements',
#     'score': 0.8473979830741882,
#     'id': 'Road to zero-Emphasizes-Road infrastructure improvements',
#     'rank': 13,
#     'relevant': 0},
#    {'head': 'Road to zero strategy',
#     'relation': 'Aims',
#     'tail': 'Eliminate road deaths and serious injuries',
#     'score': 0.900111198425293,
#     'id': 'Road to zero strategy-Aims-Eliminate road deaths and serious injuries',
#     'rank': 14,
#     'relevant': 0},
#    {'head': 'Road to zero strategy',
#     'relation': 'Aims to',
#     'tail': 'Eliminate road fatalities and serious injuries by',
#     'score': 2050.0,
#     'id': 'Road to zero strategy-Aims to-Eliminate road fatalities and serious injuries by',
#     'rank': 15,
#     'relevant': 0},
#    {'head': 'Road to zero strategy',
#     'relation': 'Sets goal',
#     'tail': 'Reducing road deaths and serious injuries to zero by',
#     'score': 2050.0,
#     'id': 'Road to zero strategy-Sets goal-Reducing road deaths and serious injuries to zero by',
#     'rank': 16,
#     'relevant': 0},
#    {'head': 'Road to zero strategy',
#     'relation': 'Aligns with',
#     'tail': "New zealand's commitment to reducing greenhouse gas emissions",
#     'score': 0.8694576025009155,
#     'id': "Road to zero strategy-Aligns with-New zealand's commitment to reducing greenhouse gas emissions",
#     'rank': 17,
#     'relevant': 0},
#    {'head': 'Road safety strategy',
#     'relation': 'Launched',
#     'tail': '2019',
#     'score': 0.8618295192718506,
#     'id': 'Road safety strategy-Launched-2019',
#     'rank': 2,
#     'relevant': 1},
#    {'head': 'Road to zero strategy',
#     'relation': 'Launched',
#     'tail': '2019',
#     'score': 0.8572276830673218,
#     'id': 'Road to zero strategy-Launched-2019',
#     'rank': 1,
#     'relevant': 1},
#    {'head': 'Road to zero strategy',
#     'relation': 'Aligns with',
#     'tail': "Global best practices and united nations' sustainable development goals",
#     'score': 0.8380827903747559,
#     'id': "Road to zero strategy-Aligns with-Global best practices and united nations' sustainable development goals",
#     'rank': 18,
#     'relevant': 0},
#    {'head': 'Safer journeys strategy',
#     'relation': 'Marked',
#     'tail': "Significant shift in new zealand's approach to road safety",
#     'score': 0.8818174004554749,
#     'id': "Safer journeys strategy-Marked-Significant shift in new zealand's approach to road safety",
#     'rank': 19,
#     'relevant': 0},
#    {'head': 'Safer journeys strategy',
#     'relation': 'Focused on',
#     'tail': 'Safer road use',
#     'score': 0.854165256023407,
#     'id': 'Safer journeys strategy-Focused on-Safer road use',
#     'rank': 20,
#     'relevant': 0},
#    {'head': 'Safer journeys strategy',
#     'relation': 'Focused on',
#     'tail': 'Safer roads and roadsides',
#     'score': 0.852825939655304,
#     'id': 'Safer journeys strategy-Focused on-Safer roads and roadsides',
#     'rank': 21,
#     'relevant': 0},
#    {'head': 'Safer journeys strategy',
#     'relation': 'Focused on',
#     'tail': 'Safer vehicles',
#     'score': 0.8389161825180054,
#     'id': 'Safer journeys strategy-Focused on-Safer vehicles',
#     'rank': 22,
#     'relevant': 0},
#    {'head': 'Road transport safety',
#     'relation': 'Focus on',
#     'tail': 'Safer vehicles',
#     'score': 0.8302736282348633,
#     'id': 'Road transport safety-Focus on-Safer vehicles',
#     'rank': 23,
#     'relevant': 0},
#    {'head': 'Safer journeys strategy',
#     'relation': 'Focused on',
#     'tail': 'Safer speeds',
#     'score': 0.8276400566101074,
#     'id': 'Safer journeys strategy-Focused on-Safer speeds',
#     'rank': 24,
#     'relevant': 0},
#    {'head': 'Safer journeys strategy',
#     'relation': 'Focused on',
#     'tail': 'Four key areas',
#     'score': 0.8172357082366943,
#     'id': 'Safer journeys strategy-Focused on-Four key areas',
#     'rank': 25,
#     'relevant': 0},
#    {'head': 'Road to zero',
#     'relation': 'Aims',
#     'tail': 'Achieve vision of zero deaths and serious injuries',
#     'score': 0.902812123298645,
#     'id': 'Road to zero-Aims-Achieve vision of zero deaths and serious injuries',
#     'rank': 26,
#     'relevant': 0}]},
#  {'question': 'In what year did the Onehunga Line get reintroduced, enhancing the connection between the two locations connected by the first railway line constructed in New Zealand in 1873?',
#   'triplets': [{'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Developing rail network',
#     'score': 0.8471730947494507,
#     'id': 'New zealand-Has-Developing rail network',
#     'rank': 10,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Railways',
#     'score': 0.8412001132965088,
#     'id': 'New zealand-Has-Railways',
#     'rank': 11,
#     'relevant': 0},
#    {'head': 'Auckland',
#     'relation': 'Has',
#     'tail': 'Rail network with several lines',
#     'score': 0.8382218480110168,
#     'id': 'Auckland-Has-Rail network with several lines',
#     'rank': 9,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Composed of',
#     'tail': 'Rail networks',
#     'score': 0.8351947069168091,
#     'id': 'New zealand-Composed of-Rail networks',
#     'rank': 12,
#     'relevant': 0},
#    {'head': 'Auckland',
#     'relation': 'Has',
#     'tail': 'Rail network',
#     'score': 0.8333912491798401,
#     'id': 'Auckland-Has-Rail network',
#     'rank': 8,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Rail transport',
#     'score': 0.8331774473190308,
#     'id': 'New zealand-Has-Rail transport',
#     'rank': 13,
#     'relevant': 0},
#    {'head': 'Onehunga line',
#     'relation': 'Connects',
#     'tail': 'Onehunga to the wider auckland rail network',
#     'score': 0.8747345805168152,
#     'id': 'Onehunga line-Connects-Onehunga to the wider auckland rail network',
#     'rank': 3,
#     'relevant': 1},
#    {'head': 'Onehunga line',
#     'relation': 'Has',
#     'tail': 'Been instrumental in promoting public transport use',
#     'score': 0.8333762288093567,
#     'id': 'Onehunga line-Has-Been instrumental in promoting public transport use',
#     'rank': 14,
#     'relevant': 0},
#    {'head': 'Onehunga line',
#     'relation': 'Has',
#     'tail': 'Been instrumental in alleviating road congestion',
#     'score': 0.8332298994064331,
#     'id': 'Onehunga line-Has-Been instrumental in alleviating road congestion',
#     'rank': 15,
#     'relevant': 0},
#    {'head': 'Onehunga line',
#     'relation': 'Has',
#     'tail': 'Been instrumental in reducing travel times for commuters',
#     'score': 0.82525634765625,
#     'id': 'Onehunga line-Has-Been instrumental in reducing travel times for commuters',
#     'rank': 16,
#     'relevant': 0},
#    {'head': 'Railway line',
#     'relation': 'Opened',
#     'tail': '1873',
#     'score': 0.8641853332519531,
#     'id': 'Railway line-Opened-1873',
#     'rank': 2,
#     'relevant': 1},
#    {'head': 'New zealand',
#     'relation': 'Had',
#     'tail': 'First railway line between auckland and onehunga in',
#     'score': 1873.0,
#     'id': 'New zealand-Had-First railway line between auckland and onehunga in',
#     'rank': 1,
#     'relevant': 1}]},
#  {'question': "What major arterial route enhances accessibility between Auckland and Onehunga, particularly for travel to one of the major airports in New Zealand's transport infrastructure as of 2023?",
#   'triplets': [{'head': 'Auckland airport',
#     'relation': 'Is',
#     'tail': 'Undergoing significant expansion',
#     'score': 0.867223858833313,
#     'id': 'Auckland airport-Is-Undergoing significant expansion',
#     'rank': 13,
#     'relevant': 0},
#    {'head': 'Auckland airport',
#     'relation': 'Plays',
#     'tail': "Crucial role in new zealand's transport infrastructure",
#     'score': 0.8630920648574829,
#     'id': "Auckland airport-Plays-Crucial role in new zealand's transport infrastructure",
#     'rank': 14,
#     'relevant': 0},
#    {'head': 'Auckland airport',
#     'relation': 'Has',
#     'tail': 'Undergone significant expansion and modernization',
#     'score': 0.8628732562065125,
#     'id': 'Auckland airport-Has-Undergone significant expansion and modernization',
#     'rank': 15,
#     'relevant': 0},
#    {'head': 'Auckland airport',
#     'relation': 'Well-connected',
#     'tail': 'Wider transport network of new zealand',
#     'score': 0.8628103733062744,
#     'id': 'Auckland airport-Well-connected-Wider transport network of new zealand',
#     'rank': 16,
#     'relevant': 0},
#    {'head': 'Auckland airport',
#     'relation': 'Equipped with',
#     'tail': 'Modern amenities',
#     'score': 0.8599750995635986,
#     'id': 'Auckland airport-Equipped with-Modern amenities',
#     'rank': 17,
#     'relevant': 0},
#    {'head': 'Auckland',
#     'relation': 'Has',
#     'tail': 'International airport',
#     'score': 0.8586162328720093,
#     'id': 'Auckland-Has-International airport',
#     'rank': 18,
#     'relevant': 0},
#    {'head': 'State highway 20',
#     'relation': 'Facilitates',
#     'tail': 'Access to auckland airport and other regions of the north island',
#     'score': 0.8455373048782349,
#     'id': 'State highway 20-Facilitates-Access to auckland airport and other regions of the north island',
#     'rank': 1,
#     'relevant': 1},
#    {'head': 'Auckland western ring route',
#     'relation': 'Key component',
#     'tail': "Auckland's broader transport strategy",
#     'score': 0.834848165512085,
#     'id': "Auckland western ring route-Key component-Auckland's broader transport strategy",
#     'rank': 2,
#     'relevant': 1},
#    {'head': 'Auckland western ring route',
#     'relation': 'Is',
#     'tail': 'Significant transport corridor',
#     'score': 0.8333609104156494,
#     'id': 'Auckland western ring route-Is-Significant transport corridor',
#     'rank': 3,
#     'relevant': 1},
#    {'head': 'Auckland western ring route',
#     'relation': 'Anticipates',
#     'tail': 'Improved public transport links',
#     'score': 0.830819308757782,
#     'id': 'Auckland western ring route-Anticipates-Improved public transport links',
#     'rank': 7,
#     'relevant': 0},
#    {'head': 'Auckland western ring route',
#     'relation': 'Supports',
#     'tail': 'Urban transport',
#     'score': 0.8286157846450806,
#     'id': 'Auckland western ring route-Supports-Urban transport',
#     'rank': 6,
#     'relevant': 0},
#    {'head': 'Auckland western ring route',
#     'relation': 'Provides',
#     'tail': 'More efficient transport option',
#     'score': 0.826379120349884,
#     'id': 'Auckland western ring route-Provides-More efficient transport option',
#     'rank': 4,
#     'relevant': 1},
#    {'head': 'Auckland western ring route',
#     'relation': 'Anticipates',
#     'tail': 'Further enhancements',
#     'score': 0.8248204588890076,
#     'id': 'Auckland western ring route-Anticipates-Further enhancements',
#     'rank': 8,
#     'relevant': 0},
#    {'head': 'Onehunga',
#     'relation': 'Is',
#     'tail': 'Served by the auckland public transport network',
#     'score': 0.8893288373947144,
#     'id': 'Onehunga-Is-Served by the auckland public transport network',
#     'rank': 19,
#     'relevant': 0},
#    {'head': 'Onehunga',
#     'relation': 'Is',
#     'tail': 'Strategically located near major arterial routes',
#     'score': 0.8761754631996155,
#     'id': 'Onehunga-Is-Strategically located near major arterial routes',
#     'rank': 5,
#     'relevant': 1},
#    {'head': 'Onehunga',
#     'relation': 'Has',
#     'tail': 'Multiple routes linking it to surrounding suburbs and the auckland cbd',
#     'score': 0.867659866809845,
#     'id': 'Onehunga-Has-Multiple routes linking it to surrounding suburbs and the auckland cbd',
#     'rank': 9,
#     'relevant': 0},
#    {'head': 'Onehunga',
#     'relation': 'Has',
#     'tail': 'Integration of bus and rail services',
#     'score': 0.8547335267066956,
#     'id': 'Onehunga-Has-Integration of bus and rail services',
#     'rank': 10,
#     'relevant': 0},
#    {'head': 'Onehunga',
#     'relation': 'Is',
#     'tail': 'Suburb located approximately',
#     'score': 12.0,
#     'id': 'Onehunga-Is-Suburb located approximately',
#     'rank': 20,
#     'relevant': 0},
#    {'head': 'Onehunga',
#     'relation': 'Has',
#     'tail': 'Encouraged more sustainable travel options',
#     'score': 0.8419249057769775,
#     'id': 'Onehunga-Has-Encouraged more sustainable travel options',
#     'rank': 11,
#     'relevant': 0},
#    {'head': 'Onehunga',
#     'relation': 'Has',
#     'tail': 'Seen significant improvements in cycling and walking infrastructure',
#     'score': 0.8407048583030701,
#     'id': 'Onehunga-Has-Seen significant improvements in cycling and walking infrastructure',
#     'rank': 12,
#     'relevant': 0},
#    {'head': 'Auckland airport',
#     'relation': 'Key player',
#     'tail': 'Future of transport in new zealand',
#     'score': 0.8787257671356201,
#     'id': 'Auckland airport-Key player-Future of transport in new zealand',
#     'rank': 21,
#     'relevant': 0}]},
#  {'question': 'Which city is linked to the urban area in New Zealand that has experienced significant investment in public transport infrastructure alongside Auckland and Wellington by State Highway 1 to the north?',
#   'triplets': [{'head': 'Wellington northern corridor',
#     'relation': 'Links with',
#     'tail': 'State highway',
#     'score': 1.0,
#     'id': 'Wellington northern corridor-Links with-State highway',
#     'rank': 5,
#     'relevant': 1},
#    {'head': 'Wellington',
#     'relation': 'Focused on',
#     'tail': 'Enhancing its transport infrastructure',
#     'score': 0.8669570088386536,
#     'id': 'Wellington-Focused on-Enhancing its transport infrastructure',
#     'rank': 11,
#     'relevant': 0},
#    {'head': 'Wellington',
#     'relation': 'Relies heavily on',
#     'tail': 'Public transport',
#     'score': 0.8667759895324707,
#     'id': 'Wellington-Relies heavily on-Public transport',
#     'rank': 12,
#     'relevant': 0},
#    {'head': 'Wellington',
#     'relation': 'Has',
#     'tail': 'Comprehensive public transport networks',
#     'score': 0.8653692603111267,
#     'id': 'Wellington-Has-Comprehensive public transport networks',
#     'rank': 13,
#     'relevant': 0},
#    {'head': 'Wellington',
#     'relation': 'Serves as',
#     'tail': 'Vital transport hub',
#     'score': 0.8653260469436646,
#     'id': 'Wellington-Serves as-Vital transport hub',
#     'rank': 14,
#     'relevant': 0},
#    {'head': 'Wellington',
#     'relation': 'Has',
#     'tail': 'Public transport services',
#     'score': 0.863973081111908,
#     'id': 'Wellington-Has-Public transport services',
#     'rank': 15,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Transport infrastructure investment',
#     'score': 0.9011587500572205,
#     'id': 'New zealand-Has-Transport infrastructure investment',
#     'rank': 16,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Urban-centric transport system',
#     'score': 0.8887932300567627,
#     'id': 'New zealand-Has-Urban-centric transport system',
#     'rank': 17,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Transport infrastructure',
#     'score': 0.8873845338821411,
#     'id': 'New zealand-Has-Transport infrastructure',
#     'rank': 18,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Transport infrastructure development',
#     'score': 0.887237548828125,
#     'id': 'New zealand-Has-Transport infrastructure development',
#     'rank': 19,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Public transport development',
#     'score': 0.8839156627655029,
#     'id': 'New zealand-Has-Public transport development',
#     'rank': 20,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Transport projects',
#     'score': 0.8823251724243164,
#     'id': 'New zealand-Has-Transport projects',
#     'rank': 21,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Transport infrastructure funding',
#     'score': 0.881171464920044,
#     'id': 'New zealand-Has-Transport infrastructure funding',
#     'rank': 22,
#     'relevant': 0},
#    {'head': 'Road infrastructure projects',
#     'relation': 'Play crucial role in',
#     'tail': "New zealand's transport network",
#     'score': 0.8776376843452454,
#     'id': "Road infrastructure projects-Play crucial role in-New zealand's transport network",
#     'rank': 23,
#     'relevant': 0},
#    {'head': 'Auckland transport alignment project',
#     'relation': 'Focuses on',
#     'tail': 'Aligning transport investments',
#     'score': 0.8630427718162537,
#     'id': 'Auckland transport alignment project-Focuses on-Aligning transport investments',
#     'rank': 24,
#     'relevant': 0},
#    {'head': 'Auckland transport alignment project',
#     'relation': 'Focuses',
#     'tail': 'On enhancing road infrastructure',
#     'score': 0.8624625205993652,
#     'id': 'Auckland transport alignment project-Focuses-On enhancing road infrastructure',
#     'rank': 25,
#     'relevant': 0},
#    {'head': 'Auckland transport alignment project',
#     'relation': 'Focuses',
#     'tail': 'On improving public transport',
#     'score': 0.8576145172119141,
#     'id': 'Auckland transport alignment project-Focuses-On improving public transport',
#     'rank': 26,
#     'relevant': 0},
#    {'head': 'Auckland transport alignment project',
#     'relation': 'Focuses on',
#     'tail': 'Development of comprehensive transport network',
#     'score': 0.8551918864250183,
#     'id': 'Auckland transport alignment project-Focuses on-Development of comprehensive transport network',
#     'rank': 27,
#     'relevant': 0},
#    {'head': 'Auckland transport alignment project',
#     'relation': 'Encompasses',
#     'tail': 'Range of projects',
#     'score': 0.8525838255882263,
#     'id': 'Auckland transport alignment project-Encompasses-Range of projects',
#     'rank': 28,
#     'relevant': 0},
#    {'head': 'Auckland transport alignment project',
#     'relation': 'Focuses on',
#     'tail': 'Addressing transport challenges in auckland',
#     'score': 0.8512289524078369,
#     'id': 'Auckland transport alignment project-Focuses on-Addressing transport challenges in auckland',
#     'rank': 29,
#     'relevant': 0},
#    {'head': 'Auckland transport alignment project',
#     'relation': 'Is',
#     'tail': 'Strategic initiative',
#     'score': 0.8462114334106445,
#     'id': 'Auckland transport alignment project-Is-Strategic initiative',
#     'rank': 30,
#     'relevant': 0}]},
#  {'question': 'In what year did the project that aims to develop a high-quality public transport corridor in Wellington begin?',
#   'triplets': [{'head': 'Wellington public transport plan',
#     'relation': 'Initiated in response to',
#     'tail': 'Increasing urbanization',
#     'score': 0.882498025894165,
#     'id': 'Wellington public transport plan-Initiated in response to-Increasing urbanization',
#     'rank': 1,
#     'relevant': 0},
#    {'head': 'Wellington public transport plan',
#     'relation': 'Represents',
#     'tail': 'Significant step towards creating sustainable and user-friendly public transport system',
#     'score': 0.8819208145141602,
#     'id': 'Wellington public transport plan-Represents-Significant step towards creating sustainable and user-friendly public transport system',
#     'rank': 2,
#     'relevant': 0},
#    {'head': 'Wellington public transport plan',
#     'relation': 'Outlines',
#     'tail': 'Comprehensive approach',
#     'score': 0.8812780380249023,
#     'id': 'Wellington public transport plan-Outlines-Comprehensive approach',
#     'rank': 3,
#     'relevant': 0},
#    {'head': 'Wellington public transport plan',
#     'relation': 'Aimed at',
#     'tail': 'Promoting sustainability',
#     'score': 0.880703330039978,
#     'id': 'Wellington public transport plan-Aimed at-Promoting sustainability',
#     'rank': 4,
#     'relevant': 0},
#    {'head': 'Wellington public transport plan',
#     'relation': 'Is',
#     'tail': 'Strategic framework',
#     'score': 0.8795210123062134,
#     'id': 'Wellington public transport plan-Is-Strategic framework',
#     'rank': 5,
#     'relevant': 0},
#    {'head': 'Wellington regional public transport plan',
#     'relation': 'Is',
#     'tail': 'Strategic framework',
#     'score': 0.877652645111084,
#     'id': 'Wellington regional public transport plan-Is-Strategic framework',
#     'rank': 6,
#     'relevant': 0},
#    {'head': 'Wellington northern corridor',
#     'relation': 'Aims to',
#     'tail': "Meet the evolving needs of new zealand's transport system",
#     'score': 0.892913281917572,
#     'id': "Wellington northern corridor-Aims to-Meet the evolving needs of new zealand's transport system",
#     'rank': 7,
#     'relevant': 0},
#    {'head': 'Wellington',
#     'relation': 'Has',
#     'tail': 'Comprehensive public transport networks',
#     'score': 0.8759836554527283,
#     'id': 'Wellington-Has-Comprehensive public transport networks',
#     'rank': 8,
#     'relevant': 0},
#    {'head': 'Wellington',
#     'relation': 'Has',
#     'tail': 'Public transport services',
#     'score': 0.8745676875114441,
#     'id': 'Wellington-Has-Public transport services',
#     'rank': 9,
#     'relevant': 0},
#    {'head': 'Wellington',
#     'relation': 'Has',
#     'tail': 'Well-integrated transport system',
#     'score': 0.8744156956672668,
#     'id': 'Wellington-Has-Well-integrated transport system',
#     'rank': 10,
#     'relevant': 0},
#    {'head': 'Wellington',
#     'relation': 'Focused on',
#     'tail': 'Enhancing its transport infrastructure',
#     'score': 0.8736780285835266,
#     'id': 'Wellington-Focused on-Enhancing its transport infrastructure',
#     'rank': 11,
#     'relevant': 0},
#    {'head': 'Sustainable urban transport',
#     'relation': 'Key component',
#     'tail': 'Wellington',
#     'score': 0.8695807456970215,
#     'id': 'Sustainable urban transport-Key component-Wellington',
#     'rank': 12,
#     'relevant': 0},
#    {'head': 'Wellington northern corridor',
#     'relation': 'Is',
#     'tail': 'Key transport route',
#     'score': 0.8695229291915894,
#     'id': 'Wellington northern corridor-Is-Key transport route',
#     'rank': 13,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Transport projects',
#     'score': 0.8684442043304443,
#     'id': 'New zealand-Has-Transport projects',
#     'rank': 14,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Public transport development',
#     'score': 0.8676924109458923,
#     'id': 'New zealand-Has-Public transport development',
#     'rank': 15,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Public transport integration',
#     'score': 0.8607476353645325,
#     'id': 'New zealand-Has-Public transport integration',
#     'rank': 16,
#     'relevant': 0},
#    {'head': 'Auckland',
#     'relation': 'Has',
#     'tail': 'Transport projects',
#     'score': 0.8602539300918579,
#     'id': 'Auckland-Has-Transport projects',
#     'rank': 17,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Transport infrastructure development',
#     'score': 0.8599637746810913,
#     'id': 'New zealand-Has-Transport infrastructure development',
#     'rank': 18,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Public transport network planning',
#     'score': 0.8597931861877441,
#     'id': 'New zealand-Has-Public transport network planning',
#     'rank': 19,
#     'relevant': 0},
#    {'head': 'Wellington',
#     'relation': 'Has',
#     'tail': 'Initiatives',
#     'score': 0.8562711477279663,
#     'id': 'Wellington-Has-Initiatives',
#     'rank': 20,
#     'relevant': 0}]},
#  {'question': 'Which line does the major transport infrastructure project in New Zealand, which aims to improve rail connectivity and reduce congestion in Auckland, connect to at Britomart Station?',
#   'triplets': [{'head': 'Auckland transport alignment project',
#     'relation': 'Aims to',
#     'tail': 'Reduce congestion',
#     'score': 0.8695691227912903,
#     'id': 'Auckland transport alignment project-Aims to-Reduce congestion',
#     'rank': 8,
#     'relevant': 0},
#    {'head': 'Auckland transport alignment project',
#     'relation': 'Focuses',
#     'tail': 'On enhancing road infrastructure',
#     'score': 0.8682559728622437,
#     'id': 'Auckland transport alignment project-Focuses-On enhancing road infrastructure',
#     'rank': 9,
#     'relevant': 0},
#    {'head': 'Auckland transport alignment project',
#     'relation': 'Aims to',
#     'tail': 'Create unified transport network',
#     'score': 0.8629523515701294,
#     'id': 'Auckland transport alignment project-Aims to-Create unified transport network',
#     'rank': 10,
#     'relevant': 0},
#    {'head': 'Auckland transport alignment project',
#     'relation': 'Aims to',
#     'tail': 'Improve efficiency and effectiveness of transport system',
#     'score': 0.8603688478469849,
# ...
#     'relation': 'Is',
#     'tail': 'Second-busiest airport in new zealand',
#     'score': 0.8753463625907898,
#     'id': 'Christchurch international airport-Is-Second-busiest airport in new zealand',
#     'rank': 1,
#     'relevant': 1},
#    {'head': 'Christchurch',
#     'relation': 'Has',
#     'tail': 'Second-busiest airport in new zealand',
#     'score': 0.872168779373169,
#     'id': 'Christchurch-Has-Second-busiest airport in new zealand',
#     'rank': 2,
#     'relevant': 1},
#    {'head': 'Auckland',
#     'relation': 'Has',
#     'tail': 'Public transport system',
#     'score': 0.8715581893920898,
#     'id': 'Auckland-Has-Public transport system',
#     'rank': 15,
#     'relevant': 0},
#    {'head': 'Auckland',
#     'relation': 'Has',
#     'tail': 'Comprehensive public transport networks',
#     'score': 0.8670401573181152,
#     'id': 'Auckland-Has-Comprehensive public transport networks',
#     'rank': 16,
#     'relevant': 0},
#    {'head': 'Christchurch international airport',
#     'relation': 'Is',
#     'tail': 'Second-busiest airport',
#     'score': 0.864715576171875,
#     'id': 'Christchurch international airport-Is-Second-busiest airport',
#     'rank': 14,
#     'relevant': 0},
#    {'head': 'Auckland',
#     'relation': 'Has',
#     'tail': 'Buses',
#     'score': 0.8631771802902222,
#     'id': 'Auckland-Has-Buses',
#     'rank': 17,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Public transport',
#     'score': 0.855236291885376,
#     'id': 'New zealand-Has-Public transport',
#     'rank': 18,
#     'relevant': 0}]},
#  {'question': 'Which country did the airline that initially operated trans-Tasman flights to in 1940 connect to for tourism and business travel, alongside major cities in New Zealand and Asia, alongside the urban area in New Zealand that has experienced significant investment in public transport infrastructure alongside Auckland and Wellington?',
#   'triplets': [{'head': 'Auckland airport',
#     'relation': 'Vital',
#     'tail': 'Hub for tourism and business travel',
#     'score': 0.8601557016372681,
#     'id': 'Auckland airport-Vital-Hub for tourism and business travel',
#     'rank': 2,
#     'relevant': 1},
#    {'head': 'Auckland airport',
#     'relation': 'Plays',
#     'tail': "Crucial role in new zealand's transport infrastructure",
#     'score': 0.859595000743866,
#     'id': "Auckland airport-Plays-Crucial role in new zealand's transport infrastructure",
#     'rank': 3,
#     'relevant': 1},
#    {'head': 'Auckland airport',
#     'relation': 'Supporting',
#     'tail': 'Local economy and tourism industry',
#     'score': 0.8570446968078613,
#     'id': 'Auckland airport-Supporting-Local economy and tourism industry',
#     'rank': 4,
#     'relevant': 1},
#    {'head': 'Auckland airport',
#     'relation': 'Connecting',
#     'tail': 'Country to the rest of the world',
#     'score': 0.8521264791488647,
#     'id': 'Auckland airport-Connecting-Country to the rest of the world',
#     'rank': 5,
#     'relevant': 1},
#    {'head': 'Auckland airport',
#     'relation': 'Facilitates',
#     'tail': 'Domestic and international travel',
#     'score': 0.8515406847000122,
#     'id': 'Auckland airport-Facilitates-Domestic and international travel',
#     'rank': 6,
#     'relevant': 1},
#    {'head': 'Auckland airport',
#     'relation': 'Serves',
#     'tail': 'Domestic and international flights',
#     'score': 0.851431667804718,
#     'id': 'Auckland airport-Serves-Domestic and international flights',
#     'rank': 7,
#     'relevant': 1},
#    {'head': 'Teal',
#     'relation': 'Initially operating',
#     'tail': 'Trans-tasman flights between new zealand and australia',
#     'score': 0.875971794128418,
#     'id': 'Teal-Initially operating-Trans-tasman flights between new zealand and australia',
#     'rank': 1,
#     'relevant': 1},
#    {'head': 'Air new zealand',
#     'relation': 'Operates',
#     'tail': 'Numerous routes connecting major cities and regional centers',
#     'score': 0.8753840923309326,
#     'id': 'Air new zealand-Operates-Numerous routes connecting major cities and regional centers',
#     'rank': 8,
#     'relevant': 1},
#    {'head': 'Air new zealand',
#     'relation': 'Established in',
#     'tail': '1940',
#     'score': 0.8750410079956055,
#     'id': 'Air new zealand-Established in-1940',
#     'rank': 9,
#     'relevant': 1},
#    {'head': 'Air new zealand',
#     'relation': 'Plays crucial role in',
#     'tail': "Connecting new zealand's remote regions with major urban centers",
#     'score': 0.8676568269729614,
#     'id': "Air new zealand-Plays crucial role in-Connecting new zealand's remote regions with major urban centers",
#     'rank': 10,
#     'relevant': 1},
#    {'head': 'Air new zealand',
#     'relation': 'Contributes significantly to',
#     'tail': "Country's economy and connectivity",
#     'score': 0.8641636371612549,
#     'id': "Air new zealand-Contributes significantly to-Country's economy and connectivity",
#     'rank': 11,
#     'relevant': 1},
#    {'head': 'Air new zealand',
#     'relation': 'Is',
#     'tail': 'Flagship airline of new zealand',
#     'score': 0.8531244993209839,
#     'id': 'Air new zealand-Is-Flagship airline of new zealand',
#     'rank': 12,
#     'relevant': 1},
#    {'head': 'Air new zealand',
#     'relation': 'Remains',
#     'tail': "Cornerstone of new zealand's transport infrastructure",
#     'score': 0.851710855960846,
#     'id': "Air new zealand-Remains-Cornerstone of new zealand's transport infrastructure",
#     'rank': 13,
#     'relevant': 1},
#    {'head': 'Wellington international airport',
#     'relation': 'Provides',
#     'tail': 'Domestic flights to major cities across new zealand',
#     'score': 0.8632847666740417,
#     'id': 'Wellington international airport-Provides-Domestic flights to major cities across new zealand',
#     'rank': 14,
#     'relevant': 1},
#    {'head': 'Wellington international airport',
#     'relation': 'Provides',
#     'tail': 'International flights to australia and the south pacific',
#     'score': 0.8583430051803589,
#     'id': 'Wellington international airport-Provides-International flights to australia and the south pacific',
#     'rank': 15,
#     'relevant': 1},
#    {'head': 'Wellington international airport',
#     'relation': 'Known for',
#     'tail': 'Unique location',
#     'score': 0.8400535583496094,
#     'id': 'Wellington international airport-Known for-Unique location',
#     'rank': 16,
#     'relevant': 0},
#    {'head': 'Wellington international airport',
#     'relation': 'Is',
#     'tail': 'Primary airport serving the city',
#     'score': 0.8377350568771362,
#     'id': 'Wellington international airport-Is-Primary airport serving the city',
#     'rank': 17,
#     'relevant': 0},
#    {'head': 'Wellington international airport',
#     'relation': 'Situated on',
#     'tail': 'Narrow strip of land between the hills and the sea',
#     'score': 0.8257229924201965,
#     'id': 'Wellington international airport-Situated on-Narrow strip of land between the hills and the sea',
#     'rank': 18,
#     'relevant': 0},
#    {'head': 'Wellington international airport',
#     'relation': 'Located',
#     'tail': 'Just',
#     'score': 8.0,
#     'id': 'Wellington international airport-Located-Just',
#     'rank': 19,
#     'relevant': 0},
#    {'head': 'Wellington international airport',
#     'relation': 'Presents challenges for',
#     'tail': 'Both takeoff and landing',
#     'score': 0.8080945014953613,
#     'id': 'Wellington international airport-Presents challenges for-Both takeoff and landing',
#     'rank': 20,
#     'relevant': 0},
#    {'head': 'Port of wellington',
#     'relation': 'Facilitates',
#     'tail': 'Both passenger and freight transport across the cook strait',
#     'score': 0.8303159475326538,
#     'id': 'Port of wellington-Facilitates-Both passenger and freight transport across the cook strait',
#     'rank': 21,
#     'relevant': 0},
#    {'head': 'Port of wellington',
#     'relation': 'Connects',
#     'tail': 'Wellington to the south island',
#     'score': 0.8179738521575928,
#     'id': 'Port of wellington-Connects-Wellington to the south island',
#     'rank': 22,
#     'relevant': 0},
#    {'head': 'Port of wellington',
#     'relation': 'Is',
#     'tail': 'One of the busiest ports in new zealand',
#     'score': 0.813212513923645,
#     'id': 'Port of wellington-Is-One of the busiest ports in new zealand',
#     'rank': 23,
#     'relevant': 0},
#    {'head': 'Port of wellington',
#     'relation': 'Serves as',
#     'tail': 'Departure point for ferries',
#     'score': 0.8077861070632935,
#     'id': 'Port of wellington-Serves as-Departure point for ferries',
#     'rank': 24,
#     'relevant': 0},
#    {'head': 'Port of wellington',
#     'relation': 'Handles',
#     'tail': 'Variety of cargo',
#     'score': 0.8069910407066345,
#     'id': 'Port of wellington-Handles-Variety of cargo',
#     'rank': 25,
#     'relevant': 0}]},
#  {'question': 'What significant engineering challenge associated with the key transport corridor critical for freight and passenger movement and running through the North Island, completed in the year the major railway line in New Zealand is being upgraded to enhance its capacity and efficiency for sustainable transport, is known for its unique spiral design?',
#   'triplets': [{'head': 'Austroads',
#     'relation': 'Plays',
#     'tail': 'Significant role in shaping transport infrastructure and policy in new zealand',
#     'score': 0.8465326428413391,
#     'id': 'Austroads-Plays-Significant role in shaping transport infrastructure and policy in new zealand',
#     'rank': 5,
#     'relevant': 0},
#    {'head': 'Austroads',
#     'relation': 'Collaborates with',
#     'tail': 'New zealand transport agency (nzta',
#     'score': 0.8093392848968506,
#     'id': 'Austroads-Collaborates with-New zealand transport agency (nzta',
#     'rank': 6,
#     'relevant': 0},
#    {'head': 'Austroads',
#     'relation': 'Is',
#     'tail': 'Collective of australian and new zealand road transport and traffic agencies',
#     'score': 0.7922015190124512,
#     'id': 'Austroads-Is-Collective of australian and new zealand road transport and traffic agencies',
#     'rank': 7,
#     'relevant': 0},
#    {'head': 'Austroads',
#     'relation': 'Conducts',
#     'tail': 'Extensive research and development projects',
#     'score': 0.7718237638473511,
#     'id': 'Austroads-Conducts-Extensive research and development projects',
#     'rank': 8,
#     'relevant': 0},
#    {'head': 'Austroads',
#     'relation': 'Engages in',
#     'tail': 'International collaborations to align initiatives with global best practices',
#     'score': 0.7564767003059387,
#     'id': 'Austroads-Engages in-International collaborations to align initiatives with global best practices',
#     'rank': 9,
#     'relevant': 0},
#    {'head': 'Austroads',
#     'relation': 'Founded in',
#     'tail': '1990',
#     'score': 0.7261661887168884,
#     'id': 'Austroads-Founded in-1990',
#     'rank': 10,
#     'relevant': 0},
#    {'head': 'New zealand government',
#     'relation': 'Supported',
#     'tail': 'Adoption of sustainable transport technologies',
#     'score': 0.8407054543495178,
#     'id': 'New zealand government-Supported-Adoption of sustainable transport technologies',
#     'rank': 11,
#     'relevant': 0},
#    {'head': 'New zealand government',
#     'relation': 'Improve',
#     'tail': 'Overall transport experience',
#     'score': 0.8402334451675415,
#     'id': 'New zealand government-Improve-Overall transport experience',
#     'rank': 12,
#     'relevant': 0},
#    {'head': 'Road safety education',
#     'relation': 'Is',
#     'tail': "Critical component of new zealand's transport strategy",
#     'score': 0.8351141214370728,
#     'id': "Road safety education-Is-Critical component of new zealand's transport strategy",
#     'rank': 13,
#     'relevant': 0},
#    {'head': 'Auckland transport',
#     'relation': 'Actively involved in',
#     'tail': 'Community engagement',
#     'score': 0.8343073129653931,
#     'id': 'Auckland transport-Actively involved in-Community engagement',
#     'rank': 14,
#     'relevant': 0},
#    {'head': 'Sustainable transport solutions',
#     'relation': 'Includes',
#     'tail': 'Cycling',
#     'score': 0.8279963731765747,
#     'id': 'Sustainable transport solutions-Includes-Cycling',
#     'rank': 15,
#     'relevant': 0},
#    {'head': 'New zealand government',
#     'relation': 'Prioritizes',
#     'tail': 'Transport research',
#     'score': 0.8272744417190552,
#     'id': 'New zealand government-Prioritizes-Transport research',
#     'rank': 16,
#     'relevant': 0},
#    {'head': 'Nzta',
#     'relation': 'Actively exploring',
#     'tail': 'Enhancing traffic management capabilities',
#     'score': 0.8268737196922302,
#     'id': 'Nzta-Actively exploring-Enhancing traffic management capabilities',
#     'rank': 17,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Transport planning',
#     'score': 0.8634418249130249,
#     'id': 'New zealand-Has-Transport planning',
#     'rank': 18,
#     'relevant': 0},
#    {'head': 'Auckland transport',
#     'relation': 'Remains',
#     'tail': 'Forefront of addressing challenges',
#     'score': 0.8586375117301941,
#     'id': 'Auckland transport-Remains-Forefront of addressing challenges',
#     'rank': 19,
#     'relevant': 0},
#    {'head': 'Auckland transport',
#     'relation': 'Implemented',
#     'tail': 'Cycling infrastructure projects',
#     'score': 0.8506833910942078,
#     'id': 'Auckland transport-Implemented-Cycling infrastructure projects',
#     'rank': 20,
#     'relevant': 0},
#    {'head': 'Auckland transport',
#     'relation': 'Focused on',
#     'tail': 'Promoting active transport modes',
#     'score': 0.8490039706230164,
#     'id': 'Auckland transport-Focused on-Promoting active transport modes',
#     'rank': 21,
#     'relevant': 0},
#    {'head': 'Auckland transport',
#     'relation': 'Committed to',
#     'tail': 'Providing sustainable transport options',
#     'score': 0.8488008379936218,
#     'id': 'Auckland transport-Committed to-Providing sustainable transport options',
#     'rank': 22,
#     'relevant': 0},
#    {'head': 'Auckland transport',
#     'relation': 'Plays',
#     'tail': 'Crucial role',
#     'score': 0.8472338914871216,
#     'id': 'Auckland transport-Plays-Crucial role',
#     'rank': 23,
#     'relevant': 0},
#    {'head': 'Auckland transport',
#     'relation': 'Remains',
#     'tail': 'Forefront of addressing opportunities',
#     'score': 0.8449376821517944,
#     'id': 'Auckland transport-Remains-Forefront of addressing opportunities',
#     'rank': 24,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Faces challenges',
#     'tail': 'The need for sustainable transport solutions',
#     'score': 0.8824827671051025,
#     'id': 'New zealand-Faces challenges-The need for sustainable transport solutions',
#     'rank': 25,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Faces',
#     'tail': 'Unique challenges in transportation',
#     'score': 0.8784781098365784,
#     'id': 'New zealand-Faces-Unique challenges in transportation',
#     'rank': 26,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Growing emphasis on sustainable transport solutions',
#     'score': 0.8751609921455383,
#     'id': 'New zealand-Has-Growing emphasis on sustainable transport solutions',
#     'rank': 27,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Sustainable transport initiatives',
#     'score': 0.8734918236732483,
#     'id': 'New zealand-Has-Sustainable transport initiatives',
#     'rank': 28,
#     'relevant': 0},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Transport infrastructure development',
#     'score': 0.8722070455551147,
#     'id': 'New zealand-Has-Transport infrastructure development',
#     'rank': 29,
#     'relevant': 0},
#    {'head': 'Wellington northern corridor',
#     'relation': 'Accommodates',
#     'tail': 'Sustainable transport options',
#     'score': 0.8712188005447388,
#     'id': 'Wellington northern corridor-Accommodates-Sustainable transport options',
#     'rank': 1,
#     'relevant': 1},
#    {'head': 'New zealand',
#     'relation': 'Has',
#     'tail': 'Transport system innovation',
#     'score': 0.8709776997566223,
#     'id': 'New zealand-Has-Transport system innovation',
#     'rank': 30,
#     'relevant': 0}]})

# %%
import math

def calculate_mrr(data):
    """
    Calculates the Mean Reciprocal Rank (MRR) and returns per-entry reciprocal ranks.
    
    Parameters:
    - data (List[Dict]): List of entries with 'triplets' sorted by retrieval model.
    
    Returns:
    - float: The overall MRR score.
    - List[float]: Reciprocal ranks for each entry.
    """
    mrr = 0.0
    reciprocal_ranks = []
    for entry in data:
        rr = 0.0
        for idx, triplet in enumerate(entry['triplets']):
            if triplet['relevant'] == 1:
                rr = 1.0 / (idx + 1)
                break
        reciprocal_ranks.append(rr)
        mrr += rr
    overall_mrr = mrr / len(data) if data else 0.0
    return overall_mrr, reciprocal_ranks


def calculate_ndcg(data, k=28):
    """
    Calculates the average Normalized Discounted Cumulative Gain (nDCG) and returns per-entry nDCG scores.
    
    Parameters:
    - data (List[Dict]): List of entries with 'triplets' sorted by retrieval model.
    - k (int, optional): Rank position to calculate DCG up to. Defaults to 28.
    
    Returns:
    - float: The average nDCG score.
    - List[float]: nDCG scores for each entry.
    """
    dcg_sum = 0.0
    idcg_sum = 0.0
    ndcg_scores = []
    for entry in data:
        triplets = entry['triplets'][:k]
        
        # Calculate DCG
        dcg = sum(
            triplet['relevant'] / math.log2(idx + 2) 
            for idx, triplet in enumerate(triplets)
        )
        dcg_sum += dcg
        
        # Calculate Ideal DCG
        ideal_triplets = sorted(entry['triplets'], key=lambda x: x['relevant'], reverse=True)[:k]
        idcg = sum(
            triplet['relevant'] / math.log2(idx + 2) 
            for idx, triplet in enumerate(ideal_triplets)
        )
        idcg_sum += idcg if idcg > 0 else 1.0  # Avoid division by zero
        
        # Calculate nDCG for the entry
        ndcg = dcg / idcg if idcg > 0 else 0.0
        ndcg_scores.append(ndcg)
    
    average_ndcg = dcg_sum / idcg_sum if idcg_sum > 0 else 0.0
    return average_ndcg, ndcg_scores


def calculate_precision_at_k(data, k):
    """
    Calculates the average Precision at K (P@K) and returns per-entry precision scores.
    
    Parameters:
    - data (List[Dict]): List of entries with 'triplets' sorted by retrieval model.
    - k (int): The rank position to calculate precision up to.
    
    Returns:
    - float: The average P@K score.
    - List[float]: Precision scores for each entry.
    """
    precision_sum = 0.0
    precision_scores = []
    for entry in data:
        triplets = entry['triplets'][:k]
        relevant_count = sum(triplet['relevant'] for triplet in triplets)
        precision = relevant_count / k
        precision_scores.append(precision)
        precision_sum += precision
    average_precision = precision_sum / len(data) if data else 0.0
    return average_precision, precision_scores


# Assuming clean_sorted_data_with_ranking and clean_unsorted_data_with_ranking are defined

# Calculate metrics for sorted data
mrr_sorted, mrr_sorted_list = calculate_mrr(clean_sorted_data_with_ranking)
ndcg_sorted, ndcg_sorted_list = calculate_ndcg(clean_sorted_data_with_ranking, k=28)
precision_at_28_sorted, precision_at_28_sorted_list = calculate_precision_at_k(clean_sorted_data_with_ranking, k=28)
precision_at_14_sorted, precision_at_14_sorted_list = calculate_precision_at_k(clean_sorted_data_with_ranking, k=14)
precision_at_7_sorted, precision_at_7_sorted_list = calculate_precision_at_k(clean_sorted_data_with_ranking, k=7)

# Calculate metrics for unsorted data
mrr_unsorted, mrr_unsorted_list = calculate_mrr(clean_unsorted_data_with_ranking)
ndcg_unsorted, ndcg_unsorted_list = calculate_ndcg(clean_unsorted_data_with_ranking, k=28)
precision_at_28_unsorted, precision_at_28_unsorted_list = calculate_precision_at_k(clean_unsorted_data_with_ranking, k=28)
precision_at_14_unsorted, precision_at_14_unsorted_list = calculate_precision_at_k(clean_unsorted_data_with_ranking, k=14)
precision_at_7_unsorted, precision_at_7_unsorted_list = calculate_precision_at_k(clean_unsorted_data_with_ranking, k=7)

# Print overall metrics
print(f"Mean Reciprocal Rank (MRR) for sorted data: {mrr_sorted:.4f}")
print(f"Mean Reciprocal Rank (MRR) for unsorted data: {mrr_unsorted:.4f}\n")

print(f"Normalized Discounted Cumulative Gain (nDCG@28) for sorted data: {ndcg_sorted:.4f}")
print(f"Normalized Discounted Cumulative Gain (nDCG@28) for unsorted data: {ndcg_unsorted:.4f}\n")

print(f"Precision at 28 (P@28) for sorted data: {precision_at_28_sorted:.4f}")
print(f"Precision at 28 (P@28) for unsorted data: {precision_at_28_unsorted:.4f}\n")

print(f"Precision at 14 (P@14) for sorted data: {precision_at_14_sorted:.4f}")
print(f"Precision at 14 (P@14) for unsorted data: {precision_at_14_unsorted:.4f}\n")

print(f"Precision at 7 (P@7) for sorted data: {precision_at_7_sorted:.4f}")
print(f"Precision at 7 (P@7) for unsorted data: {precision_at_7_unsorted:.4f}")



# print(f"Mean Reciprocal Rank (MRR) for unsorted data: {mrr_score_unsorted:.4f}")
# print(f"Normalized Discounted Cumulative Gain (nDCG@10) for unsorted data: {ndcg_score_unsorted:.4f}")
# print(f"Precision at 10 for unsorted data: {precision_at_10_unsorted:.4f}")




### for d=1
# Mean Reciprocal Rank (MRR) for sorted data: 0.6683
# Mean Reciprocal Rank (MRR) for unsorted data: 0.6565

# Normalized Discounted Cumulative Gain (nDCG@30) for sorted data: 0.7777
# Normalized Discounted Cumulative Gain (nDCG@30) for unsorted data: 0.7554

# Precision at 10 (P@10) for sorted data: 0.1672
# Precision at 10 (P@10) for unsorted data: 0.1603

# Precision at 10 (P@28) for sorted data: 0.0625
# Precision at 10 (P@28) for unsorted data: 0.0653


## fod d=2
# Mean Reciprocal Rank (MRR) for sorted data: 0.5391
# Mean Reciprocal Rank (MRR) for unsorted data: 0.3462

# Normalized Discounted Cumulative Gain (nDCG@30) for sorted data: 0.7100
# Normalized Discounted Cumulative Gain (nDCG@30) for unsorted data: 0.6382

# Precision at 10 (P@10) for sorted data: 0.3147
# Precision at 10 (P@10) for unsorted data: 0.2069

# Precision at 10 (P@28) for sorted data: 0.2069
# Precision at 10 (P@28) for unsorted data: 0.2211

## for d=3
# Mean Reciprocal Rank (MRR) for sorted data: 0.5436
# Mean Reciprocal Rank (MRR) for unsorted data: 0.3024

# Normalized Discounted Cumulative Gain (nDCG@30) for sorted data: 0.7153
# Normalized Discounted Cumulative Gain (nDCG@30) for unsorted data: 0.5326

# Precision at 10 (P@10) for sorted data: 0.3250
# Precision at 10 (P@10) for unsorted data: 0.1250

# Precision at 10 (P@28) for sorted data: 0.1835
# Precision at 10 (P@28) for unsorted data: 0.0988


## for d=4

# Mean Reciprocal Rank (MRR) for sorted data: 0.5574
# Mean Reciprocal Rank (MRR) for unsorted data: 0.2424

# Normalized Discounted Cumulative Gain (nDCG@30) for sorted data: 0.7303
# Normalized Discounted Cumulative Gain (nDCG@30) for unsorted data: 0.5082

# Precision at 10 (P@10) for sorted data: 0.3405
# Precision at 10 (P@10) for unsorted data: 0.1052

# Precision at 10 (P@28) for sorted data: 0.1758
# Precision at 10 (P@28) for unsorted data: 0.0856

## for d=5
# Mean Reciprocal Rank (MRR) for sorted data: 0.6258
# Mean Reciprocal Rank (MRR) for unsorted data: 0.3008

# Normalized Discounted Cumulative Gain (nDCG@30) for sorted data: 0.7430
# Normalized Discounted Cumulative Gain (nDCG@30) for unsorted data: 0.5383

# Precision at 10 (P@10) for sorted data: 0.3431
# Precision at 10 (P@10) for unsorted data: 0.1172

# Precision at 10 (P@28) for sorted data: 0.1564
# Precision at 10 (P@28) for unsorted data: 0.0914

## for d=6
# Mean Reciprocal Rank (MRR) for sorted data: 0.6312
# Mean Reciprocal Rank (MRR) for unsorted data: 0.3415

# Normalized Discounted Cumulative Gain (nDCG@30) for sorted data: 0.7645
# Normalized Discounted Cumulative Gain (nDCG@30) for unsorted data: 0.5265

# Precision at 10 (P@10) for sorted data: 0.3353
# Precision at 10 (P@10) for unsorted data: 0.1043

# Precision at 10 (P@28) for sorted data: 0.1413
# Precision at 10 (P@28) for unsorted data: 0.0674

######################################################################### Evaluations at 28

# d=1
# Mean Reciprocal Rank (MRR) for sorted data: 0.6867
# Mean Reciprocal Rank (MRR) for unsorted data: 0.6819

# Normalized Discounted Cumulative Gain (nDCG@30) for sorted data: 0.7910
# Normalized Discounted Cumulative Gain (nDCG@30) for unsorted data: 0.7751

# Precision at 10 (P@) for sorted data: 0.0625
# Precision at 10 (P@) for unsorted data: 0.0653


# d=2
# Mean Reciprocal Rank (MRR) for sorted data: 0.5443
# Mean Reciprocal Rank (MRR) for unsorted data: 0.3714

# Normalized Discounted Cumulative Gain (nDCG@30) for sorted data: 0.7407
# Normalized Discounted Cumulative Gain (nDCG@30) for unsorted data: 0.6643

# Precision at 10 (P@) for sorted data: 0.2069
# Precision at 10 (P@) for unsorted data: 0.2211

# d=3
# Mean Reciprocal Rank (MRR) for sorted data: 0.5436
# Mean Reciprocal Rank (MRR) for unsorted data: 0.3024

# Normalized Discounted Cumulative Gain (nDCG@30) for sorted data: 0.7153
# Normalized Discounted Cumulative Gain (nDCG@30) for unsorted data: 0.5290

# Precision at 10 (P@) for sorted data: 0.1835
# Precision at 10 (P@) for unsorted data: 0.0988

# d=4
# Mean Reciprocal Rank (MRR) for sorted data: 0.5574
# Mean Reciprocal Rank (MRR) for unsorted data: 0.2424

# Normalized Discounted Cumulative Gain (nDCG@30) for sorted data: 0.7303
# Normalized Discounted Cumulative Gain (nDCG@30) for unsorted data: 0.5027

# Precision at 10 (P@) for sorted data: 0.1758
# Precision at 10 (P@) for unsorted data: 0.0856

# d=5
# Mean Reciprocal Rank (MRR) for sorted data: 0.6258
# Mean Reciprocal Rank (MRR) for unsorted data: 0.3008

# Normalized Discounted Cumulative Gain (nDCG@30) for sorted data: 0.7430
# Normalized Discounted Cumulative Gain (nDCG@30) for unsorted data: 0.5336

# Precision at 10 (P@) for sorted data: 0.1564
# Precision at 10 (P@) for unsorted data: 0.0914


# d=6
# Mean Reciprocal Rank (MRR) for sorted data: 0.6312
# Mean Reciprocal Rank (MRR) for unsorted data: 0.3415

# Normalized Discounted Cumulative Gain (nDCG@30) for sorted data: 0.7645
# Normalized Discounted Cumulative Gain (nDCG@30) for unsorted data: 0.5183

# Precision at 10 (P@) for sorted data: 0.1413
# Precision at 10 (P@) for unsorted data: 0.0674

############################################################ Correct Version ############################################

# d=1

# Mean Reciprocal Rank (MRR) for sorted data: 0.6867
# Mean Reciprocal Rank (MRR) for unsorted data: 0.6819

# Normalized Discounted Cumulative Gain (nDCG@28) for sorted data: 0.7910
# Normalized Discounted Cumulative Gain (nDCG@28) for unsorted data: 0.7751

# Precision at 28 (P@28) for sorted data: 0.0625
# Precision at 28 (P@28) for unsorted data: 0.0653

# Precision at 14 (P@14) for sorted data: 0.1250
# Precision at 14 (P@14) for unsorted data: 0.1244

# Precision at 7 (P@7) for sorted data: 0.2438
# Precision at 7 (P@7) for unsorted data: 0.2303

# d=2

# Mean Reciprocal Rank (MRR) for sorted data: 0.5443
# Mean Reciprocal Rank (MRR) for unsorted data: 0.3714

# Normalized Discounted Cumulative Gain (nDCG@28) for sorted data: 0.7407
# Normalized Discounted Cumulative Gain (nDCG@28) for unsorted data: 0.6643

# Precision at 28 (P@28) for sorted data: 0.2069
# Precision at 28 (P@28) for unsorted data: 0.2211

# Precision at 14 (P@14) for sorted data: 0.3140
# Precision at 14 (P@14) for unsorted data: 0.2463

# Precision at 7 (P@7) for sorted data: 0.3695
# Precision at 7 (P@7) for unsorted data: 0.2537

# d=3
# Mean Reciprocal Rank (MRR) for sorted data: 0.5436
# Mean Reciprocal Rank (MRR) for unsorted data: 0.3024

# Normalized Discounted Cumulative Gain (nDCG@28) for sorted data: 0.7153
# Normalized Discounted Cumulative Gain (nDCG@28) for unsorted data: 0.5290

# Precision at 28 (P@28) for sorted data: 0.1835
# Precision at 28 (P@28) for unsorted data: 0.0988

# Precision at 14 (P@14) for sorted data: 0.2888
# Precision at 14 (P@14) for unsorted data: 0.1207

# Precision at 7 (P@7) for sorted data: 0.3461
# Precision at 7 (P@7) for unsorted data: 0.1379

# d=4
# Mean Reciprocal Rank (MRR) for sorted data: 0.5574
# Mean Reciprocal Rank (MRR) for unsorted data: 0.2424

# Normalized Discounted Cumulative Gain (nDCG@28) for sorted data: 0.7303
# Normalized Discounted Cumulative Gain (nDCG@28) for unsorted data: 0.5027

# Precision at 28 (P@28) for sorted data: 0.1758
# Precision at 28 (P@28) for unsorted data: 0.0856

# Precision at 14 (P@14) for sorted data: 0.3060
# Precision at 14 (P@14) for unsorted data: 0.0961

# Precision at 7 (P@7) for sorted data: 0.3621
# Precision at 7 (P@7) for unsorted data: 0.1182

# d=5
# Mean Reciprocal Rank (MRR) for sorted data: 0.6258
# Mean Reciprocal Rank (MRR) for unsorted data: 0.3008

# Normalized Discounted Cumulative Gain (nDCG@28) for sorted data: 0.7430
# Normalized Discounted Cumulative Gain (nDCG@28) for unsorted data: 0.5336

# Precision at 28 (P@28) for sorted data: 0.1564
# Precision at 28 (P@28) for unsorted data: 0.0914

# Precision at 14 (P@14) for sorted data: 0.2876
# Precision at 14 (P@14) for unsorted data: 0.1084

# Precision at 7 (P@7) for sorted data: 0.3793
# Precision at 7 (P@7) for unsorted data: 0.1404

# d=6

# Mean Reciprocal Rank (MRR) for sorted data: 0.6312
# Mean Reciprocal Rank (MRR) for unsorted data: 0.3415

# Normalized Discounted Cumulative Gain (nDCG@28) for sorted data: 0.7645
# Normalized Discounted Cumulative Gain (nDCG@28) for unsorted data: 0.5183

# Precision at 28 (P@28) for sorted data: 0.1413
# Precision at 28 (P@28) for unsorted data: 0.0674

# Precision at 14 (P@14) for sorted data: 0.2672
# Precision at 14 (P@14) for unsorted data: 0.0924

# Precision at 7 (P@7) for sorted data: 0.4064
# Precision at 7 (P@7) for unsorted data: 0.1207
# Out:
# Mean Reciprocal Rank (MRR) for sorted data: 0.6312
# Mean Reciprocal Rank (MRR) for unsorted data: 0.3415
#
# Normalized Discounted Cumulative Gain (nDCG@28) for sorted data: 0.7645
# Normalized Discounted Cumulative Gain (nDCG@28) for unsorted data: 0.5183
#
# Precision at 28 (P@28) for sorted data: 0.1413
# Precision at 28 (P@28) for unsorted data: 0.0674
#
# Precision at 14 (P@14) for sorted data: 0.2672
# Precision at 14 (P@14) for unsorted data: 0.0924
#
# Precision at 7 (P@7) for sorted data: 0.4064
# Precision at 7 (P@7) for unsorted data: 0.1207

# %%
import matplotlib.pyplot as plt

# Data for each metric including values for d=5 and d=6
d_values = [1, 2, 3, 4, 5, 6]
metrics_data = {
    "MRR": {
        "sorted": [0.6683, 0.5391, 0.5436, 0.5574, 0.6258, 0.6312],
        "unsorted": [0.6565, 0.3462, 0.3024, 0.2424, 0.3008, 0.3415]
    },
    "nDCG@30": {
        "sorted": [0.7777, 0.7100, 0.7153, 0.7303, 0.7430, 0.7645],
        "unsorted": [0.7554, 0.6382, 0.5326, 0.5082, 0.5383, 0.5265]
    },
    "P@10": {
        "sorted": [0.1672, 0.3147, 0.3250, 0.3405, 0.3431, 0.3353],
        "unsorted": [0.1603, 0.2069, 0.1250, 0.1052, 0.1172, 0.1043]
    }
}

# Colors for lines
sorted_color = '#1f77b4'  # Blue
unsorted_color = '#ff7f0e'  # Orange

# Create a figure with a 1x3 grid for the plots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
fig.subplots_adjust(hspace=0.3, wspace=0.4)

# Plot each metric in a subplot
for ax, (metric, values) in zip(axes, metrics_data.items()):
    ax.plot(d_values, values["sorted"], marker='o', color=sorted_color, label="CSMR", linestyle="-")
    ax.plot(d_values, values["unsorted"], marker='o', color=unsorted_color, label="Original", linestyle="--")
    ax.set_title(f"{metric}", fontsize=14)
    ax.set_xlabel(r"Neighbor depth $\mathit{d}$", fontsize=12)
    ax.set_ylabel(metric, fontsize=12)
    ax.grid(True)
    
    # Add labels to each point
    for i, d in enumerate(d_values):
        ax.text(d, values["sorted"][i], f"{values['sorted'][i]:.4f}", ha="center", va="bottom", fontsize=10)
        ax.text(d, values["unsorted"][i], f"{values['unsorted'][i]:.4f}", ha="center", va="bottom", fontsize=10)

# Add a shared legend
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc="upper center", ncol=3, fontsize=12, title="SP-CoT - Node Retrieval Evaluation", title_fontsize=13, bbox_to_anchor=(0.5, 1.05))

plt.show()

# %%
import matplotlib.pyplot as plt

# Data for each metric including values for d=1 to d=6
d_values = [1, 2, 3, 4, 5, 6]
metrics_data = {
    "MRR": {
        "sorted": [0.6867, 0.5443, 0.5436, 0.5574, 0.6258, 0.6312],
        "unsorted": [0.6819, 0.3714, 0.3024, 0.2424, 0.3008, 0.3415]
    },
    "nDCG@28": {
        "sorted": [0.7910, 0.7407, 0.7153, 0.7303, 0.7430, 0.7645],
        "unsorted": [0.7751, 0.6643, 0.5290, 0.5027, 0.5336, 0.5183]
    },
    "P@28": {
        "sorted": [0.0625, 0.2069, 0.1835, 0.1758, 0.1564, 0.1413],
        "unsorted": [0.0653, 0.2211, 0.0988, 0.0856, 0.0914, 0.0674]
    },
    "P@14": {
        "sorted": [0.1250, 0.3140, 0.2888, 0.3060, 0.2876, 0.2672],
        "unsorted": [0.1244, 0.2463, 0.1207, 0.0961, 0.1084, 0.0924]
    },
    "P@7": {
        "sorted": [0.2438, 0.3695, 0.3461, 0.3621, 0.3793, 0.4064],
        "unsorted": [0.2303, 0.2537, 0.1379, 0.1182, 0.1404, 0.1207]
    }
}

# Colors for lines
sorted_color = '#1f77b4'  # Blue
unsorted_color = '#ff7f0e'  # Orange

# Set global font size (increase for bigger text)
plt.rcParams.update({
    'font.size': 22,
    'axes.titlesize': 28,
    'axes.labelsize': 26,
    'xtick.labelsize': 22,
    'ytick.labelsize': 22,
    'legend.fontsize': 24,
    'legend.title_fontsize': 28
})

# Create a figure with a 2x3 grid for the plots
fig, axes = plt.subplots(2, 3, figsize=(30, 14))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

# Assign specific axes for each metric
mrr_ax = axes[0, 0]
ndcg_ax = axes[0, 1]
p28_ax = axes[1, 0]
p14_ax = axes[1, 1]
p7_ax = axes[1, 2]

# Define metrics and their corresponding axes
metric_axes = {
    "MRR": mrr_ax,
    "nDCG@28": ndcg_ax,
    "P@28": p28_ax,
    "P@14": p14_ax,
    "P@7": p7_ax
}

# Plot each metric in its assigned subplot
for metric, ax in metric_axes.items():
    values = metrics_data[metric]
    ax.plot(d_values, values["sorted"], marker='o', color=sorted_color, label="CSMR", linestyle="-")
    ax.plot(d_values, values["unsorted"], marker='o', color=unsorted_color, label="Original", linestyle="--")
    ax.set_title(f"{metric}", fontsize=28)
    ax.set_xlabel(r"Neighbor depth $\mathit{d}$", fontsize=26)
    ax.set_ylabel(metric, fontsize=26)
    ax.grid(True)
    ax.tick_params(axis='both', which='major', labelsize=22)

# Add a shared legend in the empty upper-right subplot space
handles, labels = mrr_ax.get_legend_handles_labels()
fig.legend(handles, labels, loc="center right", ncol=1, fontsize=24, title="SP-CoT - Node Retrieval Evaluation", title_fontsize=28, bbox_to_anchor=(.88, 0.75))

# Hide the empty subplot in the top middle (axes[0, 2])
fig.delaxes(axes[0, 2])

plt.show()

# %%
import matplotlib.pyplot as plt

# Data for each metric including values for d=1 to d=6
d_values = [1, 2, 3, 4, 5, 6]
metrics_data = {
    "MRR": {
        "sorted": [0.6867, 0.5443, 0.5436, 0.5574, 0.6258, 0.6312],
        "unsorted": [0.6819, 0.3714, 0.3024, 0.2424, 0.3008, 0.3415]
    },
    "nDCG@28": {
        "sorted": [0.7910, 0.7407, 0.7153, 0.7303, 0.7430, 0.7645],
        "unsorted": [0.7751, 0.6643, 0.5290, 0.5027, 0.5336, 0.5183]
    },
    "P@28": {
        "sorted": [0.0625, 0.2069, 0.1835, 0.1758, 0.1564, 0.1413],
        "unsorted": [0.0653, 0.2211, 0.0988, 0.0856, 0.0914, 0.0674]
    },
    "P@14": {
        "sorted": [0.1250, 0.3140, 0.2888, 0.3060, 0.2876, 0.2672],
        "unsorted": [0.1244, 0.2463, 0.1207, 0.0961, 0.1084, 0.0924]
    }
}

# Colors for lines
sorted_color = '#1f77b4'  # Blue
unsorted_color = '#ff7f0e'  # Orange

# Create a figure with a 1x4 grid for the plots
fig, axes = plt.subplots(1, 4, figsize=(24, 6))
fig.subplots_adjust(hspace=0.3, wspace=0.4)

# Font size settings
title_fontsize = 18
label_fontsize = 16
tick_fontsize = 14
legend_fontsize = 16
legend_title_fontsize = 18

# Plot each metric in a subplot
for ax, (metric, values) in zip(axes, metrics_data.items()):
    ax.plot(d_values, values["sorted"], marker='o', color=sorted_color, label="CSMR", linestyle="-")
    ax.plot(d_values, values["unsorted"], marker='o', color=unsorted_color, label="Original", linestyle="--")
    ax.set_title(f"{metric}", fontsize=title_fontsize)
    ax.set_xlabel(r"Neighbor depth $\mathit{d}$", fontsize=label_fontsize)
    ax.set_ylabel(metric, fontsize=label_fontsize)
    ax.grid(True)
    
    # Increase the font size for the axis ticks
    ax.tick_params(axis='both', which='major', labelsize=tick_fontsize)

# Add a shared legend
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc="upper center", ncol=4, fontsize=legend_fontsize, title="SP-CoT - Node Retrieval Evaluation", title_fontsize=legend_title_fontsize, bbox_to_anchor=(0.5, 1.1))

plt.show()

# %%
# # Store per-entry metrics in dictionaries
# metrics_sorted = {
#     'mrr': mrr_sorted_list,
#     'ndcg': ndcg_sorted_list,
#     'precision_at_10': precision_at_10_sorted_list
# }

# metrics_unsorted = {
#     'mrr': mrr_unsorted_list,
#     'ndcg': ndcg_unsorted_list,
#     'precision_at_10': precision_at_10_unsorted_list
# }

# # Example: Saving to JSON for later use
# import json

# with open('metrics_sorted.json', 'w') as f:
#     json.dump(metrics_sorted, f, indent=4)

# with open('metrics_unsorted.json', 'w') as f:
#     json.dump(metrics_unsorted, f, indent=4)

# print("\nPer-entry metrics have been saved to 'metrics_sorted.json' and 'metrics_unsorted.json'.")

# Store per-entry metrics in dictionaries
metrics_sorted = {
    'mrr': mrr_sorted_list,
    'ndcg': ndcg_sorted_list,
    'precision_at_28': precision_at_28_sorted_list,
    'precision_at_14': precision_at_14_sorted_list,
    'precision_at_7': precision_at_7_sorted_list
}

metrics_unsorted = {
    'mrr': mrr_unsorted_list,
    'ndcg': ndcg_unsorted_list,
    'precision_at_28': precision_at_28_unsorted_list,
    'precision_at_14': precision_at_14_unsorted_list,
    'precision_at_7': precision_at_7_unsorted_list
}

# Example: Saving to JSON for later use
import json

with open('metrics_sorted.json', 'w') as f:
    json.dump(metrics_sorted, f, indent=4)

with open('metrics_unsorted.json', 'w') as f:
    json.dump(metrics_unsorted, f, indent=4)

print("\nPer-entry metrics have been saved to 'metrics_sorted.json' and 'metrics_unsorted.json'.")
# Out:
# Per-entry metrics have been saved to 'metrics_sorted.json' and 'metrics_unsorted.json'.

# %%
# Perform paired t-tests
from scipy import stats

# Load the saved metrics
with open('metrics_sorted.json', 'r') as f:
    metrics_sorted = json.load(f)

with open('metrics_unsorted.json', 'r') as f:
    metrics_unsorted = json.load(f)

# Convert lists to appropriate formats (if needed)
mrr_sorted = metrics_sorted['mrr']
mrr_unsorted = metrics_unsorted['mrr']

ndcg_sorted = metrics_sorted['ndcg']
ndcg_unsorted = metrics_unsorted['ndcg']

precision_sorted = metrics_sorted['precision_at_10']
precision_unsorted = metrics_unsorted['precision_at_10']

# Perform paired t-tests
mrr_ttest = stats.ttest_rel(mrr_sorted, mrr_unsorted)
ndcg_ttest = stats.ttest_rel(ndcg_sorted, ndcg_unsorted)
precision_ttest = stats.ttest_rel(precision_sorted, precision_unsorted)

# Print t-test results in scientific notation
print("\nPaired t-test Results:")
print(f"MRR: t-statistic = {mrr_ttest.statistic:.4f}, p-value = {mrr_ttest.pvalue:.4e}")
print(f"nDCG@30: t-statistic = {ndcg_ttest.statistic:.4f}, p-value = {ndcg_ttest.pvalue:.4e}")
print(f"P@10: t-statistic = {precision_ttest.statistic:.4f}, p-value = {precision_ttest.pvalue:.4e}")


# d1
# Paired t-test Results:
# MRR: t-statistic = 0.7974, p-value = 4.2688e-01
# nDCG@30: t-statistic = 0.7745, p-value = 4.4020e-01
# P@10: t-statistic = 1.5790, p-value = 1.1708e-01


# Paired t-test Results:
# MRR: t-statistic = 10.4245, p-value = 1.3979e-20
# nDCG@30: t-statistic = 13.1206, p-value = 9.5977e-29
# P@10: t-statistic = 11.1749, p-value = 8.0973e-23


# d3
# Paired t-test Results:
# MRR: t-statistic = 6.1405, p-value = 1.2079e-08
# nDCG@30: t-statistic = 9.4291, p-value = 5.5436e-16
# P@10: t-statistic = 8.7185, p-value = 2.4803e-14


# d4
# Paired t-test Results:
# MRR: t-statistic = 7.5541, p-value = 1.0988e-11
# nDCG@30: t-statistic = 9.8536, p-value = 5.6330e-17
# P@10: t-statistic = 10.6412, p-value = 7.9864e-19
# Out:
# Paired t-test Results:
# MRR: t-statistic = 7.3830, p-value = 2.6373e-11
# nDCG@30: t-statistic = 8.3934, p-value = 1.3872e-13
# P@10: t-statistic = 9.9582, p-value = 3.2028e-17

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming metrics_sorted and metrics_unsorted are dictionaries containing the per-query metrics
# Create DataFrames for each metric
df_mrr = pd.DataFrame({
    'Condition': ['Sorted'] * len(metrics_sorted['mrr']) + ['Unsorted'] * len(metrics_unsorted['mrr']),
    'MRR': metrics_sorted['mrr'] + metrics_unsorted['mrr']
})

df_ndcg = pd.DataFrame({
    'Condition': ['Sorted'] * len(metrics_sorted['ndcg']) + ['Unsorted'] * len(metrics_unsorted['ndcg']),
    'nDCG@30': metrics_sorted['ndcg'] + metrics_unsorted['ndcg']
})

df_p_at_k = pd.DataFrame({
    'Condition': ['Sorted'] * len(metrics_sorted['precision_at_10']) + ['Unsorted'] * len(metrics_unsorted['precision_at_10']),
    'P@10': metrics_sorted['precision_at_10'] + metrics_unsorted['precision_at_10']
})

# Create DataFrames for differences between sorted and unsorted for each metric
df_diff_mrr = pd.DataFrame({
    'Difference (MRR)': [sorted_val - unsorted_val for sorted_val, unsorted_val in zip(metrics_sorted['mrr'], metrics_unsorted['mrr'])]
})

df_diff_ndcg = pd.DataFrame({
    'Difference (nDCG@30)': [sorted_val - unsorted_val for sorted_val, unsorted_val in zip(metrics_sorted['ndcg'], metrics_unsorted['ndcg'])]
})

df_diff_p_at_k = pd.DataFrame({
    'Difference (P@10)': [sorted_val - unsorted_val for sorted_val, unsorted_val in zip(metrics_sorted['precision_at_10'], metrics_unsorted['precision_at_10'])]
})

# Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Initialize the matplotlib figure with 2 rows and 3 columns
fig, axes = plt.subplots(2, 3, figsize=(21, 12))

# Define a color palette
palette = {"Sorted": "skyblue", "Unsorted": "salmon"}

# Plot MRR Histogram
sns.histplot(data=df_mrr, x='MRR', hue='Condition', element='step', stat='density',
             common_norm=False, palette=palette, ax=axes[0, 0])
axes[0, 0].set_title('Mean Reciprocal Rank (MRR)', fontsize=14)
axes[0, 0].set_xlabel('MRR', fontsize=12)
axes[0, 0].set_ylabel('Density', fontsize=12)

# Plot nDCG@30 Histogram
sns.histplot(data=df_ndcg, x='nDCG@30', hue='Condition', element='step', stat='density',
             common_norm=False, palette=palette, ax=axes[0, 1])
axes[0, 1].set_title('Normalized Discounted Cumulative Gain (nDCG@30)', fontsize=14)
axes[0, 1].set_xlabel('nDCG@30', fontsize=12)
axes[0, 1].set_ylabel('Density', fontsize=12)

# Plot Precision@10 Histogram
sns.histplot(data=df_p_at_k, x='P@10', hue='Condition', element='step', stat='density',
             common_norm=False, palette=palette, ax=axes[0, 2])
axes[0, 2].set_title('Precision at 10 (P@10)', fontsize=14)
axes[0, 2].set_xlabel('P@10', fontsize=12)
axes[0, 2].set_ylabel('Density', fontsize=12)

# Plot Differences MRR
sns.histplot(data=df_diff_mrr, x='Difference (MRR)', kde=True, color="purple", ax=axes[1, 0])
axes[1, 0].set_title('Difference (MRR)', fontsize=14)
axes[1, 0].set_xlabel('Difference (MRR)', fontsize=12)
axes[1, 0].set_ylabel('Density', fontsize=12)

# Plot Differences nDCG@30
sns.histplot(data=df_diff_ndcg, x='Difference (nDCG@30)', kde=True, color="green", ax=axes[1, 1])
axes[1, 1].set_title('Difference (nDCG@30)', fontsize=14)
axes[1, 1].set_xlabel('Difference (nDCG@30)', fontsize=12)
axes[1, 1].set_ylabel('Density', fontsize=12)

# Plot Differences P@10
sns.histplot(data=df_diff_p_at_k, x='Difference (P@10)', kde=True, color="orange", ax=axes[1, 2])
axes[1, 2].set_title('Difference (P@10)', fontsize=14)
axes[1, 2].set_xlabel('Difference (P@10)', fontsize=12)
axes[1, 2].set_ylabel('Density', fontsize=12)

# Adjust layout
plt.tight_layout()

# Display the plots
plt.show()

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt

# Calculate differences for each metric
differences_mrr = [sorted_val - unsorted_val for sorted_val, unsorted_val in zip(metrics_sorted['mrr'], metrics_unsorted['mrr'])]
differences_ndcg = [sorted_val - unsorted_val for sorted_val, unsorted_val in zip(metrics_sorted['ndcg'], metrics_unsorted['ndcg'])]
differences_p_at_28 = [sorted_val - unsorted_val for sorted_val, unsorted_val in zip(metrics_sorted['precision_at_28'], metrics_unsorted['precision_at_28'])]
differences_p_at_14 = [sorted_val - unsorted_val for sorted_val, unsorted_val in zip(metrics_sorted['precision_at_14'], metrics_unsorted['precision_at_14'])]
differences_p_at_7 = [sorted_val - unsorted_val for sorted_val, unsorted_val in zip(metrics_sorted['precision_at_7'], metrics_unsorted['precision_at_7'])]

# Perform Shapiro-Wilk test for each metric
shapiro_mrr = stats.shapiro(differences_mrr)
shapiro_ndcg = stats.shapiro(differences_ndcg)
shapiro_p_at_28 = stats.shapiro(differences_p_at_28)
shapiro_p_at_14 = stats.shapiro(differences_p_at_14)
shapiro_p_at_14 = stats.shapiro(differences_p_at_7)

print(f"Shapiro-Wilk test for MRR differences: p-value = {shapiro_mrr.pvalue:.4f}")
print(f"Shapiro-Wilk test for nDCG@28 differences: p-value = {shapiro_ndcg.pvalue:.4f}")
print(f"Shapiro-Wilk test for P@28 differences: p-value = {shapiro_p_at_28.pvalue:.4f}")
print(f"Shapiro-Wilk test for P@14 differences: p-value = {shapiro_p_at_14.pvalue:.4f}")
print(f"Shapiro-Wilk test for P@7 differences: p-value = {shapiro_p_at_14.pvalue:.4f}")

# Q-Q plot for MRR differences
plt.figure(figsize=(6, 6))
stats.probplot(differences_mrr, dist="norm", plot=plt)
plt.title("Q-Q Plot for MRR Differences")
plt.show()

# Q-Q plot for nDCG@28 differences
plt.figure(figsize=(6, 6))
stats.probplot(differences_ndcg, dist="norm", plot=plt)
plt.title("Q-Q Plot for nDCG@28 Differences")
plt.show()

# Q-Q plot for P@28 differences
plt.figure(figsize=(6, 6))
stats.probplot(differences_p_at_28, dist="norm", plot=plt)
plt.title("Q-Q Plot for P@28 Differences")
plt.show()

# Q-Q plot for P@14 differences
plt.figure(figsize=(6, 6))
stats.probplot(differences_p_at_14, dist="norm", plot=plt)
plt.title("Q-Q Plot for P@14 Differences")
plt.show()
# Out:
# Shapiro-Wilk test for MRR differences: p-value = 0.0000
# Shapiro-Wilk test for nDCG@28 differences: p-value = 0.0001
# Shapiro-Wilk test for P@28 differences: p-value = 0.0000
# Shapiro-Wilk test for P@14 differences: p-value = 0.0023
# Shapiro-Wilk test for P@7 differences: p-value = 0.0023

# %%
# # Perform Wilcoxon signed-rank test for each metric
# wilcoxon_mrr = stats.wilcoxon(differences_mrr)
# wilcoxon_ndcg = stats.wilcoxon(differences_ndcg)
# wilcoxon_p_at_k = stats.wilcoxon(differences_p_at_k)

# print(f"Wilcoxon test for MRR differences: p-value = {wilcoxon_mrr.pvalue}")
# print(f"Wilcoxon test for nDCG differences: p-value = {wilcoxon_ndcg.pvalue}")
# print(f"Wilcoxon test for P@10 differences: p-value = {wilcoxon_p_at_k.pvalue}")

from statsmodels.stats.descriptivestats import sign_test

# Perform Sign test for each metric
sign_test_mrr = sign_test(differences_mrr, mu0=0)
sign_test_ndcg = sign_test(differences_ndcg, mu0=0)
sign_test_p_at_28 = sign_test(differences_p_at_28, mu0=0)
sign_test_p_at_14 = sign_test(differences_p_at_14, mu0=0)
sign_test_p_at_7 = sign_test(differences_p_at_7, mu0=0)

# Print the results
print(f"Sign test for MRR differences: Test Statistic = {sign_test_mrr[0]:.4f}, p-value = {sign_test_mrr[1]:.4e}")
print(f"Sign test for nDCG@28 differences: Test Statistic = {sign_test_ndcg[0]:.4f}, p-value = {sign_test_ndcg[1]:.4e}")
print(f"Sign test for P@28 differences: Test Statistic = {sign_test_p_at_28[0]:.4f}, p-value = {sign_test_p_at_28[1]:.4e}")
print(f"Sign test for P@14 differences: Test Statistic = {sign_test_p_at_14[0]:.4f}, p-value = {sign_test_p_at_14[1]:.4e}")
print(f"Sign test for P@7 differences: Test Statistic = {sign_test_p_at_7[0]:.4f}, p-value = {sign_test_p_at_7[1]:.4e}")




# d = 1
# Wilcoxon test for MRR differences: p-value = 0.5044584038016553
# Wilcoxon test for nDCG differences: p-value = 0.3792364621156361
# Wilcoxon test for P@10 differences: p-value = 0.2013932544395831


#d = 2
# Wilcoxon test for MRR differences: p-value = 7.31132001922349e-08
# Wilcoxon test for nDCG differences: p-value = 4.491108753257627e-10
# Wilcoxon test for P@10 differences: p-value = 3.693019733242788e-05

# d = 3
# Wilcoxon test for MRR differences: p-value = 3.186956416606478e-10
# Wilcoxon test for nDCG differences: p-value = 1.975315090321478e-13
# Wilcoxon test for P@10 differences: p-value = 1.5008206317894912e-12

# d = 4
# Wilcoxon test for MRR differences: p-value = 1.923540673436064e-11
# Wilcoxon test for nDCG differences: p-value = 1.4080133650236824e-13
# Wilcoxon test for P@10 differences: p-value = 5.136686916377891e-15

# d = 5
# Wilcoxon test for MRR differences: p-value = 1.2791602829341168e-10
# Wilcoxon test for nDCG differences: p-value = 2.294128253214051e-11
# Wilcoxon test for P@10 differences: p-value = 3.5074804711694975e-14


####################### Correct Version ############################
#d = 1
# Sign test for MRR differences: Test Statistic = 1.0000, p-value = 7.5391e-01
# Sign test for nDCG@28 differences: Test Statistic = 2.0000, p-value = 4.2395e-01
# Sign test for P@28 differences: Test Statistic = -1.5000, p-value = 3.7500e-01
# Sign test for P@14 differences: Test Statistic = 0.0000, p-value = 1.0000e+00
# Sign test for P@7 differences: Test Statistic = 2.0000, p-value = 2.8906e-01

# d = 2
# Sign test for MRR differences: Test Statistic = 27.5000, p-value = 1.0540e-10
# Sign test for nDCG@28 differences: Test Statistic = 32.0000, p-value = 1.6381e-10
# Sign test for P@28 differences: Test Statistic = 4.0000, p-value = 4.7049e-01
# Sign test for P@14 differences: Test Statistic = 23.5000, p-value = 5.9867e-07
#Sign test for P@7 differences: Test Statistic = 23.5000, p-value = 7.5558e-09

# d = 3
# Sign test for MRR differences: Test Statistic = 31.5000, p-value = 5.8007e-13
# Sign test for nDCG@28 differences: Test Statistic = 34.5000, p-value = 8.4813e-12
# Sign test for P@28 differences: Test Statistic = 30.5000, p-value = 1.6180e-09
# Sign test for P@14 differences: Test Statistic = 36.0000, p-value = 1.6534e-13
# Sign test for P@7 differences: Test Statistic = 34.0000, p-value = 1.3411e-14

# d = 4
# Sign test for MRR differences: Test Statistic = 34.5000, p-value = 7.4671e-15
# Sign test for nDCG@28 differences: Test Statistic = 35.5000, p-value = 1.7810e-12
# Sign test for P@28 differences: Test Statistic = 36.5000, p-value = 3.5058e-13
# Sign test for P@14 differences: Test Statistic = 44.0000, p-value = 8.9034e-20
# Sign test for P@7 differences: Test Statistic = 41.0000, p-value = 4.3245e-21


# d = 5
# Sign test for MRR differences: Test Statistic = 31.5000, p-value = 1.2888e-12
# Sign test for nDCG@28 differences: Test Statistic = 31.5000, p-value = 9.5931e-10
# Sign test for P@28 differences: Test Statistic = 31.0000, p-value = 6.6760e-10
# Sign test for P@14 differences: Test Statistic = 37.5000, p-value = 7.5206e-15
# Sign test for P@7 differences: Test Statistic = 37.5000, p-value = 7.5206e-15

# d = 6
# Sign test for MRR differences: Test Statistic = 24.5000, p-value = 1.2352e-07
# Sign test for nDCG@28 differences: Test Statistic = 22.0000, p-value = 2.7608e-05
# Sign test for P@28 differences: Test Statistic = 35.0000, p-value = 9.1347e-13
# Sign test for P@14 differences: Test Statistic = 40.0000, p-value = 3.0633e-17
# Sign test for P@7 differences: Test Statistic = 39.0000, p-value = 1.2362e-17
# Out:
# Sign test for MRR differences: Test Statistic = 24.5000, p-value = 1.2352e-07
# Sign test for nDCG@28 differences: Test Statistic = 22.0000, p-value = 2.7608e-05
# Sign test for P@28 differences: Test Statistic = 35.0000, p-value = 9.1347e-13
# Sign test for P@14 differences: Test Statistic = 40.0000, p-value = 3.0633e-17
# Sign test for P@7 differences: Test Statistic = 39.0000, p-value = 1.2362e-17
