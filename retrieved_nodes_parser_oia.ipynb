# %% [markdown]
# # Parsed the files that contain the retrieved nodes for the different methods and prepares them to be anotated by chatgpt

# %%
sorted_path = 'Retrieved Nodes Original/full_sorted_k4_d6/'
unsorted_path = 'Retrieved Nodes Original/full_unsorted_k4_d6'

# %%
import os
import re

def parse_files_in_directory(directory_path):
    parsed_data_list = []
    triplet_pattern = re.compile(r'\[(.*?)\]: (.*?) --\[(.*?)\]-> (.*?) ([0-9.]+)')

    # Get all filenames in the directory
    filenames = [f for f in os.listdir(directory_path) if os.path.isfile(os.path.join(directory_path, f))]

    # Filter filenames that match the pattern 'n.txt' where n is an integer
    file_pattern = re.compile(r'(\d+)\.txt$')
    numbered_files = []
    for f in filenames:
        match = file_pattern.match(f)
        if match:
            number = int(match.group(1))
            numbered_files.append((number, f))

    # Sort the files based on the extracted number
    numbered_files.sort(key=lambda x: x[0])

    # Process files in the sorted order
    for number, filename in numbered_files:
        filepath = os.path.join(directory_path, filename)

        # Try reading the file with UTF-8 encoding
        try:
            with open(filepath, 'r', encoding='utf-8') as file:
                lines = [line.strip() for line in file if line.strip()]
        except UnicodeDecodeError:
            # Fall back to Latin-1 encoding if UTF-8 fails
            with open(filepath, 'r', encoding='latin-1') as file:
                lines = [line.strip() for line in file if line.strip()]
        except Exception as e:
            print(f"Error reading file {filename}: {e}")
            continue

        if not lines:
            continue

        iterator = iter(lines)
        data = {'question': None, 'seeds': [], 'triplets': []}

        try:
            # Extract the question
            data['question'] = next(iterator)

            # Skip the 'None' line if it exists
            current_line = next(iterator)
            if current_line.lower() == 'none':
                pass
            else:
                # If 'None' line is missing, we need to process the current line
                if current_line.startswith('Seed:'):
                    data['seeds'].append(current_line[len('Seed:'):].strip())
                else:
                    # If the line is not a seed, reset the iterator
                    iterator = iter([current_line] + list(iterator))

            # Extract seed nodes
            for line in iterator:
                if line.startswith('Seed:'):
                    data['seeds'].append(line[len('Seed:'):].strip())
                else:
                    # Break if the line doesn't start with 'Seed:'
                    break

            # Extract triplets
            for line in iterator:
                match = triplet_pattern.match(line)
                if match:
                    data['triplets'].append({
                        'seed': match.group(1),
                        'head': match.group(2),
                        'relation': match.group(3),
                        'tail': match.group(4),
                        'score': float(match.group(5))
                    })
        except StopIteration:
            pass  # Handle files that may not have complete content

        parsed_data_list.append(data)

    return parsed_data_list

# %%
parsed_sorted_data = parse_files_in_directory(sorted_path)
parsed_unsorted_data = parse_files_in_directory(unsorted_path)

# %%
def create_clean_entry(entry):
    clean_entry = {'question': entry['question'], 'triplets': []}
    seen_triplets = set()

    for triplet in entry.get('triplets', []):
        # Create a tuple of (head, relation, tail) to identify duplicates
        triplet_key = (triplet['head'], triplet['relation'], triplet['tail'])

        if triplet_key not in seen_triplets:
            seen_triplets.add(triplet_key)
            # Exclude the 'seed' key, and create an 'id' from head-relation-tail
            clean_triplet = {
                'head': triplet['head'],
                'relation': triplet['relation'],
                'tail': triplet['tail'],
                'score': triplet['score'],
                'id': f"{triplet['head']}-{triplet['relation']}-{triplet['tail']}"
            }
            clean_entry['triplets'].append(clean_triplet)

    return clean_entry

# Example usage
clean_sorted_data = [create_clean_entry(entry) for entry in parsed_sorted_data]
clean_unsorted_data = [create_clean_entry(entry) for entry in parsed_unsorted_data]

# %%
def combine_clean_entries(clean_sorted_data, clean_unsorted_data):
    combined_data = []
    
    # Assuming that clean_sorted_data and clean_unsorted_data have the same length
    # and that entries correspond to the same question
    for sorted_entry, unsorted_entry in zip(clean_sorted_data, clean_unsorted_data):
        combined_entry = {'question': sorted_entry['question'], 'triplets': []}
        seen_triplets = set()
        
        # First, add triplets from sorted_entry
        for triplet in sorted_entry.get('triplets', []):
            triplet_id = triplet['id']
            if triplet_id not in seen_triplets:
                seen_triplets.add(triplet_id)
                
                # Copy the triplet without the 'score' field
                new_triplet = {key: value for key, value in triplet.items() if key != 'score'}
                combined_entry['triplets'].append(new_triplet)
        
        # Then, add triplets from unsorted_entry, if not already added
        for triplet in unsorted_entry.get('triplets', []):
            triplet_id = triplet['id']
            if triplet_id not in seen_triplets:
                seen_triplets.add(triplet_id)
                
                # Copy the triplet without the 'score' field
                new_triplet = {key: value for key, value in triplet.items() if key != 'score'}
                combined_entry['triplets'].append(new_triplet)
        
        combined_data.append(combined_entry)
    
    return combined_data

# %%
combined_data =  combine_clean_entries(clean_sorted_data, clean_unsorted_data)

# %%
#SET OPEN AI API KEY 

import openai
import json
import os

openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
print(os.getenv("OPENAI_API_KEY"))
# Out:
# None

# %%
from pydantic import BaseModel, Field
from typing import List
from openai import OpenAI

# Initialize the OpenAI client


class TripletRanking(BaseModel):
    triplet_id: str = Field(..., description="The unique identifier of the triplet.")
    rank: int = Field(..., description="The rank assigned to the triplet (1 is most relevant).")
    relevant: int = Field(..., description="1 if the triplet is relevant to the query, 0 if not.")

class RankingResult(BaseModel):
    rankings: List[TripletRanking]

def create_prompt(entry):
    prompt_template = """
I am testing a knowledge graph retrieval system. The knowledge graph contains entities and relations extracted from New Zealand Transport Agency documents. I have retrieved some triplets from the graph, and I need your help to rank them.

Please do the following:

- Given the query and the list of triplets, return the rank of each triplet according to how relevant you think it is to answer the query.
- For each triplet, also indicate whether it is relevant to the query (1 for relevant, 0 for not relevant).
- Provide your answer in the format:

{{
  "rankings": [
    {{
      "triplet_id": "<triplet_id>",
      "rank": <rank>,
      "relevant": <1 or 0>
    }},
    ...
  ]
}}

- The 'triplet_id' corresponds to the unique identifier of the triplet.
- The 'rank' indicates the relevance ranking you assign (1 is most relevant).
- 'relevant' is 1 if the triplet is relevant, 0 if not.

For example:

- Query: "What is the speed limit in Auckland?"

- Triplets:

1: id: "Auckland-has speed limit-50 km/h", triplet: "Auckland -has speed limit-> 50 km/h"
2: id: "New Zealand-increased sales-Motorcycles", triplet: "New Zealand -increased sales-> Motorcycles"
3: id: "Wellington-has speed limit-40 km/h", triplet: "Wellington -has speed limit-> 40 km/h"
4: id: "Auckland driving rules-provides information-Speed limits", triplet: "Auckland driving rules -provides information-> Speed limits"

- Output:

{{
  "rankings": [
    {{
      "triplet_id": "Auckland-has speed limit-50 km/h",
      "rank": 1,
      "relevant": 1
    }},
    {{
      "triplet_id": "Auckland driving rules-provides information-Speed limits",
      "rank": 2,
      "relevant": 1
    }},
    {{
      "triplet_id": "Wellington-has speed limit-40 km/h",
      "rank": 3,
      "relevant": 0
    }},
    {{
      "triplet_id": "New Zealand-increased sales-Motorcycles",
      "rank": 4,
      "relevant": 0
    }}
  ]
}}

- **Important:** Do not include any additional text or explanations in your response. Only output the JSON object as specified.
- **Important:** Output a valid JSON object with keys and strings properly quoted (use double quotes).
- Make sure to include an entry for every triplet provided.
- Make sure the output has the same total number of entries as the number of triplets provided, this is crucial for evaluation.

Here is the query:

{query}

Here are the triplets:

{triplets}
""".strip()

    query = entry['question']
    triplets_list = entry.get('triplets', [])
    triplets_formatted = ''
    for i, triplet in enumerate(triplets_list, start=1):
        triplet_id = triplet['id']
        head = triplet['head']
        relation = triplet['relation']
        tail = triplet['tail']
        triplets_formatted += f'{i}: id: "{triplet_id}", triplet: "{head} -{relation}-> {tail}"\n'

    prompt = prompt_template.format(query=query, triplets=triplets_formatted)
    return prompt

# Example entry (replace with your actual data)
entry = combined_data[0]


# Generate the prompt
prompt = create_prompt(entry)

# Call the OpenAI API
completion = client.beta.chat.completions.parse(
    model="gpt-4o-2024-08-06",  # Replace with the actual model you are using
    messages=[
        {"role": "user", "content": prompt}
    ],
    response_format=RankingResult,
    temperature=0,  # For deterministic output
)

# Get the parsed result
ranking_result = completion.choices[0].message.parsed

# Print the results
for ranking in ranking_result.rankings:
    print(f"Triplet ID: {ranking.triplet_id}")
    print(f"Rank: {ranking.rank}")
    print(f"Relevant: {ranking.relevant}\n")
# Out:
# Triplet ID: Marlborough Transport System-AFFECTED_BY-Interislander Ferries
# Rank: 1
# Relevant: 1
#
# Triplet ID: Marlborough Region-REQUIRES-Road Network Changes
# Rank: 2
# Relevant: 1
#
# Triplet ID: Road Network Changes-PLANNED_BY-New Zealand Transport Agency
# Rank: 3
# Relevant: 1
#
# Triplet ID: Road Traffic Volumes-INCREASES-Marlborough Region
# Rank: 4
# Relevant: 1
#
# Triplet ID: Larger Ferries-AFFECTS-Road Traffic Volumes
# Rank: 5
# Relevant: 1
#
# Triplet ID: Interislander Ferries-INTRODUCES-Larger Ferries
# Rank: 6
# Relevant: 1
#
# Triplet ID: 2023-24 State Highway Investment Proposal-INCLUDES-Hornby Access and Development Programme Business Case
# Rank: 7
# Relevant: 0
#
# Triplet ID: Regional Land Transport Plan-ASSESSMENT_OF-Hornby Hub and Corridor Safety and Optimisation Single Stage Business Case
# Rank: 8
# Relevant: 0
#
# Triplet ID: Regional Land Transport Plan-ASSESSMENT_OF-Hornby Access and Development Programme Business Case
# Rank: 9
# Relevant: 0
#
# Triplet ID: 2024-27 National Land Transport Programme-DEVELOPMENT_OF-Regional Land Transport Plan
# Rank: 10
# Relevant: 0
#
# Triplet ID: Hornby Hub and Corridor Safety and Optimisation Single Stage Business Case-POTENTIAL_FOR-short-term and longer-term improvements
# Rank: 11
# Relevant: 0
#
# Triplet ID: Hornby Access and Development Programme Business Case-POTENTIAL_FOR-short-term and longer-term improvements
# Rank: 12
# Relevant: 0
#
# Triplet ID: Let's Get Wellington Moving-HAS_COMPONENT-Strategic Highway Improvements
# Rank: 13
# Relevant: 0
#
# Triplet ID: New Zealand Transport Agency-FOLLOWS-NZTA policy
# Rank: 14
# Relevant: 0
#
# Triplet ID: New Zealand Transport Agency-PLANS-Road to Zero Strategy
# Rank: 15
# Relevant: 0
#
# Triplet ID: underlying principles of the current policy-CONTRIBUTES-wider objectives in Regional Public Transport Plans
# Rank: 16
# Relevant: 0
#
# Triplet ID: wider objectives in Regional Public Transport Plans-CONTRIBUTES-government's transport priorities
# Rank: 17
# Relevant: 0
#
# Triplet ID: manage fare revenue and public transport budgets within current funding allocations-REQUIRES-standard cost scope adjustment process
# Rank: 18
# Relevant: 0
#
# Triplet ID: public transport budgets-MANAGED_BY-councils
# Rank: 19
# Relevant: 0
#
# Triplet ID: councils-MUST-manage fare revenue and public transport budgets within current funding allocations
# Rank: 20
# Relevant: 0
#
# Triplet ID: national farebox recovery target-REPLACED_BY-underlying principles of the current policy
# Rank: 21
# Relevant: 0
#
# Triplet ID: councils with greater flexibility-ADDRESS-public transport affordability
# Rank: 22
# Relevant: 0
#
# Triplet ID: Main South Road, Shands Road and Carmen Road intersection-LOCATED_NEAR-Hornby Access and Development Programme Business Case
# Rank: 23
# Relevant: 0
#
# Triplet ID: Picton Transport Improvements Factsheet-CONTAINS-Marlborough Transport System
# Rank: 24
# Relevant: 0
#
# Triplet ID: New Zealand Transport Agency-LOCATED_IN-Wellington
# Rank: 25
# Relevant: 0
#
# Triplet ID: New Zealand Transport Agency-BASED-Wellington
# Rank: 26
# Relevant: 0
#
# Triplet ID: New Zealand Transport Agency-LOCATED_IN-Private Bag
# Rank: 27
# Relevant: 0
#
# Triplet ID: New Zealand Transport Agency-CONTACT-Private Bag
# Rank: 28
# Relevant: 0
#
# Triplet ID: New Zealand Transport Agency-LOCATED_IN-50 Victoria Street
# Rank: 29
# Relevant: 0
#
# Triplet ID: New Zealand Transport Agency-LOCATED_IN-Victoria Arcade
# Rank: 30
# Relevant: 0
#
# Triplet ID: New Zealand Transport Agency-LOCATED_IN-New Zealand
# Rank: 31
# Relevant: 0
#
# Triplet ID: New Zealand-CONTAINS-New Zealand Transport Agency
# Rank: 32
# Relevant: 0
#
# Triplet ID: Auckland-CONTAINS-New Zealand Transport Agency
# Rank: 33
# Relevant: 0
#
# Triplet ID: Private Bag 6995-ASSOCIATED_WITH-New Zealand Transport Agency
# Rank: 34
# Relevant: 0
#
# Triplet ID: OIA request-ASSOCIATED_WITH-New Zealand Transport Agency
# Rank: 35
# Relevant: 0
#
# Triplet ID: official.correspondence@nzta.govt.nz-ASSOCIATED_WITH-New Zealand Transport Agency
# Rank: 36
# Relevant: 0
#
# Triplet ID: contact details-ASSOCIATED_WITH-New Zealand Transport Agency
# Rank: 37
# Relevant: 0
#
# Triplet ID: website-ASSOCIATED_WITH-New Zealand Transport Agency
# Rank: 38
# Relevant: 0

# %%
ranking_result.rankings[0]
# Out:
# TripletRanking(triplet_id='Marlborough Transport System-AFFECTED_BY-Interislander Ferries', rank=1, relevant=1)

# %%
from tqdm import tqdm

# Initialize a list to store all the ranking results
all_ranking_results = []

# Loop through all the entries in combined_data with a progress bar
for entry in tqdm(combined_data, desc="Processing entries"):
    # Generate the prompt for the current entry
    prompt = create_prompt(entry)

    # Call the OpenAI API
    completion = client.beta.chat.completions.parse(
        model="gpt-4o-2024-08-06",  # Replace with the actual model you are using
        messages=[
            {"role": "user", "content": prompt}
        ],
        response_format=RankingResult,
        temperature=0,  # For deterministic output
    )

    # Get the parsed result
    ranking_result = completion.choices[0].message.parsed

    # Append the current ranking result to the list
    all_ranking_results.append(ranking_result)

# Now, `all_ranking_results` contains the ranking results for all entries in `combined_data`
# Out:
# Processing entries: 100%|██████████| 200/200 [45:18<00:00, 13.59s/it]

# %%
# add empty entries to ranking_results until it is length 200
while len(all_ranking_results) < 200:
    all_ranking_results.append(RankingResult(rankings=[]))

# %%
# Save the ranking results as a pickle file
import pickle

with open('ranking_results/ranking_results_d4.pkl', 'wb') as file:
    pickle.dump(all_ranking_results, file)

# %%
import pickle
all_ranking_results = pickle.load(open('ranking_results/ranking_results_d6.pkl', 'rb'))
print(len(all_ranking_results))
# Out:
# 200

# %%
len(all_ranking_results)
#all_ranking_results

# oia
#  1, 3, 4
# Out:
# 200

# %%
# Step 2: Identify and Clean Incomplete Entries
print("\nIdentifying and cleaning incomplete entries...")

incomplete_entries = []

for i, (rank_result, data_entry) in enumerate(zip(all_ranking_results, combined_data)):
    if rank_result is None:
        incomplete_entries.append(i)
        continue  # No rankings available, mark as incomplete

    # Create a set of valid triplet IDs from the original data
    valid_triplet_ids = {triplet['id'] for triplet in data_entry['triplets']}
    
    # Remove any rankings with triplet_ids not present in the original data
    cleaned_rankings_dict = {}
    for ranking in rank_result.rankings:
        if ranking.triplet_id in valid_triplet_ids:
            # If triplet_id already exists, decide which one to keep (e.g., keep the first occurrence)
            if ranking.triplet_id not in cleaned_rankings_dict:
                cleaned_rankings_dict[ranking.triplet_id] = ranking
            else:
                # Optionally, you can implement logic to decide which duplicate to keep
                # For simplicity, we're keeping the first occurrence
                continue
    
    # Convert the dictionary back to a list
    cleaned_rankings = list(cleaned_rankings_dict.values())
    
    # Update the rankings in all_ranking_results with the cleaned rankings
    all_ranking_results[i].rankings = cleaned_rankings
    
    # Now, compare the lengths to identify incomplete entries
    if len(cleaned_rankings) != len(data_entry['triplets']):
        incomplete_entries.append(i)

print(f"Found {len(incomplete_entries)} incomplete entries after cleaning.")
# Out:
# Identifying and cleaning incomplete entries...
# Found 0 incomplete entries after cleaning.

# %%
all_ranking_results[57].rankings[0].triplet_id
combined_data[57]['triplets'][0]['id']

# loop over that entry (57) and figure out which id from combined_data is missing in all_ranking_results
for triplet in combined_data[57]['triplets']:
    triplet_id = triplet['id']
    found = False
    for ranking in all_ranking_results[57].rankings:
        if ranking.triplet_id == triplet_id:
            found = True
            break
    if not found:
        print(f"Triplet ID {triplet_id} is missing in the rankings.")

# do the vice versa
for ranking in all_ranking_results[57].rankings:
    triplet_id = ranking.triplet_id
    found = False
    for triplet in combined_data[57]['triplets']:
        if triplet['id'] == triplet_id:
            found = True
            break
    if not found:
        print(f"Triplet ID {triplet_id} is missing in the data.")

# %%
# find entry in all_ranking_results that has the id Triplet ID Toitū Te Taiao-FOCUSES-reducing corporate emissions
for i, rank_result in enumerate(all_ranking_results):
    for j, ranking in enumerate(rank_result.rankings):
        if ranking.triplet_id == 'Toitū Te Taiao-FOCUSES-reducing corporate emissions':
            print(f"Found in entry {j}")
            break
# Out:
# Found in entry 1

# %%
combined_data[57]['triplets'][0]['id']
# Out:
# 'Waka Kotahi Capital Projects-MANAGES-State Highway'

# %%
print(len(combined_data[57]['triplets']))
print(len(all_ranking_results[57].rankings))
# Out:
# 34
# 34

# %%
def create_correction_prompt(entry, existing_rankings):
    correction_prompt_template = """
I previously ranked the following triplets for the query:

{query}

Existing Rankings:
{existing_rankings}

However, some triplets were missing from the rankings. Please assign ranks to the missing triplets. Use decimal ranks (e.g., 2.5) to place them between existing ranks or whole numbers if they should be last. Ensure that the final rankings include all triplets with consistent formatting.

Missing Triplets:
{missing_triplets}

Provide your answer in the following JSON format, **only** for the missing triplets:

{{
  "rankings": [
    {{
      "triplet_id": "<triplet_id>",
      "rank": <rank>,
      "relevant": <1 or 0>
    }},
    ...
  ]
}}
""".strip()
    
    query = entry['question']
    existing_rankings_formatted = ''
    for ranking in existing_rankings:
        existing_rankings_formatted += f'{{"triplet_id": "{ranking.triplet_id}", "rank": {ranking.rank}, "relevant": {ranking.relevant}}},\n'
    
    # Remove the trailing comma and newline
    existing_rankings_formatted = existing_rankings_formatted.rstrip(',\n')
    
    # Identify missing triplets
    existing_triplet_ids = {r.triplet_id for r in existing_rankings}
    missing_triplets = [
        triplet for triplet in entry['triplets']
        if triplet['id'] not in existing_triplet_ids
    ]

    
    if not missing_triplets:
        return None  # No missing triplets to correct
    
    missing_triplets_formatted = ''
    for triplet in missing_triplets:
        missing_triplets_formatted += f'{{"triplet_id": "{triplet["id"]}"}} ,\n'
    
    # Remove the trailing comma and newline
    missing_triplets_formatted = missing_triplets_formatted.rstrip(',\n')
    
    correction_prompt = correction_prompt_template.format(
        query=query,
        existing_rankings=existing_rankings_formatted,
        missing_triplets=missing_triplets_formatted
    )
    
    return correction_prompt

# %%
from tqdm import tqdm
import json

# Step 1: Identify Incomplete Entries
incomplete_entries = [
    i for i, (rank_result, data_entry) in enumerate(zip(all_ranking_results, combined_data))
    if rank_result is None or len(rank_result.rankings) != len(data_entry['triplets'])
]

print(f"Found {len(incomplete_entries)} incomplete entries.")

# Step 2: Rerun Incomplete Entries with Correction Prompts
if incomplete_entries:
    print("\nRerunning incomplete entries with correction prompts...")
    for i in tqdm(incomplete_entries, desc="Rerunning incomplete entries"):
        entry = combined_data[i]
        existing_rankings = all_ranking_results[i].rankings if all_ranking_results[i] else []
        
        # Create the correction prompt
        correction_prompt = create_correction_prompt(entry, existing_rankings)
        
        if not correction_prompt:
            # No missing triplets to correct
            continue
        
        try:
            # Call the OpenAI API with the correction prompt
            correction_completion = client.beta.chat.completions.parse(
                model="gpt-4o-2024-08-06",
                messages=[{"role": "user", "content": correction_prompt}],
                response_format=RankingResult,
                temperature=0,
            )
            new_ranking_result = correction_completion.choices[0].message.parsed
            
            # Merge the new rankings with existing ones
            if all_ranking_results[i] is None:
                all_ranking_results[i] = new_ranking_result
            else:
                # Create a dictionary to avoid duplicate triplet_ids
                combined_rankings_dict = {r.triplet_id: r for r in all_ranking_results[i].rankings}
                for new_ranking in new_ranking_result.rankings:
                    combined_rankings_dict[new_ranking.triplet_id] = new_ranking  # Overwrite or add
                
                # Convert back to a list and sort by rank
                combined_rankings_sorted = sorted(combined_rankings_dict.values(), key=lambda x: x.rank)
                
                # Assign the sorted rankings back
                all_ranking_results[i].rankings = combined_rankings_sorted
            
            # Verify if rerun was successful
            if len(all_ranking_results[i].rankings) == len(entry['triplets']):
                print(f"Successfully corrected entry at index {i}")
            else:
                print(f"Still incomplete after correction at index {i}")
        except Exception as e:
            print(f"Error correcting entry at index {i}: {e}")

    # Step 3: Final Check for Remaining Incomplete Entries
    remaining_incomplete = [
        i for i, (rank_result, data_entry) in enumerate(zip(all_ranking_results, combined_data))
        if rank_result is None or len(rank_result.rankings) != len(data_entry['triplets'])
    ]

    if remaining_incomplete:
        print(f"\n{len(remaining_incomplete)} entries are still incomplete after correction:")
        for i in remaining_incomplete:
            print(f" - Index {i}")
        # Optionally, save these to a file for manual review
        mismatches = [
            {
                'index': i, 
                'missing_rankings': len(combined_data[i]['triplets']) - (len(all_ranking_results[i].rankings) if all_ranking_results[i] else 0)
            }
            for i in remaining_incomplete
        ]

        with open('remaining_incomplete_entries.json', 'w') as f:
            json.dump(mismatches, f, indent=4)
        
        print("\nRemaining incomplete entries have been saved to 'remaining_incomplete_entries.json' for further review.")
    else:
        print("\nAll incomplete entries have been successfully corrected and completed.")
else:
    print("No incomplete entries found.")
# Out:
# Found 16 incomplete entries.
#
# Rerunning incomplete entries with correction prompts...
# Rerunning incomplete entries:   6%|▋         | 1/16 [00:01<00:28,  1.87s/it]
# Successfully corrected entry at index 36
# Rerunning incomplete entries:  12%|█▎        | 2/16 [00:03<00:22,  1.64s/it]
# Successfully corrected entry at index 42
# Rerunning incomplete entries:  19%|█▉        | 3/16 [00:12<01:02,  4.84s/it]
# Successfully corrected entry at index 45
# Rerunning incomplete entries:  25%|██▌       | 4/16 [00:12<00:39,  3.32s/it]
# Successfully corrected entry at index 56
# Rerunning incomplete entries:  31%|███▏      | 5/16 [00:31<01:38,  8.93s/it]
# Successfully corrected entry at index 65
# Rerunning incomplete entries:  38%|███▊      | 6/16 [00:33<01:05,  6.53s/it]
# Successfully corrected entry at index 95
# Rerunning incomplete entries:  44%|████▍     | 7/16 [00:44<01:12,  8.03s/it]
# Successfully corrected entry at index 98
# Rerunning incomplete entries:  50%|█████     | 8/16 [00:48<00:52,  6.54s/it]
# Successfully corrected entry at index 99
# Rerunning incomplete entries:  56%|█████▋    | 9/16 [00:49<00:34,  4.90s/it]
# Successfully corrected entry at index 101
# Rerunning incomplete entries:  62%|██████▎   | 10/16 [01:08<00:56,  9.36s/it]
# Successfully corrected entry at index 106
# Rerunning incomplete entries:  69%|██████▉   | 11/16 [01:10<00:34,  6.91s/it]
# Successfully corrected entry at index 115
# Rerunning incomplete entries:  75%|███████▌  | 12/16 [01:11<00:21,  5.33s/it]
# Successfully corrected entry at index 139
# Rerunning incomplete entries:  81%|████████▏ | 13/16 [01:13<00:12,  4.09s/it]
# Successfully corrected entry at index 144
# Rerunning incomplete entries:  88%|████████▊ | 14/16 [01:14<00:06,  3.22s/it]
# Successfully corrected entry at index 147
# Rerunning incomplete entries:  94%|█████████▍| 15/16 [01:15<00:02,  2.62s/it]
# Successfully corrected entry at index 177
# Rerunning incomplete entries: 100%|██████████| 16/16 [01:22<00:00,  5.15s/it]
# Successfully corrected entry at index 180
#
# All incomplete entries have been successfully corrected and completed.

# %%
# Step 3: Rerun Incomplete Entries
if incomplete_entries:
    print("\nRerunning incomplete entries...")
    for i in tqdm(incomplete_entries, desc="Rerunning incomplete entries"):
        entry = combined_data[i]
        prompt = create_prompt(entry)
        try:
            completion = client.beta.chat.completions.parse(
                model="gpt-4o-2024-08-06",
                messages=[{"role": "user", "content": prompt}],
                response_format=RankingResult,
                temperature=0,
            )
            new_ranking_result = completion.choices[0].message.parsed

            # Replace the incomplete ranking_result with the new one
            all_ranking_results[i] = new_ranking_result

            # Verify if rerun was successful
            if len(new_ranking_result.rankings) == len(entry['triplets']):
                print(f"Successfully reran entry at index {i}")
            else:
                print(f"Still incomplete after rerunning entry at index {i}")
        except Exception as e:
            print(f"Error rerunning entry at index {i}: {e}")
            # Optionally, decide how to handle errors (e.g., keep as None or append to a failed list)

    # Step 4: Optional - Check for Remaining Incomplete Entries
    remaining_incomplete = [
        i for i, (rank_result, data_entry) in enumerate(zip(all_ranking_results, combined_data))
        if rank_result is None or len(rank_result.rankings) != len(data_entry['triplets'])
    ]
# Out:
# Rerunning incomplete entries...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[132], line 4
#       2 if incomplete_entries:
#       3     print("\nRerunning incomplete entries...")
# ----> 4     for i in tqdm(incomplete_entries, desc="Rerunning incomplete entries"):
#       5         entry = combined_data[i]
#       6         prompt = create_prompt(entry)
#
# NameError: name 'tqdm' is not defined

# %%
def normalize_ranks(rankings):
    """
    Converts decimal ranks to integer ranks by sorting and reassigning ranks.
    Prints a message if any decimal ranks were found and corrected.
    
    Parameters:
    - rankings (List[TripletRanking]): The list of rankings to normalize.
    
    Returns:
    - List[TripletRanking]: The list with normalized integer ranks.
    """
    has_decimal = any(r.rank != int(r.rank) for r in rankings)
    
    # Sort the rankings by current rank
    sorted_rankings = sorted(rankings, key=lambda x: x.rank)
    
    # Assign integer ranks based on sorted order
    for idx, ranking in enumerate(sorted_rankings, start=1):
        ranking.rank = idx
    
    if has_decimal:
        print("Decimal ranks detected and normalized.")
    
    return sorted_rankings

from tqdm import tqdm

# Normalize ranks for all ranking results
for ranking_result in tqdm(all_ranking_results, desc="Normalizing ranks"):
    if ranking_result and ranking_result.rankings:
        ranking_result.rankings = normalize_ranks(ranking_result.rankings)
# Out:
# Normalizing ranks: 100%|██████████| 200/200 [00:00<00:00, 14622.96it/s]

# %%
def add_rank_and_relevance_for_index(clean_sorted_entry, ranking_result):
    mismatches = []
    # Loop through each triplet in clean_sorted_entry
    for triplet in clean_sorted_entry['triplets']:
        triplet_id = triplet['id']
        found = False

        # Loop through rankings in ranking_result and match by id
        for ranking in ranking_result.rankings:
            if triplet_id == ranking.triplet_id:
                # Add rank and relevance to the triplet
                triplet['rank'] = ranking.rank
                triplet['relevant'] = ranking.relevant
                found = True
                break

        # If no matching id is found, store the triplet
        if not found:
            mismatches.append(triplet)

    return clean_sorted_entry, mismatches

# %%
# Assuming clean_sorted_data, clean_unsorted_data, and all_ranking_results are defined

# Process clean_sorted_data and collect mismatches
clean_sorted_data_with_ranking, sorted_mismatches_raw = zip(*[
    add_rank_and_relevance_for_index(entry, ranking_result) 
    for entry, ranking_result in zip(clean_sorted_data, all_ranking_results)
])

# Process clean_unsorted_data and collect mismatches
clean_unsorted_data_with_ranking, unsorted_mismatches_raw = zip(*[
    add_rank_and_relevance_for_index(entry, ranking_result) 
    for entry, ranking_result in zip(clean_unsorted_data, all_ranking_results)
])

# Convert mismatches into a list of dictionaries with indices
sorted_mismatches = [
    {'index': idx, 'missing': mismatches} 
    for idx, mismatches in enumerate(sorted_mismatches_raw) if mismatches
]

unsorted_mismatches = [
    {'index': idx, 'missing': mismatches} 
    for idx, mismatches in enumerate(unsorted_mismatches_raw) if mismatches
]

# %%
clean_sorted_data_with_ranking
# Out:
# ({'question': 'What is the NZTA planning in terms of road network changes to accommodate the increased traffic from the new Interislander ferries in Marlborough?',
#   'triplets': [{'head': '2023-24 State Highway Investment Proposal',
#     'relation': 'INCLUDES',
#     'tail': 'Hornby Access and Development Programme Business Case',
#     'score': 0.8242402672767639,
#     'id': '2023-24 State Highway Investment Proposal-INCLUDES-Hornby Access and Development Programme Business Case'},
#    {'head': 'Road Network Changes',
#     'relation': 'PLANNED_BY',
#     'tail': 'New Zealand Transport Agency',
#     'score': 0.8945071697235107,
#     'id': 'Road Network Changes-PLANNED_BY-New Zealand Transport Agency'},
#    {'head': 'Marlborough Region',
#     'relation': 'REQUIRES',
#     'tail': 'Road Network Changes',
#     'score': 0.8848259449005127,
#     'id': 'Marlborough Region-REQUIRES-Road Network Changes'},
#    {'head': "Let's Get Wellington Moving",
#     'relation': 'HAS_COMPONENT',
#     'tail': 'Strategic Highway Improvements',
#     'score': 0.859376072883606,
#     'id': "Let's Get Wellington Moving-HAS_COMPONENT-Strategic Highway Improvements"},
#    {'head': 'underlying principles of the current policy',
#     'relation': 'CONTRIBUTES',
#     'tail': 'wider objectives in Regional Public Transport Plans',
#     'score': 0.8204548358917236,
#     'id': 'underlying principles of the current policy-CONTRIBUTES-wider objectives in Regional Public Transport Plans'},
#    {'head': 'wider objectives in Regional Public Transport Plans',
#     'relation': 'CONTRIBUTES',
#     'tail': "government's transport priorities",
#     'score': 0.8107022643089294,
#     'id': "wider objectives in Regional Public Transport Plans-CONTRIBUTES-government's transport priorities"}]},
#  {'question': 'When is the draft Strategic Case for Picton Port Access expected to be completed?',
#   'triplets': [{'head': '2023-24 State Highway Investment Proposal',
#     'relation': 'INCLUDES',
#     'tail': 'Hornby Hub and Corridor Safety and Optimisation Single Stage Business Case',
#     'score': 0.8369826674461365,
#     'id': '2023-24 State Highway Investment Proposal-INCLUDES-Hornby Hub and Corridor Safety and Optimisation Single Stage Business Case'},
#    {'head': 'New Zealand Transport Agency',
#     'relation': 'FALLS_IN_SCOPE',
#     'tail': 'RE WK PPP Strategy draft',
#     'score': 0.7971137166023254,
#     'id': 'New Zealand Transport Agency-FALLS_IN_SCOPE-RE WK PPP Strategy draft'},
#    {'head': '10 September 2020',
#     'relation': 'ASSOCIATED_WITH',
#     'tail': 'Waito hi Picton Ferry Precinct Redevelopment',
#     'score': 0.8679131269454956,
#     'id': '10 September 2020-ASSOCIATED_WITH-Waito hi Picton Ferry Precinct Redevelopment'},
#    {'head': 'Waito hi Picton Ferry Precinct Redevelopment',
#     'relation': 'ASSOCIATED_WITH',
#     'tail': 'Integrated Transportation Assessment',
#     'score': 0.8574420213699341,
#     'id': 'Waito hi Picton Ferry Precinct Redevelopment-ASSOCIATED_WITH-Integrated Transportation Assessment'},
#    {'head': 'Picton Transport Improvements Factsheet',
#     'relation': 'AVAILABLE_AT',
#     'tail': 'https://nzta.govt.nz/assets/projects/waitohi-picton-transport-network-improvements/picton-transport-improvements-factsheet-202010.pdf',
#     'score': 0.8026319742202759,
#     'id': 'Picton Transport Improvements Factsheet-AVAILABLE_AT-https://nzta.govt.nz/assets/projects/waitohi-picton-transport-network-improvements/picton-transport-improvements-factsheet-202010.pdf'}]},
#  {'question': 'What is the crash history for the SH2/SH53 intersection in Featherston over the past 10 years?',
#   'triplets': [{'head': 'Crash Data',
#     'relation': 'LIMITED_TO',
#     'tail': 'SH2 and SH53 in Featherston',
#     'score': 0.8665138483047485,
#     'id': 'Crash Data-LIMITED_TO-SH2 and SH53 in Featherston'},
#    {'head': 'intersection of SH2 and SH53',
#     'relation': 'LOCATED_IN',
#     'tail': 'Featherston',
#     'score': 0.8975452184677124,
#     'id': 'intersection of SH2 and SH53-LOCATED_IN-Featherston'},
#    {'head': 'no fatal, serious or minor injury crashes',
#     'relation': 'OCCURRED',
#     'tail': 'intersection of SH2 and SH53',
#     'score': 0.8890056610107422,
#     'id': 'no fatal, serious or minor injury crashes-OCCURRED-intersection of SH2 and SH53'},
#    {'head': 'accident or crash history',
#     'relation': 'RELATES_TO',
#     'tail': 'intersection of SH2 and SH53',
#     'score': 0.8879202604293823,
#     'id': 'accident or crash history-RELATES_TO-intersection of SH2 and SH53'},
#    {'head': 'Transport Agency',
#     'relation': 'GETS_INFORMATION',
#     'tail': 'Traffic Crash Reports',
#     'score': 0.8154091238975525,
#     'id': 'Transport Agency-GETS_INFORMATION-Traffic Crash Reports'},
#    {'head': 'Traffic Crash Reports',
#     'relation': 'CONTAINS',
#     'tail': 'information on crash movements and causes',
#     'score': 0.8129220008850098,
#     'id': 'Traffic Crash Reports-CONTAINS-information on crash movements and causes'},
#    {'head': 'Crash Analysis System',
#     'relation': 'UPDATES',
#     'tail': 'Traffic Crash Reports',
#     'score': 0.8108359575271606,
#     'id': 'Crash Analysis System-UPDATES-Traffic Crash Reports'},
#    {'head': 'Traffic Crash Reports',
#     'relation': 'STORED_AS',
#     'tail': 'PDFs',
#     'score': 0.801708996295929,
#     'id': 'Traffic Crash Reports-STORED_AS-PDFs'},
#    {'head': 'Traffic Crash Reports',
#     'relation': 'RECEIVED_FROM',
#     'tail': 'NZ Police',
#     'score': 0.8004510998725891,
#     'id': 'Traffic Crash Reports-RECEIVED_FROM-NZ Police'},
#    {'head': 'NZ Police',
#     'relation': 'PROVIDES',
#     'tail': 'Traffic Crash Reports',
#     'score': 0.7982059717178345,
#     'id': 'NZ Police-PROVIDES-Traffic Crash Reports'},
#    {'head': 'Crash Analysis System',
#     'relation': 'PROVIDES',
#     'tail': 'traffic crash data',
#     'score': 0.811935544013977,
#     'id': 'Crash Analysis System-PROVIDES-traffic crash data'}]},
#  {'question': 'Are there any future upgrades planned to address crash risks at the SH2/SH53 intersection?',
#   'triplets': [{'head': 'New Zealand Transport Agency',
#     'relation': 'RESPONDS_TO',
#     'tail': 'Request for information on Hornby Intersection improvements',
#     'score': 0.8424252867698669,
#     'id': 'New Zealand Transport Agency-RESPONDS_TO-Request for information on Hornby Intersection improvements'},
#    {'head': 'Featherston',
#     'relation': 'RAISED_CROSSINGS',
#     'tail': 'no other intersection safety improvements planned',
#     'score': 0.8531813621520996,
#     'id': 'Featherston-RAISED_CROSSINGS-no other intersection safety improvements planned'},
#    {'head': 'no fatal, serious or minor injury crashes',
#     'relation': 'OCCURRED',
#     'tail': 'intersection of SH2 and SH53',
#     'score': 0.911615788936615,
#     'id': 'no fatal, serious or minor injury crashes-OCCURRED-intersection of SH2 and SH53'},
#    {'head': 'accident or crash history',
#     'relation': 'RELATES_TO',
#     'tail': 'intersection of SH2 and SH53',
#     'score': 0.893663763999939,
#     'id': 'accident or crash history-RELATES_TO-intersection of SH2 and SH53'},
#    {'head': 'intersection of SH2 and SH53',
#     'relation': 'LOCATED_IN',
#     'tail': 'Featherston',
#     'score': 0.8637247681617737,
#     'id': 'intersection of SH2 and SH53-LOCATED_IN-Featherston'},
#    {'head': 'Safe System approach',
#     'relation': 'INCLUDES',
#     'tail': 'improving the safety performance of the vehicle fleet',
#     'score': 0.8217959403991699,
#     'id': 'Safe System approach-INCLUDES-improving the safety performance of the vehicle fleet'}]},
#  {'question': 'How many MR1 and MR1B transactions were completed online between 1 October 2022 and 30 September 2023?',
#   'triplets': [{'head': 'New Zealand Transport Agency',
#     'relation': 'PROVIDES',
#     'tail': 'statistics for MR1/B transactions',
#     'score': 0.8297469615936279,
#     'id': 'New Zealand Transport Agency-PROVIDES-statistics for MR1/B transactions'},
#    {'head': 'transactions',
#     'relation': 'OCCURRED',
#     'tail': '1 October',
#     'score': 2022.0,
#     'id': 'transactions-OCCURRED-1 October'},
#    {'head': 'MR1/B transactions',
#     'relation': 'TOTAL',
#     'tail': '5,496,319',
#     'score': 0.8856984972953796,
#     'id': 'MR1/B transactions-TOTAL-5,496,319'},
#    {'head': 'MR1/B transactions',
#     'relation': 'COMPLETED',
#     'tail': 'online',
#     'score': 0.8824238181114197,
#     'id': 'MR1/B transactions-COMPLETED-online'},
#    {'head': 'MR1/B transactions',
#     'relation': 'COMPLETED',
#     'tail': 'agent',
#     'score': 0.8389739394187927,
#     'id': 'MR1/B transactions-COMPLETED-agent'}]},
#  {'question': 'What percentage of MR1 and MR1B transactions were completed through an agent between 1 October 2022 and 30 September 2023?',
#   'triplets': [{'head': 'Motor Vehicle Register',
#     'relation': 'CONTAINS',
#     'tail': 'MR1/B transactions data',
#     'score': 0.8200357556343079,
#     'id': 'Motor Vehicle Register-CONTAINS-MR1/B transactions data'},
#    {'head': 'transactions',
#     'relation': 'OCCURRED',
#     'tail': '1 October',
#     'score': 2022.0,
#     'id': 'transactions-OCCURRED-1 October'},
#    {'head': 'MR1/B transactions',
#     'relation': 'TOTAL',
#     'tail': '5,496,319',
#     'score': 0.8747239112854004,
#     'id': 'MR1/B transactions-TOTAL-5,496,319'},
#    {'head': 'MR1/B transactions',
#     'relation': 'COMPLETED',
#     'tail': 'agent',
#     'score': 0.8706651926040649,
#     'id': 'MR1/B transactions-COMPLETED-agent'},
#    {'head': 'MR1/B transactions',
#     'relation': 'COMPLETED',
#     'tail': 'online',
#     'score': 0.8445967435836792,
#     'id': 'MR1/B transactions-COMPLETED-online'}]},
#  {'question': 'What are the titles of the documents released in response to OIA request 15599 regarding advice provided in April 2024?',
#   'triplets': [{'head': 'MIN-4467',
#     'relation': 'DATE',
#     'tail': '26 April',
#     'score': 2024.0,
#     'id': 'MIN-4467-DATE-26 April'},
#    {'head': '22 April 2024',
#     'relation': 'RELEASED',
#     'tail': 'Released in full',
#     'score': 0.8200981616973877,
#     'id': '22 April 2024-RELEASED-Released in full'},
#    {'head': 'MINO -1039 Road User Charges',
#     'relation': 'REVENUE',
#     'tail': '22 April',
#     'score': 2024.0,
#     'id': 'MINO -1039 Road User Charges-REVENUE-22 April'},
#    {'head': "MINO -1029 Minister Office's",
#     'relation': 'QUERY',
#     'tail': '8 April',
#     'score': 2024.0,
#     'id': "MINO -1029 Minister Office's-QUERY-8 April"},
#    {'head': 'Ministers Report',
#     'relation': 'DATE',
#     'tail': '8 April',
#     'score': 2024.0,
#     'id': 'Ministers Report-DATE-8 April'},
#    {'head': '8 April 2024',
#     'relation': 'RELEASED',
#     'tail': 'Released in full',
#     'score': 0.8180559277534485,
#     'id': '8 April 2024-RELEASED-Released in full'},
#    {'head': 'MIN-4465',
#     'relation': 'DATE',
#     'tail': '24 April',
#     'score': 2024.0,
#     'id': 'MIN-4465-DATE-24 April'}]},
#  {'question': 'Under which sections of the Official Information Act was certain information withheld in the OIA-15599 response?',
#   'triplets': [{'head': 'MIN-4452',
#     'relation': 'IS',
#     'tail': 'Some information has been withheld under section',
#     'score': 9.0,
#     'id': 'MIN-4452-IS-Some information has been withheld under section'},
#    {'head': 'REF: OIA -13915',
#     'relation': 'ASSOCIATED_WITH',
#     'tail': 'Request made under the Official Information Act',
#     'score': 1982.0,
#     'id': 'REF: OIA -13915-ASSOCIATED_WITH-Request made under the Official Information Act'},
#    {'head': 'Request made under the Official Information Act 1982',
#     'relation': 'ASSOCIATED_WITH',
#     'tail': 'information under the Official Information Act',
#     'score': 1982.0,
#     'id': 'Request made under the Official Information Act 1982-ASSOCIATED_WITH-information under the Official Information Act'},
#    {'head': 'Request made under the Official Information Act 1982',
#     'relation': 'RESPONSE_DATE',
#     'tail': '27 November',
#     'score': 2018.0,
#     'id': 'Request made under the Official Information Act 1982-RESPONSE_DATE-27 November'},
#    {'head': 'Dear',
#     'relation': 'OFFICIAL_INFORMATION',
#     'tail': 'Request made under the Official Information Act',
#     'score': 1982.0,
#     'id': 'Dear-OFFICIAL_INFORMATION-Request made under the Official Information Act'},
#    {'head': 'Request made under the Official Information Act 1982',
#     'relation': 'REQUESTED',
#     'tail': 'information under the Official Information Act',
#     'score': 1982.0,
#     'id': 'Request made under the Official Information Act 1982-REQUESTED-information under the Official Information Act'},
#    {'head': 'New Zealand Transport Agency',
#     'relation': 'RESPONDS_TO',
#     'tail': 'Request made under the Official Information Act',
#     'score': 1982.0,
#     'id': 'New Zealand Transport Agency-RESPONDS_TO-Request made under the Official Information Act'},
#    {'head': 'New Zealand Transport Agency',
#     'relation': 'RESPONDS',
#     'tail': 'Request made under the Official Information Act',
#     'score': 1982.0,
#     'id': 'New Zealand Transport Agency-RESPONDS-Request made under the Official Information Act'},
#    {'head': 'section 9(2)(j) of the Act',
#     'relation': 'ENABLES',
#     'tail': 'negotiations',
#     'score': 0.7999403476715088,
#     'id': 'section 9(2)(j) of the Act-ENABLES-negotiations'},
#    {'head': 'NZ Transport Agency Waka Kotahi',
#     'relation': 'APPLIES',
#     'tail': 'section',
#     'score': 9.0,
#     'id': 'NZ Transport Agency Waka Kotahi-APPLIES-section'}]},
#  {'question': 'How many road deaths in Christchurch between 2017 and 2019 were attributed to alcohol being a contributing factor?',
#   'triplets': [{'head': 'Alcohol Consumption',
#     'relation': 'CONTRIBUTES_TO',
#     'tail': 'Road Traffic Crashes',
#     'score': 0.8729584217071533,
#     'id': 'Alcohol Consumption-CONTRIBUTES_TO-Road Traffic Crashes'},
#    {'head': 'Road Traffic Crashes',
#     'relation': 'ANALYZED_BY',
#     'tail': 'Crash Analysis',
#     'score': 0.8118003606796265,
#     'id': 'Road Traffic Crashes-ANALYZED_BY-Crash Analysis'},
#    {'head': 'Road Traffic',
#     'relation': 'AFFECTED_BY',
#     'tail': 'Alcohol Consumption',
#     'score': 0.8579446077346802,
#     'id': 'Road Traffic-AFFECTED_BY-Alcohol Consumption'},
#    {'head': 'Road to Zero',
#     'relation': 'FATality REDUCTION',
#     'tail': '45-60 fatalities',
#     'score': 0.8196537494659424,
#     'id': 'Road to Zero-FATality REDUCTION-45-60 fatalities'}]},
#  {'question': 'How many crashes in Christchurch were alcohol-related between 2017 and 2019?',
#   'triplets': [{'head': 'Road Traffic Crashes',
#     'relation': 'ANALYZED_BY',
#     'tail': 'Crash Analysis',
#     'score': 0.8155063390731812,
#     'id': 'Road Traffic Crashes-ANALYZED_BY-Crash Analysis'},
#    {'head': 'Waka Kotahi NZ Transport Agency',
#     'relation': 'PROVIDES',
#     'tail': 'information on Christchurch road deaths',
#     'score': 0.8285273313522339,
#     'id': 'Waka Kotahi NZ Transport Agency-PROVIDES-information on Christchurch road deaths'},
#    {'head': 'Pedestrian and Cyclist Crashes',
#     'relation': 'ASSOCIATED_WITH',
#     'tail': 'Road Safety Initiatives',
#     'score': 0.8336354494094849,
#     'id': 'Pedestrian and Cyclist Crashes-ASSOCIATED_WITH-Road Safety Initiatives'},
#    {'head': 'Crash Data',
#     'relation': 'RELATES_TO',
#     'tail': 'Pedestrian and Cyclist Crashes',
#     'score': 0.8330386281013489,
#     'id': 'Crash Data-RELATES_TO-Pedestrian and Cyclist Crashes'},
#    {'head': 'Data',
#     'relation': 'RELATES_TO',
#     'tail': 'Pedestrian and Cyclist Crashes',
#     'score': 0.8222845792770386,
#     'id': 'Data-RELATES_TO-Pedestrian and Cyclist Crashes'},
#    {'head': 'Pedestrian and Cyclist Crashes',
#     'relation': 'ASSOCIATED_WITH',
#     'tail': 'Headphones, Earphones, Earbuds, or Headsets',
#     'score': 0.805854320526123,
#     'id': 'Pedestrian and Cyclist Crashes-ASSOCIATED_WITH-Headphones, Earphones, Earbuds, or Headsets'},
#    {'head': '01/10/2020 to 26/05/2021',
#     'relation': 'HAS_CRASHES',
#     'tail': '1 fatal crash,',
#     'score': 3.0,
#     'id': '01/10/2020 to 26/05/2021-HAS_CRASHES-1 fatal crash,'}]},
#  {'question': 'When were the safety cameras in the Waterview Tunnel last calibrated for accuracy?',
#   'triplets': [{'head': 'Waka Kotahi',
#     'relation': 'PROVIDES',
#     'tail': 'information on traffic light cameras and speed cameras',
#     'score': 0.7930383682250977,
#     'id': 'Waka Kotahi-PROVIDES-information on traffic light cameras and speed cameras'},
#    {'head': 'Waka Kotahi',
#     'relation': 'PROVIDES',
#     'tail': 'information on traffic light cameras',
#     'score': 0.8053565621376038,
#     'id': 'Waka Kotahi-PROVIDES-information on traffic light cameras'},
#    {'head': 'meet or exceed performance requirements',
#     'relation': 'RELATES_TO',
#     'tail': 'Lyttelton tunnel',
#     'score': 0.776185929775238,
#     'id': 'meet or exceed performance requirements-RELATES_TO-Lyttelton tunnel'},
#    {'head': 'Lyttelton tunnel',
#     'relation': 'RENEWAL_SCHEDULED',
#     'tail': '2024',
#     'score': 0.7758153676986694,
#     'id': 'Lyttelton tunnel-RENEWAL_SCHEDULED-2024'}]},
#  {'question': 'How many times have the safety cameras in the Waterview Tunnel been found faulty in the past 36 months?',
#   'triplets': [{'head': 'Waka Kotahi',
#     'relation': 'PROVIDES',
#     'tail': 'information on traffic light cameras and speed cameras for the period of',
#     'score': 1.0,
#     'id': 'Waka Kotahi-PROVIDES-information on traffic light cameras and speed cameras for the period of'},
#    {'head': 'Waka Kotahi',
#     'relation': 'PROVIDES',
#     'tail': 'information on traffic light cameras and speed cameras',
#     'score': 0.783266544342041,
#     'id': 'Waka Kotahi-PROVIDES-information on traffic light cameras and speed cameras'},
#    {'head': 'Waka Kotahi',
#     'relation': 'PROVIDES',
#     'tail': 'information on traffic light cameras',
#     'score': 0.7944238185882568,
#     'id': 'Waka Kotahi-PROVIDES-information on traffic light cameras'}]},
#  {'question': 'How are contractors paid to repair potholes on New Zealand highways?',
#   'triplets': [{'head': 'New Zealand Transport Agency',
#     'relation': 'REFUSES',
#     'tail': 'request for pothole repair cost information',
#     'score': 0.8788819313049316,
#     'id': 'New Zealand Transport Agency-REFUSES-request for pothole repair cost information'},
#    {'head': 'request for pothole repair cost information',
#     'relation': 'SUBJECT_TO',
#     'tail': 'section',
#     'score': 18.0,
#     'id': 'request for pothole repair cost information-SUBJECT_TO-section'},
#    {'head': 'request for pothole repair cost information',
#     'relation': 'SUBJECT_TO',
#     'tail': 'sections',
#     'score': 18.0,
#     'id': 'request for pothole repair cost information-SUBJECT_TO-sections'},
#    {'head': 'section 18(f) of the Act',
#     'relation': 'APPLIES_TO',
#     'tail': 'request for pothole repair cost information',
#     'score': 0.8596602082252502,
#     'id': 'section 18(f) of the Act-APPLIES_TO-request for pothole repair cost information'},
#    {'head': 'sections 18A and 18B of the Act',
#     'relation': 'APPLIES_TO',
#     'tail': 'request for pothole repair cost information',
#     'score': 0.8526146411895752,
#     'id': 'sections 18A and 18B of the Act-APPLIES_TO-request for pothole repair cost information'},
#    {'head': 'pothole repair specifications',
#     'relation': 'FROM',
#     'tail': 'NZTA',
#     'score': 0.8897546529769897,
#     'id': 'pothole repair specifications-FROM-NZTA'},
#    {'head': 'https://www.nzta.govt.nz/assets/resources/maint-specs-potholes/docs/maint-specs-potholes.pdf',
#     'relation': 'ACCESS',
#     'tail': 'pothole repair specifications',
#     'score': 0.8849823474884033,
#     'id': 'https://www.nzta.govt.nz/assets/resources/maint-specs-potholes/docs/maint-specs-potholes.pdf-ACCESS-pothole repair specifications'},
#    {'head': 'detail on any contracting of consultants to work on the investigations of the long tunnel option for Wellington (Terrace to Kilbirnie)',
#     'relation': 'CONTRACTS',
#     'tail': 'consultants',
#     'score': 0.8585132956504822,
#     'id': 'detail on any contracting of consultants to work on the investigations of the long tunnel option for Wellington (Terrace to Kilbirnie)-CONTRACTS-consultants'},
#    {'head': 'Request made under the Official Information Act 1982',
#     'relation': 'REQUESTS',
#     'tail': 'detail on any contracting of consultants to work on the investigations of the long tunnel option for Wellington (Terrace to Kilbirnie)',
#     'score': 0.8411082029342651,
#     'id': 'Request made under the Official Information Act 1982-REQUESTS-detail on any contracting of consultants to work on the investigations of the long tunnel option for Wellington (Terrace to Kilbirnie)'},
#    {'head': 'website',
#     'relation': 'LINKS',
#     'tail': 'https://www.nzta.govt.nz/assets/resources/maint-specs-potholes/docs/maint-specs-potholes.pdf',
#     'score': 0.8677428960800171,
#     'id': 'website-LINKS-https://www.nzta.govt.nz/assets/resources/maint-specs-potholes/docs/maint-specs-potholes.pdf'}]},
#  {'question': 'Does NZTA impose a quality assurance or performance clause for pothole repair work, and if so, where can it be found?',
#   'triplets': [{'head': 'https://www.nzta.govt.nz/assets/resources/maint-specs-potholes/docs/maint-specs-potholes.pdf',
#     'relation': 'ACCESS',
#     'tail': 'pothole repair specifications',
#     'score': 0.8869953751564026,
#     'id': 'https://www.nzta.govt.nz/assets/resources/maint-specs-potholes/docs/maint-specs-potholes.pdf-ACCESS-pothole repair specifications'},
#    {'head': 'New Zealand Transport Agency',
#     'relation': 'CONSIDERS',
#     'tail': 'request for pothole repair cost information',
#     'score': 0.8871679902076721,
#     'id': 'New Zealand Transport Agency-CONSIDERS-request for pothole repair cost information'},
#    {'head': 'New Zealand Transport Agency',
#     'relation': 'REFUSES',
#     'tail': 'request for pothole repair cost information',
#     'score': 0.8752009272575378,
#     'id': 'New Zealand Transport Agency-REFUSES-request for pothole repair cost information'},
#    {'head': 'request for pothole repair cost information',
#     'relation': 'SUBJECT_TO',
#     'tail': 'section',
#     'score': 18.0,
#     'id': 'request for pothole repair cost information-SUBJECT_TO-section'},
#    {'head': 'request for pothole repair cost information',
#     'relation': 'SUBJECT_TO',
#     'tail': 'sections',
#     'score': 18.0,
#     'id': 'request for pothole repair cost information-SUBJECT_TO-sections'},
#    {'head': 'section 18(f) of the Act',
#     'relation': 'APPLIES_TO',
#     'tail': 'request for pothole repair cost information',
#     'score': 0.8544352650642395,
#     'id': 'section 18(f) of the Act-APPLIES_TO-request for pothole repair cost information'},
#    {'head': 'sections 18A and 18B of the Act',
#     'relation': 'APPLIES_TO',
#     'tail': 'request for pothole repair cost information',
#     'score': 0.8514285683631897,
#     'id': 'sections 18A and 18B of the Act-APPLIES_TO-request for pothole repair cost information'},
#    {'head': 'website',
#     'relation': 'LINKS',
#     'tail': 'https://www.nzta.govt.nz/assets/resources/maint-specs-potholes/docs/maint-specs-potholes.pdf',
#     'score': 0.8628110885620117,
#     'id': 'website-LINKS-https://www.nzta.govt.nz/assets/resources/maint-specs-potholes/docs/maint-specs-potholes.pdf'},
#    {'head': 'State Highway 1',
#     'relation': 'REPAIRS',
#     'tail': 'potholes',
#     'score': 0.8354532718658447,
#     'id': 'State Highway 1-REPAIRS-potholes'}]},
#  {'question': 'What were the safety failures identified in Go Wellington buses during the inspections in April and May 2013?',
#   'triplets': [{'head': 'Health, Safety & Quality Report',
#     'relation': 'CONTAINS',
#     'tail': 'Safety Incidents',
#     'score': 0.8126248717308044,
#     'id': 'Health, Safety & Quality Report-CONTAINS-Safety Incidents'},
#    {'head': 'awareness',
#     'relation': 'increased',
#     'tail': 'rail operational safety',
#     'score': 0.7968844175338745,
#     'id': 'awareness-increased-rail operational safety'},
#    {'head': 'rail operational safety',
#     'relation': 'improved',
#     'tail': 'emergency plan',
#     'score': 0.7927109003067017,
#     'id': 'rail operational safety-improved-emergency plan'},
#    {'head': 'Senior Manager Road Safety',
#     'relation': 'EMPLOYER',
#     'tail': 'Waka Kotahi',
#     'score': 0.7954689860343933,
#     'id': 'Senior Manager Road Safety-EMPLOYER-Waka Kotahi'},
#    {'head': 'Fabian Marsh',
#     'relation': 'POSITION',
#     'tail': 'Senior Manager Road Safety',
#     'score': 0.7869345545768738,
#     'id': 'Fabian Marsh-POSITION-Senior Manager Road Safety'},
#    {'head': 'Vehicle Safety',
#     'relation': 'Is',
#     'tail': 'Critical',
#     'score': 0.806066632270813,
#     'id': 'Vehicle Safety-Is-Critical'},
#    {'head': 'Safety Tolerance',
#     'relation': 'Ensures',
#     'tail': 'Vehicle Safety',
#     'score': 0.7789112329483032,
#     'id': 'Safety Tolerance-Ensures-Vehicle Safety'}]},
#  {'question': 'How did NZ Bus Limited respond to the faults identified in the inspection of Go Wellington buses?',
#   'triplets': [{'head': 'reports on converting the shoulder of Auckland Motorway into Bus Lanes',
#     'relation': 'PROVIDED',
#     'tail': 'Attachment',
#     'score': 1.0,
#     'id': 'reports on converting the shoulder of Auckland Motorway into Bus Lanes-PROVIDED-Attachment'},
#    {'head': 'New Zealand Transport Agency',
#     'relation': 'PRODUCES',
#     'tail': 'report on the impacts of the Fare Recovery Ratio',
#     'score': 0.8566558361053467,
#     'id': 'New Zealand Transport Agency-PRODUCES-report on the impacts of the Fare Recovery Ratio'},
#    {'head': 'New Zealand Transport Agency',
#     'relation': 'POLICY',
#     'tail': 'Investigating transport companies',
#     'score': 0.8748288154602051,
#     'id': 'New Zealand Transport Agency-POLICY-Investigating transport companies'},
#    {'head': 'New Zealand Transport Agency',
#     'relation': 'MANAGES',
#     'tail': 'investigating transport companies',
#     'score': 0.8718224167823792,
#     'id': 'New Zealand Transport Agency-MANAGES-investigating transport companies'}]},
#  {'question': 'How many Clean Car rebates have been issued between 1 July 2021 and 31 May 2022?',
#   'triplets': [{'head': 'Clean Car rebate scheme',
#     'relation': 'SPENT',
#     'tail': '$101,770,725.74',
#     'score': 0.8810279369354248,
#     'id': 'Clean Car rebate scheme-SPENT-$101,770,725.74'},
#    {'head': 'Waka Kotahi',
#     'relation': 'RECEIVED',
#     'tail': '7,162 Clean Car fees',
#     'score': 0.8232439756393433,
#     'id': 'Waka Kotahi-RECEIVED-7,162 Clean Car fees'},
#    {'head': 'New Zealand Transport Agency',
#     'relation': 'RESPONSE',
#     'tail': 'Thank you for your email of',
#     'score': 13.0,
#     'id': 'New Zealand Transport Agency-RESPONSE-Thank you for your email of'}]},
#  {'question': 'How much revenue has been collected from Clean Car penalties between 1 April and 31 May 2022?',
#   'triplets': [{'head': 'Waka Kotahi',
#     'relation': 'RECEIVED',
#     'tail': '7,162 Clean Car fees',
#     'score': 0.8049030303955078,
#     'id': 'Waka Kotahi-RECEIVED-7,162 Clean Car fees'},
#    {'head': 'New Zealand Transport Agency',
#     'relation': 'RESPONSE',
#     'tail': 'Thank you for your email of',
#     'score': 13.0,
#     'id': 'New Zealand Transport Agency-RESPONSE-Thank you for your email of'},
#    {'head': 'manage fare revenue and public transport budgets within current funding allocations',
#     'relation': 'REQUIRES',
#     'tail': 'standard cost scope adjustment process',
#     'score': 0.8038504123687744,
#     'id': 'manage fare revenue and public transport budgets within current funding allocations-REQUIRES-standard cost scope adjustment process'},
#    {'head': 'councils',
#     'relation': 'MUST',
#     'tail': 'manage fare revenue and public transport budgets within current funding allocations',
#     'score': 0.8035011291503906,
#     'id': 'councils-MUST-manage fare revenue and public transport budgets within current funding allocations'}]},
#  {'question': 'What was the total number of vacancies under active recruitment at NZTA as of 23 August 2019?',
#   'triplets': [{'head': 'Applicant 7',
#     'relation': 'CONVICTED',
#     'tail': 'Breach Probation',
#     'score': 0.775154709815979,
#     'id': 'Applicant 7-CONVICTED-Breach Probation'},
#    {'head': 'Applicant 3',
#     'relation': 'CONVICTED',
#     'tail': 'Assault Police (Manual)',
#     'score': 0.7781451344490051,
#     'id': 'Applicant 3-CONVICTED-Assault Police (Manual)'},
#    {'head': 'Applicant 2',
#     'relation': 'CONVICTED',
#     'tail': 'Assault Child (Manually)',
#     'score': 0.7653548121452332,
#     'id': 'Applicant 2-CONVICTED-Assault Child (Manually)'}]},
#  {'question': 'Were there any personal grievances or employment law processes underway with Charles Ronaldson, Giles Southwell, or Leigh Mitchell?',
#   'triplets': [{'head': 'Leigh Mitchell',
#     'relation': 'EMPLOYED_BY',
#     'tail': 'New Zealand Transport Agency',
#     'score': 0.8143210411071777,
#     'id': 'Leigh Mitchell-EMPLOYED_BY-New Zealand Transport Agency'},
#    {'head': 'Charles Ronaldson',
#     'relation': 'IS',
#     'tail': 'Programme Director, Commercial Projects',
#     'score': 0.8273807168006897,
#     'id': 'Charles Ronaldson-IS-Programme Director, Commercial Projects'},
#    {'head': 'Charles Ronaldson',
#     'relation': 'EMPLOYED_BY',
#     'tail': 'New Zealand Transport Agency',
#     'score': 0.8140394687652588,
#     'id': 'Charles Ronaldson-EMPLOYED_BY-New Zealand Transport Agency'},
#    {'head': 'Charles Ronaldson',
#     'relation': 'GENERAL_MANAGER',
#     'tail': 'Operations',
#     'score': 0.8089484572410583,
#     'id': 'Charles Ronaldson-GENERAL_MANAGER-Operations'},
#    {'head': 'Charles Ronaldson',
#     'relation': 'SIGNED',
#     'tail': 'response',
#     'score': 0.804772675037384,
#     'id': 'Charles Ronaldson-SIGNED-response'},
#    {'head': 'Waka Kotahi',
#     'relation': 'PROTECTS',
#     'tail': 'public interest in legal professional privilege',
#     'score': 0.7598839998245239,
#     'id': 'Waka Kotahi-PROTECTS-public interest in legal professional privilege'},
#    {'head': 'Waka Kotahi',
#     'relation': 'CONTINUES',
#     'tail': 'public interest in legal professional privilege',
#     'score': 0.7487151026725769,
#     'id': 'Waka Kotahi-CONTINUES-public interest in legal professional privilege'},
#    {'head': 'Waka Kotahi',
#     'relation': 'ACKNOWLEDGES',
#     'tail': 'public interest in legal professional privilege',
#     'score': 0.7473810911178589,
#     'id': 'Waka Kotahi-ACKNOWLEDGES-public interest in legal professional privilege'}]},
#  {'question': 'How many drivers had a zero-alcohol condition on their licence as of 1 July 2018?',
#   'triplets': [{'head': 'Data',
#     'relation': 'IS',
#     'tail': 'Standard condition of drivers under',
#     'score': 20.0,
#     'id': 'Data-IS-Standard condition of drivers under'},
#    {'head': 'Driving With Excess Blood Alcohol Level',
#     'relation': 'COUNT',
#     'tail': '1',
#     'score': 0.8650611042976379,
#     'id': 'Driving With Excess Blood Alcohol Level-COUNT-1'},
#    {'head': 'Data',
#     'relation': 'IS',
#     'tail': 'Limited to drivers who held a current licence as at',
#     'score': 1.0,
#     'id': 'Data-IS-Limited to drivers who held a current licence as at'}]},
#  {'question': 'How many drivers had a zero-alcohol condition on their licence as of 1 July 2019?',
#   'triplets': [{'head': 'Data',
#     'relation': 'IS',
#     'tail': 'Standard condition of drivers under',
#     'score': 20.0,
#     'id': 'Data-IS-Standard condition of drivers under'},
#    {'head': 'Data',
#     'relation': 'IS',
#     'tail': 'Limited to drivers who held a current licence as at',
#     'score': 1.0,
#     'id': 'Data-IS-Limited to drivers who held a current licence as at'},
#    {'head': 'Driving With Excess Blood Alcohol Level',
#     'relation': 'COUNT',
#     'tail': '1',
#     'score': 0.865689754486084,
#     'id': 'Driving With Excess Blood Alcohol Level-COUNT-1'}]},
#  {'question': 'How many fatal crashes in the Queenstown Lakes and Central Otago districts involved overseas drivers between 2015 and 2019?',
#   'triplets': [{'head': 'Road Traffic Crashes',
#     'relation': 'ANALYZED_BY',
#     'tail': 'Crash Analysis',
#     'score': 0.822953462600708,
#     'id': 'Road Traffic Crashes-ANALYZED_BY-Crash Analysis'},
#    {'head': 'Alcohol Consumption',
#     'relation': 'CONTRIBUTES_TO',
#     'tail': 'Road Traffic Crashes',
#     'score': 0.8032260537147522,
#     'id': 'Alcohol Consumption-CONTRIBUTES_TO-Road Traffic Crashes'},
#    {'head': 'road traffic crashes',
#     'relation': 'OCCURS_IN',
#     'tail': 'Queenstown Lakes and Central Otago',
#     'score': 0.9232737421989441,
#     'id': 'road traffic crashes-OCCURS_IN-Queenstown Lakes and Central Otago'},
#    {'head': 'NZ Police',
#     'relation': 'INVESTIGATES',
#     'tail': 'road traffic crashes',
#     'score': 0.8609979152679443,
#     'id': 'NZ Police-INVESTIGATES-road traffic crashes'},
#    {'head': 'AA',
#     'relation': 'PROVIDES',
#     'tail': 'figures on drivers involved in fatal crashes',
#     'score': 0.827420711517334,
#     'id': 'AA-PROVIDES-figures on drivers involved in fatal crashes'}]},
#  {'question': 'How many fatal crashes in the Queenstown Lakes and Central Otago districts involved local drivers between 2015 and 2019?',
#   'triplets': [{'head': 'Road Traffic Crashes',
#     'relation': 'ANALYZED_BY',
#     'tail': 'Crash Analysis',
#     'score': 0.8271992802619934,
#     'id': 'Road Traffic Crashes-ANALYZED_BY-Crash Analysis'},
#    {'head': 'Alcohol Consumption',
#     'relation': 'CONTRIBUTES_TO',
#     'tail': 'Road Traffic Crashes',
#     'score': 0.8081628084182739,
#     'id': 'Alcohol Consumption-CONTRIBUTES_TO-Road Traffic Crashes'},
#    {'head': 'road traffic crashes',
#     'relation': 'OCCURS_IN',
#     'tail': 'Queenstown Lakes and Central Otago',
#     'score': 0.929458737373352,
#     'id': 'road traffic crashes-OCCURS_IN-Queenstown Lakes and Central Otago'},
#    {'head': 'NZ Police',
#     'relation': 'INVESTIGATES',
#     'tail': 'road traffic crashes',
#     'score': 0.8625869750976562,
#     'id': 'NZ Police-INVESTIGATES-road traffic crashes'},
#    {'head': 'AA',
#     'relation': 'PROVIDES',
#     'tail': 'figures on drivers involved in fatal crashes',
#     'score': 0.8298554420471191,
#     'id': 'AA-PROVIDES-figures on drivers involved in fatal crashes'}]},
#  {'question': 'Since when does the NZ Transport Agency have records of directives or requests to process OIA requests with urgency?',
#   'triplets': [{'head': 'New Zealand Transport Agency',
#     'relation': 'DISCUSSES',
#     'tail': 'OIA request',
#     'score': 0.9307509064674377,
#     'id': 'New Zealand Transport Agency-DISCUSSES-OIA request'},
#    {'head': 'New Zealand Transport Agency',
#     'relation': 'PROVIDES',
#     'tail': 'response to OIA request',
#     'score': 0.9205774068832397,
#     'id': 'New Zealand Transport Agency-PROVIDES-response to OIA request'},
#    {'head': 'New Zealand Transport Agency',
#     'relation': 'RESPONDS_TO',
#     'tail': 'OIA requests',
#     'score': 0.9205530881881714,
#     'id': 'New Zealand Transport Agency-RESPONDS_TO-OIA requests'},
#    {'head': 'New Zealand Transport Agency',
#     'relation': 'RESPONDS_TO',
#     'tail': 'OIA request',
#     'score': 0.9197360277175903,
#     'id': 'New Zealand Transport Agency-RESPONDS_TO-OIA request'},
#    {'head': 'OIA-8452',
#     'relation': 'ANSWERED_BY',
#     'tail': 'New Zealand Transport Agency',
#     'score': 0.9192745685577393,
#     'id': 'OIA-8452-ANSWERED_BY-New Zealand Transport Agency'},
#    {'head': 'OIA request',
#     'relation': 'SUBMITTED_TO',
#     'tail': 'New Zealand Transport Agency',
#     'score': 0.917543888092041,
#     'id': 'OIA request-SUBMITTED_TO-New Zealand Transport Agency'},
#    {'head': 'New Zealand Transport Agency',
#     'relation': 'RESPONDS',
#     'tail': 'OIA-10752',
#     'score': 0.9163401126861572,
#     'id': 'New Zealand Transport Agency-RESPONDS-OIA-10752'},
#    {'head': 'reply with NZ Transport Agency Waka Kotahi (NZTA)',
#     'relation': 'INVOLVES',
#     'tail': 'Andy Knackstedt',
#     'score': 0.843327522277832,
#     'id': 'reply with NZ Transport Agency Waka Kotahi (NZTA)-INVOLVES-Andy Knackstedt'},
#    {'head': 'Jackie Smith',
#     'relation': 'DISCUSSES',
#     'tail': 'reply with NZ Transport Agency Waka Kotahi (NZTA)',
#     'score': 0.839218020439148,
#     'id': 'Jackie Smith-DISCUSSES-reply with NZ Transport Agency Waka Kotahi (NZTA)'},
#    {'head': 'New Zealand Transport Agency',
#     'relation': 'PROVIDES',
#     'tail': 'information to New Zealand Transport Agency Waka Kotahi',
#     'score': 0.8662154674530029,
#     'id': 'New Zealand Transport Agency-PROVIDES-information to New Zealand Transport Agency Waka Kotahi'}]},
#  {'question': 'Where can information about the average length of time taken to respond to OIA requests be found?',
#   'triplets': [{'head': 'response to OIA request',
#     'relation': 'PROVIDES',
#     'tail': 'information requested',
#     'score': 0.8843493461608887,
#     'id': 'response to OIA request-PROVIDES-information requested'},
#    {'head': 'New Zealand Transport Agency',
#     'relation': 'PROVIDES',
#     'tail': 'response to OIA request',
#     'score': 0.8585140705108643,
#     'id': 'New Zealand Transport Agency-PROVIDES-response to OIA request'},
#    {'head': 'oia-9194-response.pdf',
#     'relation': 'CONTAINS',
#     'tail': 'response to OIA request',
#     'score': 0.8492631912231445,
#     'id': 'oia-9194-response.pdf-CONTAINS-response to OIA request'},
#    {'head': 'REF: OIA -13915',
#     'relation': 'ASSOCIATED_WITH',
#     'tail': 'Request made under the Official Information Act',
#     'score': 1982.0,
#     'id': 'REF: OIA -13915-ASSOCIATED_WITH-Request made under the Official Information Act'},
#    {'head': 'Request made under the Official Information Act 1982',
#     'relation': 'RESPONSE_DATE',
#     'tail': '27 November',
#     'score': 2018.0,
#     'id': 'Request made under the Official Information Act 1982-RESPONSE_DATE-27 November'},
#    {'head': 'Request made under the Official Information Act 1982',
#     'relation': 'REQUEST_DATE',
#     'tail': '30 October',
#     'score': 2018.0,
#     'id': 'Request made under the Official Information Act 1982-REQUEST_DATE-30 October'},
#    {'head': 'Dear',
#     'relation': 'OFFICIAL_INFORMATION',
#     'tail': 'Request made under the Official Information Act',
#     'score': 1982.0,
#     'id': 'Dear-OFFICIAL_INFORMATION-Request made under the Official Information Act'},
#    {'head': 'New Zealand Transport Agency',
#     'relation': 'RESPONDS_TO',
#     'tail': 'Request made under the Official Information Act',
#     'score': 1982.0,
#     'id': 'New Zealand Transport Agency-RESPONDS_TO-Request made under the Official Information Act'},
#    {'head': 'Request made under the Official Information Act 1982',
#     'relation': 'ASSOCIATED_WITH',
#     'tail': 'information under the Official Information Act',
#     'score': 1982.0,
#     'id': 'Request made under the Official Information Act 1982-ASSOCIATED_WITH-information under the Official Information Act'},
#    {'head': 'New Zealand Transport Agency',
#     'relation': 'RESPONDS',
#     'tail': 'Request made under the Official Information Act',
#     'score': 1982.0,
#     'id': 'New Zealand Transport Agency-RESPONDS-Request made under the Official Information Act'},
#    {'head': 'New Zealand Transport Agency',
#     'relation': 'RESPONDED',
#     'tail': 'Request for Information',
#     'score': 0.8393378257751465,
#     'id': 'New Zealand Transport Agency-RESPONDED-Request for Information'},
#    {'head': 'Request for Information',
#     'relation': 'REQUESTS',
#     'tail': 'Complaint Data',
#     'score': 0.8362391591072083,
#     'id': 'Request for Information-REQUESTS-Complaint Data'},
#    {'head': 'Antoinette Spicer',
#     'relation': 'SUBMITTED',
#     'tail': 'Request for Information',
#     'score': 0.8250135183334351,
#     'id': 'Antoinette Spicer-SUBMITTED-Request for Information'},
#    {'head': 'Request for Information',
#     'relation': 'REQUESTS',
#     'tail': 'Warning Letters',
#     'score': 0.8039490580558777,
#     'id': 'Request for Information-REQUESTS-Warning Letters'}]},
#  {'question': 'What information does Waka Kotahi NZTA provide regarding the amount of money spent on litter collection?',
#   'triplets': [{'head': 'Waka Kotahi NZ Transport Agency',
#     'relation': 'DOES_NOT_HOLD',
#     'tail': 'information regarding amount of litter collected and disposed',
#     'score': 0.8816825747489929,
#     'id': 'Waka Kotahi NZ Transport Agency-DOES_NOT_HOLD-information regarding amount of litter collected and disposed'},
#    {'head': 'New Zealand Transport Agency',
#     'relation': 'PROVIDES',
#     'tail': 'information to Waka Kotahi',
#     'score': 0.8655425310134888,
#     'id': 'New Zealand Transport Agency-PROVIDES-information to Waka Kotahi'},
#    {'head': 'information',
#     'relation': 'PROVIDED_BY',
#     'tail': 'Waka Kotahi',
#     'score': 0.8722138404846191,
#     'id': 'information-PROVIDED_BY-Waka Kotahi'},
#    {'head': 'Waka Kotahi',
#     'relation': 'PROVIDES',
#     'tail': 'publicly available information',
#     'score': 0.8713779449462891,
#     'id': 'Waka Kotahi-PROVIDES-publicly available information'},
#    {'head': 'Waka Kotahi',
#     'relation': 'CONTACTABLE',
#     'tail': 'official.correspondence@nzta.govt.nz',
#     'score': 0.8652936816215515,
#     'id': 'Waka Kotahi-CONTACTABLE-official.correspondence@nzta.govt.nz'},
#    {'head': 'Waka Kotahi',
#     'relation': 'CONTACT',
#     'tail': 'official.correspondence@nzta.govt.nz',
#     'score': 0.8637201189994812,
#     'id': 'Waka Kotahi-CONTACT-official.correspondence@nzta.govt.nz'},
#    {'head': 'Road User Charges',
#     'relation': 'UNDERTAKEN_BY',
#     'tail': 'Waka Kotahi',
#     'score': 0.8631265163421631,
#     'id': 'Road User Charges-UNDERTAKEN_BY-Waka Kotahi'},
#    {'head': 'Waka Kotahi',
#     'relation': 'CONTACT',
#     'tail': 'official.corespondence@nzta.govt.nz',
#     'score': 0.8617894053459167,
#     'id': 'Waka Kotahi-CONTACT-official.corespondence@nzta.govt.nz'},
#    {'head': 'New Zealand',
#     'relation': 'HOME',
#     'tail': 'Waka Kotahi',
#     'score': 0.8604342341423035,
#     'id': 'New Zealand-HOME-Waka Kotahi'}]},
#  {'question': 'Does Waka Kotahi NZTA have information on the weight or amount of rubbish collected along state highways?',
#   'triplets': [{'head': 'Waka Kotahi NZ Transport Agency',
#     'relation': 'REFUSES',
#     'tail': 'request for weight/amount of rubbish cleaned up',
#     'score': 0.8862603306770325,
#     'id': 'Waka Kotahi NZ Transport Agency-REFUSES-request for weight/amount of rubbish cleaned up'},
#    {'head': 'Data',
#     'relation': 'PROVIDED',
#     'tail': 'Waka Kotahi N Z Transport Agency',
#     'score': 0.8702329993247986,
#     'id': 'Data-PROVIDED-Waka Kotahi N Z Transport Agency'},
#    {'head': 'Crash Analysis System',
#     'relation': 'MAINTAINS',
#     'tail': 'Waka Kotahi N Z Transport Agency',
#     'score': 0.8243070840835571,
#     'id': 'Crash Analysis System-MAINTAINS-Waka Kotahi N Z Transport Agency'},
#    {'head': 'Waka Kotahi NZ Transport Agency',
#     'relation': 'PROVIDES',
#     'tail': 'information on Christchurch road deaths',
#     'score': 0.8895785808563232,
#     'id': 'Waka Kotahi NZ Transport Agency-PROVIDES-information on Christchurch road deaths'},
#    {'head': 'Waka Kotahi NZ Transport Agency',
#     'relation': 'DOES_NOT_HOLD',
#     'tail': 'information regarding amount of litter collected and disposed',
#     'score': 0.8885825276374817,
#     'id': 'Waka Kotahi NZ Transport Agency-DOES_NOT_HOLD-information regarding amount of litter collected and disposed'},
#    {'head': 'Waka Kotahi NZ Transport Agency',
#     'relation': 'PROVIDES',
#     'tail': 'Road Traffic Crash Data',
#     'score': 0.8852757811546326,
#     'id': 'Waka Kotahi NZ Transport Agency-PROVIDES-Road Traffic Crash Data'},
#    {'head': 'Waka Kotahi NZ Transport Agency',
#     'relation': 'WEBSITE',
#     'tail': 'www.nzta.govt.nz',
#     'score': 0.8810381889343262,
#     'id': 'Waka Kotahi NZ Transport Agency-WEBSITE-www.nzta.govt.nz'},
#    {'head': 'www.nzta.govt.nz',
#     'relation': 'OF',
#     'tail': 'Waka Kotahi NZ Transport Agency',
#     'score': 0.8799619674682617,
#     'id': 'www.nzta.govt.nz-OF-Waka Kotahi NZ Transport Agency'},
#    {'head': 'Waka Kotahi NZ Transport Agency',
#     'relation': 'PROVIDES',
#     'tail': 'Open Data portal for information about daily traffic volumes on Hewletts Road',
#     'score': 0.8798589706420898,
#     'id': 'Waka Kotahi NZ Transport Agency-PROVIDES-Open Data portal for information about daily traffic volumes on Hewletts Road'}]},
#  {'question': 'What transport route was NZTA planning from Auckland CBD to West Auckland?',
#   'triplets': [{'head': 'Rapid Transit in Auckland',
#     'relation': 'ATTACHED_TO',
#     'tail': 'Attachment',
#     'score': 1.0,
#     'id': 'Rapid Transit in Auckland-ATTACHED_TO-Attachment'},
#    {'head': 'Regional Land Transport Plan',
#     'relation': 'ASSESSMENT_OF',
#     'tail': 'Hornby Access and Development Programme Business Case',
#     'score': 0.8275936245918274,
#     'id': 'Regional Land Transport Plan-ASSESSMENT_OF-Hornby Access and Development Programme Business Case'},
#    {'head': 'Regional Land Transport Plan',
#     'relation': 'ASSESSMENT_OF',
#     'tail': 'Hornby Hub and Corridor Safety and Optimisation Single Stage Business Case',
#     'score': 0.82469642162323,
#     'id': 'Regional Land Transport Plan-ASSESSMENT_OF-Hornby Hub and Corridor Safety and Optimisation Single Stage Business Case'},
#    {'head': '2024-27 National Land Transport Programme',
#     'relation': 'DEVELOPMENT_OF',
#     'tail': 'Regional Land Transport Plan',
#     'score': 0.8012580871582031,
#     'id': '2024-27 National Land Transport Programme-DEVELOPMENT_OF-Regional Land Transport Plan'},
#    {'head': 'Regional Public Transport Plans',
#     'relation': 'DEVELOPED_BY',
#     'tail': 'Waka Kotahi',
#     'score': 0.8436858654022217,
#     'id': 'Regional Public Transport Plans-DEVELOPED_BY-Waka Kotahi'},
#    {'head': 'Waka Kotahi',
#     'relation': 'PARTNER',
#     'tail': 'Regional Public Transport Plans',
#     'score': 0.8229320049285889,
#     'id': 'Waka Kotahi-PARTNER-Regional Public Transport Plans'},
#    {'head': 'Regional Public Transport Plans',
#     'relation': 'CONTRIBUTES',
#     'tail': 'achieving mode shift',
#     'score': 0.7972267270088196,
#     'id': 'Regional Public Transport Plans-CONTRIBUTES-achieving mode shift'},
#    {'head': 'achieving mode shift',
#     'relation': 'REQUIRES',
#     'tail': 'Regional Public Transport Plans',
#     'score': 0.7972239255905151,
#     'id': 'achieving mode shift-REQUIRES-Regional Public Transport Plans'}]},
#  {'question': 'What type of public transport solution was being considered for the route between Wynyard Quarter and the north-western motorway?',
#   'triplets': [{'head': 'reports on converting the shoulder of Auckland Motorway into Bus Lanes',
#     'relation': 'PROVIDED',
#     'tail': 'Attachment',
#     'score': 1.0,
#     'id': 'reports on converting the shoulder of Auckland Motorway into Bus Lanes-PROVIDED-Attachment'},
#    {'head': 'Project Agreement',
#     'relation': 'AVAILABLE',
#     'tail': 'https://www.nzta.govt.nz/projects/wellington-northern-corridor/transmission-gully-motorway/about-the-project/public-private-partnership/ppp-contract-development/',
#     'score': 0.8196707367897034,
#     'id': 'Project Agreement-AVAILABLE-https://www.nzta.govt.nz/projects/wellington-northern-corridor/transmission-gully-motorway/about-the-project/public-private-partnership/ppp-contract-development/'},
#    {'head': 'New Zealand Transport Agency',
#     'relation': 'UNDERTAKES',
#     'tail': 'review of public transport fare policy',
#     'score': 0.7804255485534668,
#     'id': 'New Zealand Transport Agency-UNDERTAKES-review of public transport fare policy'},
#    {'head': 'Fergus Gammie',
#     'relation': 'BRIEFING',
#     'tail': 'Briefing for Fergus on WCC proposal to install non-complying rainbow pedestrian crossing traffic control device',
#     'score': 0.810894250869751,
#     'id': 'Fergus Gammie-BRIEFING-Briefing for Fergus on WCC proposal to install non-complying rainbow pedestrian crossing traffic control device'}]},
#  {'question': 'What is the reason Waka Kotahi does not provide regional breakdowns for Road User Charges, vehicle registration, and licensing data?',
#   'triplets': [{'head': 'Crash Analysis System',
#     'relation': 'MAINTAINS',
#     'tail': 'Waka Kotahi N Z Transport Agency',
#     'score': 0.855219841003418,
#     'id': 'Crash Analysis System-MAINTAINS-Waka Kotahi N Z Transport Agency'},
#    {'head': 'Waka Kotahi NZ Transport Agency',
#     'relation': 'WEBSITE',
# ...
#     'tail': 'heavy motorhomes',
#     'score': 0.8816101551055908,
#     'id': 'occupancy protection-CONCERN-heavy motorhomes'},
#    {'head': 'Transport Services',
#     'relation': 'RELATES_TO',
#     'tail': 'Occupancy Protection',
#     'score': 0.8877240419387817,
#     'id': 'Transport Services-RELATES_TO-Occupancy Protection'},
#    {'head': 'Occupancy Protection',
#     'relation': 'ASSOCIATED_WITH',
#     'tail': 'Cab Cut-out Vehicles',
#     'score': 0.8716310858726501,
#     'id': 'Occupancy Protection-ASSOCIATED_WITH-Cab Cut-out Vehicles'},
#    {'head': 'Request made under the Official Information Act 1982',
#     'relation': 'OFFICIAL_INFORMATION',
#     'tail': 'Thank you for your email of',
#     'score': 28.0,
#     'id': 'Request made under the Official Information Act 1982-OFFICIAL_INFORMATION-Thank you for your email of'},
#    {'head': 'Thank you for your email of 28 July 2021 requesting information regarding occupancy protection and protection of cab cut out vehicles under the Official Information Act 1982 (the Act).',
#     'relation': 'OFFICIAL_INFORMATION',
#     'tail': 'I will respond to each of your questions in turn.',
#     'score': 0.8374080061912537,
#     'id': 'Thank you for your email of 28 July 2021 requesting information regarding occupancy protection and protection of cab cut out vehicles under the Official Information Act 1982 (the Act).-OFFICIAL_INFORMATION-I will respond to each of your questions in turn.'}]},
#  {'question': 'Has Waka Kotahi carried out tests comparing steel reinforcement versus fiberglass or wood in cab cut-outs?',
#   'triplets': [{'head': 'steel',
#     'relation': 'VS',
#     'tail': 'fibreglass or wood',
#     'score': 0.8725225925445557,
#     'id': 'steel-VS-fibreglass or wood'},
#    {'head': 'fibreglass or wood',
#     'relation': 'TESTED',
#     'tail': 'tests',
#     'score': 0.8713247776031494,
#     'id': 'fibreglass or wood-TESTED-tests'},
#    {'head': 'I will respond to each of your questions in turn.',
#     'relation': 'OFFICIAL_INFORMATION',
#     'tail': '1. NZTA has stated that a risk to Occupancy Protection has been identified where a cab cut-out is present. Please provide evidence of such risk and how a cab-cut is shown to directly increase that risk.',
#     'score': 0.8394453525543213,
#     'id': 'I will respond to each of your questions in turn.-OFFICIAL_INFORMATION-1. NZTA has stated that a risk to Occupancy Protection has been identified where a cab cut-out is present. Please provide evidence of such risk and how a cab-cut is shown to directly increase that risk.'},
#    {'head': '1. NZTA has stated that a risk to Occupancy Protection has been identified where a cab cut-out is present. Please provide evidence of such risk and how a cab-cut is shown to directly increase that risk.',
#     'relation': 'OFFICIAL_INFORMATION',
#     'tail': 'I am refusing this part of your request under section',
#     'score': 18.0,
#     'id': '1. NZTA has stated that a risk to Occupancy Protection has been identified where a cab cut-out is present. Please provide evidence of such risk and how a cab-cut is shown to directly increase that risk.-OFFICIAL_INFORMATION-I am refusing this part of your request under section'},
#    {'head': 'steel is present reinforcing the ca b cut-out',
#     'relation': 'VS',
#     'tail': 'fibreglass or wood',
#     'score': 0.880901038646698,
#     'id': 'steel is present reinforcing the ca b cut-out-VS-fibreglass or wood'},
#    {'head': 'comparable tests',
#     'relation': 'WHERE',
#     'tail': 'steel is present reinforcing the ca b cut-out',
#     'score': 0.87354576587677,
#     'id': 'comparable tests-WHERE-steel is present reinforcing the ca b cut-out'},
#    {'head': 'New Zealand Transport Agency',
#     'relation': 'PROVIDES',
#     'tail': 'information to Waka Kotahi',
#     'score': 0.804025411605835,
#     'id': 'New Zealand Transport Agency-PROVIDES-information to Waka Kotahi'}]},
#  {'question': 'What was the total cost for the SH2 Hebden Crescent / Liverton Road intersection project?',
#   'triplets': [{'head': 'New Zealand Transport Agency',
#     'relation': 'RESPONDS_TO',
#     'tail': 'Request for information on Hornby Intersection improvements',
#     'score': 0.8174709677696228,
#     'id': 'New Zealand Transport Agency-RESPONDS_TO-Request for information on Hornby Intersection improvements'},
#    {'head': 'Featherston',
#     'relation': 'RAISED_CROSSINGS',
#     'tail': 'one crossing near SH2/Lyon Street/Birdwood Street intersection',
#     'score': 0.824114203453064,
#     'id': 'Featherston-RAISED_CROSSINGS-one crossing near SH2/Lyon Street/Birdwood Street intersection'},
#    {'head': 'New Zealand Transport Agency',
#     'relation': 'PRODUCES',
#     'tail': 'report on the impacts of the Fare Recovery Ratio',
#     'score': 0.7849465608596802,
#     'id': 'New Zealand Transport Agency-PRODUCES-report on the impacts of the Fare Recovery Ratio'},
#    {'head': 'New Zealand Transport Agency',
#     'relation': 'PROVIDES',
#     'tail': 'cost breakdown for Greater Christchurch Mass Rapid Transit',
#     'score': 0.79380863904953,
#     'id': 'New Zealand Transport Agency-PROVIDES-cost breakdown for Greater Christchurch Mass Rapid Transit'}]},
#  {'question': 'Who should be contacted to discuss the SH2 Hebden Crescent / Liverton Road intersection project?',
#   'triplets': [{'head': 'New Zealand Transport Agency',
#     'relation': 'RESPONDS_TO',
#     'tail': 'Request for information on Hornby Intersection improvements',
#     'score': 0.8491339683532715,
#     'id': 'New Zealand Transport Agency-RESPONDS_TO-Request for information on Hornby Intersection improvements'},
#    {'head': 'Request made under the Official Information Act 1982',
#     'relation': 'REQUESTS',
#     'tail': 'detail on any contracting of consultants to work on the investigations of the long tunnel option for Wellington (Terrace to Kilbirnie)',
#     'score': 0.8256518840789795,
#     'id': 'Request made under the Official Information Act 1982-REQUESTS-detail on any contracting of consultants to work on the investigations of the long tunnel option for Wellington (Terrace to Kilbirnie)'},
#    {'head': 'detail on any contracting of consultants to work on the investigations of the long tunnel option for Wellington (Terrace to Kilbirnie)',
#     'relation': 'CONTRACTS',
#     'tail': 'consultants',
#     'score': 0.8117787837982178,
#     'id': 'detail on any contracting of consultants to work on the investigations of the long tunnel option for Wellington (Terrace to Kilbirnie)-CONTRACTS-consultants'},
#    {'head': 'Featherston',
#     'relation': 'RAISED_CROSSINGS',
#     'tail': 'one crossing near SH2/Lyon Street/Birdwood Street intersection',
#     'score': 0.8307766914367676,
#     'id': 'Featherston-RAISED_CROSSINGS-one crossing near SH2/Lyon Street/Birdwood Street intersection'},
#    {'head': 'Jordan Bond',
#     'relation': 'MADE_REQUEST',
#     'tail': 'request to Minister of Transport',
#     'score': 0.8144181966781616,
#     'id': 'Jordan Bond-MADE_REQUEST-request to Minister of Transport'}]},
#  {'question': 'What communication has Waka Kotahi had regarding the Ashburton Bridge since January 2023?',
#   'triplets': [{'head': 'Waka Kotahi',
#     'relation': 'CONTACT',
#     'tail': '64-4-894',
#     'score': 5251.0,
#     'id': 'Waka Kotahi-CONTACT-64-4-894'},
#    {'head': 'Waka Kotahi',
#     'relation': 'SEEKS',
#     'tail': 'additional information',
#     'score': 0.8575963377952576,
#     'id': 'Waka Kotahi-SEEKS-additional information'},
#    {'head': 'Waka Kotahi',
#     'relation': 'IS',
#     'tail': 'New Zealand Transport Agency',
#     'score': 0.8574013710021973,
#     'id': 'Waka Kotahi-IS-New Zealand Transport Agency'},
#    {'head': 'Waka Kotahi',
#     'relation': 'DISCUSS',
#     'tail': 'Ministerial Services',
#     'score': 0.8567208647727966,
#     'id': 'Waka Kotahi-DISCUSS-Ministerial Services'},
#    {'head': 'Waka Kotahi',
#     'relation': 'CONTACTABLE',
#     'tail': 'official.correspondence@nzta.govt.nz',
#     'score': 0.8563278317451477,
#     'id': 'Waka Kotahi-CONTACTABLE-official.correspondence@nzta.govt.nz'},
#    {'head': 'response letter',
#     'relation': 'DISCUSSED',
#     'tail': 'Waka Kotahi',
#     'score': 0.8561269044876099,
#     'id': 'response letter-DISCUSSED-Waka Kotahi'},
#    {'head': 'New Zealand Transport Agency',
#     'relation': 'PROVIDES',
#     'tail': 'information to Waka Kotahi',
#     'score': 0.8501396179199219,
#     'id': 'New Zealand Transport Agency-PROVIDES-information to Waka Kotahi'},
#    {'head': 'Waka Kotahi NZ Transport Agency',
#     'relation': 'CONTACT',
#     'tail': 'T',
#     'score': 64.0,
#     'id': 'Waka Kotahi NZ Transport Agency-CONTACT-T'},
#    {'head': 'Waka Kotahi NZ Transport Agency',
#     'relation': 'PUBLISHES',
#     'tail': 'response',
#     'score': 0.8466371297836304,
#     'id': 'Waka Kotahi NZ Transport Agency-PUBLISHES-response'},
#    {'head': 'Waka Kotahi NZ Transport Agency',
#     'relation': 'PUBLISHES',
#     'tail': 'response on website',
#     'score': 0.8446374535560608,
#     'id': 'Waka Kotahi NZ Transport Agency-PUBLISHES-response on website'},
#    {'head': 'Waka Kotahi NZ Transport Agency',
#     'relation': 'COUNTRY',
#     'tail': 'New Zealand',
#     'score': 0.844450831413269,
#     'id': 'Waka Kotahi NZ Transport Agency-COUNTRY-New Zealand'},
#    {'head': 'Waka Kotahi NZ Transport Agency',
#     'relation': 'COLLABORATES_WITH',
#     'tail': 'Tauranga City Council',
#     'score': 0.8416389226913452,
#     'id': 'Waka Kotahi NZ Transport Agency-COLLABORATES_WITH-Tauranga City Council'},
#    {'head': 'Waka Kotahi NZ Transport Agency',
#     'relation': 'WEBSITE',
#     'tail': 'www.nzta.govt.nz',
#     'score': 0.8400295972824097,
#     'id': 'Waka Kotahi NZ Transport Agency-WEBSITE-www.nzta.govt.nz'},
#    {'head': 'Robyn Elston',
#     'relation': 'RESPONDS',
#     'tail': 'Waka Kotahi NZ Transport Agency',
#     'score': 0.839604914188385,
#     'id': 'Robyn Elston-RESPONDS-Waka Kotahi NZ Transport Agency'},
#    {'head': 'Data',
#     'relation': 'PROVIDED',
#     'tail': 'Waka Kotahi N Z Transport Agency',
#     'score': 0.8170425295829773,
#     'id': 'Data-PROVIDED-Waka Kotahi N Z Transport Agency'},
#    {'head': 'Crash Analysis System',
#     'relation': 'MAINTAINS',
#     'tail': 'Waka Kotahi N Z Transport Agency',
#     'score': 0.7884831428527832,
#     'id': 'Crash Analysis System-MAINTAINS-Waka Kotahi N Z Transport Agency'}]},
#  {'question': 'Where can formal advice on the second Ashburton Bridge be found?',
#   'triplets': [{'head': 'Information in Scope',
#     'relation': 'RELATES_TO',
#     'tail': 'Ashburton Bridge',
#     'score': 0.8550906181335449,
#     'id': 'Information in Scope-RELATES_TO-Ashburton Bridge'},
#    {'head': 'Information',
#     'relation': 'RELATES_TO',
#     'tail': 'proposed second bridge',
#     'score': 0.866146445274353,
#     'id': 'Information-RELATES_TO-proposed second bridge'},
#    {'head': 'Information in Scope',
#     'relation': 'RELATES_TO',
#     'tail': 'proposed second bridge',
#     'score': 0.8577600121498108,
#     'id': 'Information in Scope-RELATES_TO-proposed second bridge'},
#    {'head': 'Ashburton District Councillors',
#     'relation': 'RECEIVES',
#     'tail': 'written communication',
#     'score': 0.829969584941864,
#     'id': 'Ashburton District Councillors-RECEIVES-written communication'},
#    {'head': 'Ashburton-Tin wald Connectivity Business Case',
#     'relation': 'PROVIDED',
#     'tail': 'attached document',
#     'score': 0.8181138038635254,
#     'id': 'Ashburton-Tin wald Connectivity Business Case-PROVIDED-attached document'}]},
#  {'question': 'How many complaints did NZTA receive about vehicle certifications not being performed correctly since January 1, 2010?',
#   'triplets': [{'head': 'Waka Kotahi',
#     'relation': 'RECEIVES',
#     'tail': '196 complaints about Uber drivers',
#     'score': 0.8066796660423279,
#     'id': 'Waka Kotahi-RECEIVES-196 complaints about Uber drivers'},
#    {'head': 'Request for Information',
#     'relation': 'REQUESTS',
#     'tail': 'Complaint Data',
#     'score': 0.7922708988189697,
#     'id': 'Request for Information-REQUESTS-Complaint Data'},
#    {'head': 'Waka Kotahi',
#     'relation': 'REFUSES_REQUEST',
#     'tail': 'vehicle registration and licensing',
#     'score': 0.8350653052330017,
#     'id': 'Waka Kotahi-REFUSES_REQUEST-vehicle registration and licensing'}]},
#  {'question': 'Were any complaints about vehicle certifications upheld, and what actions were taken?',
#   'triplets': [{'head': 'Waka Kotahi',
#     'relation': 'REFUSES_REQUEST',
#     'tail': 'vehicle registration and licensing',
#     'score': 0.851997971534729,
#     'id': 'Waka Kotahi-REFUSES_REQUEST-vehicle registration and licensing'},
#    {'head': 'Waka Kotahi',
#     'relation': 'RECEIVES',
#     'tail': '196 complaints about Uber drivers',
#     'score': 0.8082746267318726,
#     'id': 'Waka Kotahi-RECEIVES-196 complaints about Uber drivers'},
#    {'head': 'Land Transport (Road User) Rule 2004',
#     'relation': 'SPECIFIES',
#     'tail': 'instances where a driver and/or passenger may automatically be excused from the requirement to utilise a child restrain and seatbelt',
#     'score': 0.8005300760269165,
#     'id': 'Land Transport (Road User) Rule 2004-SPECIFIES-instances where a driver and/or passenger may automatically be excused from the requirement to utilise a child restrain and seatbelt'}]},
#  {'question': 'Under what inspecting organization (IO) authority did VINZ operate prior to and after March 2015?',
#   'triplets': [{'head': 'Sale of VINZ',
#     'relation': 'DATE',
#     'tail': 'March',
#     'score': 2015.0,
#     'id': 'Sale of VINZ-DATE-March'},
#    {'head': 'own inspecting authority number',
#     'relation': 'ENABLES',
#     'tail': 'inspect vehicles',
#     'score': 0.8223989009857178,
#     'id': 'own inspecting authority number-ENABLES-inspect vehicles'},
#    {'head': 'appointment as an inspecting organisation',
#     'relation': 'LEADS_TO',
#     'tail': 'own inspecting authority number',
#     'score': 0.8217447996139526,
#     'id': 'appointment as an inspecting organisation-LEADS_TO-own inspecting authority number'},
#    {'head': 'New Zealand Transport Agency',
#     'relation': 'ASSOCIATED',
#     'tail': 'Enforcement of regulatory role',
#     'score': 0.8022544384002686,
#     'id': 'New Zealand Transport Agency-ASSOCIATED-Enforcement of regulatory role'},
#    {'head': 'Meredith Connell',
#     'relation': 'ASSOCIATED',
#     'tail': 'Enforcement of regulatory role',
#     'score': 0.7667723894119263,
#     'id': 'Meredith Connell-ASSOCIATED-Enforcement of regulatory role'},
#    {'head': 'New Zealand Transport Agency',
#     'relation': 'REGULATORY',
#     'tail': 'Review of regulatory role',
#     'score': 0.7905685901641846,
#     'id': 'New Zealand Transport Agency-REGULATORY-Review of regulatory role'}]},
#  {'question': 'When was NZTA advised about the sale of VINZ, and what were the implications for vehicle inspection authority?',
#   'triplets': [{'head': 'Sale of VINZ',
#     'relation': 'DATE',
#     'tail': 'March',
#     'score': 2015.0,
#     'id': 'Sale of VINZ-DATE-March'},
#    {'head': 'New Zealand Transport Agency',
#     'relation': 'RESPONSE',
#     'tail': 'Thank you for your email of',
#     'score': 13.0,
#     'id': 'New Zealand Transport Agency-RESPONSE-Thank you for your email of'},
#    {'head': 'Vehicle Inspection',
#     'relation': 'CONDUCTED_BY',
#     'tail': 'New Zealand Transport Agency',
#     'score': 0.8666824698448181,
#     'id': 'Vehicle Inspection-CONDUCTED_BY-New Zealand Transport Agency'},
#    {'head': 'New Zealand',
#     'relation': 'REGULATES',
#     'tail': 'Vehicle Inspection',
#     'score': 0.8570104241371155,
#     'id': 'New Zealand-REGULATES-Vehicle Inspection'},
#    {'head': 'Vehicle Inspection',
#     'relation': 'PROVIDES',
#     'tail': 'Safety Information',
#     'score': 0.822128415107727,
#     'id': 'Vehicle Inspection-PROVIDES-Safety Information'},
#    {'head': 'Vehicle Inspection',
#     'relation': 'Undertakes',
#     'tail': 'Calculations',
#     'score': 0.813369631767273,
#     'id': 'Vehicle Inspection-Undertakes-Calculations'},
#    {'head': 'Auckland Transport',
#     'relation': 'SUBMITS',
#     'tail': 'bid for NZ Transport Agency funding',
#     'score': 0.8232093453407288,
#     'id': 'Auckland Transport-SUBMITS-bid for NZ Transport Agency funding'}]})

# %%
import math

def calculate_mrr(data):
    """
    Calculates the Mean Reciprocal Rank (MRR) and returns per-entry reciprocal ranks.
    
    Parameters:
    - data (List[Dict]): List of entries with 'triplets' sorted by retrieval model.
    
    Returns:
    - float: The overall MRR score.
    - List[float]: Reciprocal ranks for each entry.
    """
    mrr = 0.0
    reciprocal_ranks = []
    for entry in data:
        rr = 0.0
        for idx, triplet in enumerate(entry['triplets']):
            if triplet['relevant'] == 1:
                rr = 1.0 / (idx + 1)
                break
        reciprocal_ranks.append(rr)
        mrr += rr
    overall_mrr = mrr / len(data) if data else 0.0
    return overall_mrr, reciprocal_ranks


def calculate_ndcg(data, k=28):
    """
    Calculates the average Normalized Discounted Cumulative Gain (nDCG) and returns per-entry nDCG scores.
    
    Parameters:
    - data (List[Dict]): List of entries with 'triplets' sorted by retrieval model.
    - k (int, optional): Rank position to calculate DCG up to. Defaults to 28.
    
    Returns:
    - float: The average nDCG score.
    - List[float]: nDCG scores for each entry.
    """
    dcg_sum = 0.0
    idcg_sum = 0.0
    ndcg_scores = []
    for entry in data:
        triplets = entry['triplets'][:k]
        
        # Calculate DCG
        dcg = sum(
            triplet['relevant'] / math.log2(idx + 2) 
            for idx, triplet in enumerate(triplets)
        )
        dcg_sum += dcg
        
        # Calculate Ideal DCG
        ideal_triplets = sorted(entry['triplets'], key=lambda x: x['relevant'], reverse=True)[:k]
        idcg = sum(
            triplet['relevant'] / math.log2(idx + 2) 
            for idx, triplet in enumerate(ideal_triplets)
        )
        idcg_sum += idcg if idcg > 0 else 1.0  # Avoid division by zero
        
        # Calculate nDCG for the entry
        ndcg = dcg / idcg if idcg > 0 else 0.0
        ndcg_scores.append(ndcg)
    
    average_ndcg = dcg_sum / idcg_sum if idcg_sum > 0 else 0.0
    return average_ndcg, ndcg_scores


def calculate_precision_at_k(data, k):
    """
    Calculates the average Precision at K (P@K) and returns per-entry precision scores.
    
    Parameters:
    - data (List[Dict]): List of entries with 'triplets' sorted by retrieval model.
    - k (int): The rank position to calculate precision up to.
    
    Returns:
    - float: The average P@K score.
    - List[float]: Precision scores for each entry.
    """
    precision_sum = 0.0
    precision_scores = []
    for entry in data:
        triplets = entry['triplets'][:k]
        relevant_count = sum(triplet['relevant'] for triplet in triplets)
        precision = relevant_count / k
        precision_scores.append(precision)
        precision_sum += precision
    average_precision = precision_sum / len(data) if data else 0.0
    return average_precision, precision_scores


# Assuming clean_sorted_data_with_ranking and clean_unsorted_data_with_ranking are defined

# Calculate metrics for sorted data
mrr_sorted, mrr_sorted_list = calculate_mrr(clean_sorted_data_with_ranking)
ndcg_sorted, ndcg_sorted_list = calculate_ndcg(clean_sorted_data_with_ranking, k=28)
precision_at_28_sorted, precision_at_28_sorted_list = calculate_precision_at_k(clean_sorted_data_with_ranking, k=28)
precision_at_14_sorted, precision_at_14_sorted_list = calculate_precision_at_k(clean_sorted_data_with_ranking, k=14)
precision_at_7_sorted, precision_at_7_sorted_list = calculate_precision_at_k(clean_sorted_data_with_ranking, k=7)

# Calculate metrics for unsorted data
mrr_unsorted, mrr_unsorted_list = calculate_mrr(clean_unsorted_data_with_ranking)
ndcg_unsorted, ndcg_unsorted_list = calculate_ndcg(clean_unsorted_data_with_ranking, k=28)
precision_at_28_unsorted, precision_at_28_unsorted_list = calculate_precision_at_k(clean_unsorted_data_with_ranking, k=28)
precision_at_14_unsorted, precision_at_14_unsorted_list = calculate_precision_at_k(clean_unsorted_data_with_ranking, k=14)
precision_at_7_unsorted, precision_at_7_unsorted_list = calculate_precision_at_k(clean_unsorted_data_with_ranking, k=7)

# Print overall metrics
print(f"Mean Reciprocal Rank (MRR) for sorted data: {mrr_sorted:.4f}")
print(f"Mean Reciprocal Rank (MRR) for unsorted data: {mrr_unsorted:.4f}\n")

print(f"Normalized Discounted Cumulative Gain (nDCG@28) for sorted data: {ndcg_sorted:.4f}")
print(f"Normalized Discounted Cumulative Gain (nDCG@28) for unsorted data: {ndcg_unsorted:.4f}\n")

print(f"Precision at 28 (P@28) for sorted data: {precision_at_28_sorted:.4f}")
print(f"Precision at 28 (P@28) for unsorted data: {precision_at_28_unsorted:.4f}\n")

print(f"Precision at 14 (P@14) for sorted data: {precision_at_14_sorted:.4f}")
print(f"Precision at 14 (P@14) for unsorted data: {precision_at_14_unsorted:.4f}\n")

print(f"Precision at 7 (P@7) for sorted data: {precision_at_7_sorted:.4f}")
print(f"Precision at 7 (P@7) for unsorted data: {precision_at_7_unsorted:.4f}")


# print(f"Mean Reciprocal Rank (MRR) for unsorted data: {mrr_score_unsorted:.4f}")
# print(f"Normalized Discounted Cumulative Gain (nDCG@10) for unsorted data: {ndcg_score_unsorted:.4f}")
# print(f"Precision at 10 for unsorted data: {precision_at_10_unsorted:.4f}")




### for d=1
# Mean Reciprocal Rank (MRR) for sorted data: 0.5923
# Mean Reciprocal Rank (MRR) for unsorted data: 0.5753

# Normalized Discounted Cumulative Gain (nDCG@30) for sorted data: 0.7057
# Normalized Discounted Cumulative Gain (nDCG@30) for unsorted data: 0.6789

# Precision at 10 (P@10) for sorted data: 0.1970
# Precision at 10 (P@10) for unsorted data: 0.1725


## fod d=2
# Mean Reciprocal Rank (MRR) for sorted data: 0.5683
# Mean Reciprocal Rank (MRR) for unsorted data: 0.2587

# Normalized Discounted Cumulative Gain (nDCG@30) for sorted data: 0.6859
# Normalized Discounted Cumulative Gain (nDCG@30) for unsorted data: 0.4495

# Precision at 10 (P@10) for sorted data: 0.2425
# Precision at 10 (P@10) for unsorted data: 0.1040

## for d=3
# Mean Reciprocal Rank (MRR) for sorted data: 0.5663
# Mean Reciprocal Rank (MRR) for unsorted data: 0.2149

# Normalized Discounted Cumulative Gain (nDCG@30) for sorted data: 0.6948
# Normalized Discounted Cumulative Gain (nDCG@30) for unsorted data: 0.3801

# Precision at 10 (P@10) for sorted data: 0.2715
# Precision at 10 (P@10) for unsorted data: 0.0775

## for d=4
# Mean Reciprocal Rank (MRR) for sorted data: 0.5597
# Mean Reciprocal Rank (MRR) for unsorted data: 0.1840

# Normalized Discounted Cumulative Gain (nDCG@30) for sorted data: 0.6873
# Normalized Discounted Cumulative Gain (nDCG@30) for unsorted data: 0.3655

# Precision at 10 (P@10) for sorted data: 0.2680
# Precision at 10 (P@10) for unsorted data: 0.0720

## d=5

# Mean Reciprocal Rank (MRR) for sorted data: 0.5931
# Mean Reciprocal Rank (MRR) for unsorted data: 0.1853

# Normalized Discounted Cumulative Gain (nDCG@30) for sorted data: 0.7198
# Normalized Discounted Cumulative Gain (nDCG@30) for unsorted data: 0.3345

# Precision at 10 (P@10) for sorted data: 0.2775
# Precision at 10 (P@10) for unsorted data: 0.0555


## d=6
# Mean Reciprocal Rank (MRR) for sorted data: 0.5891
# Mean Reciprocal Rank (MRR) for unsorted data: 0.1697

# Normalized Discounted Cumulative Gain (nDCG@30) for sorted data: 0.7094
# Normalized Discounted Cumulative Gain (nDCG@30) for unsorted data: 0.2935

# Precision at 10 (P@10) for sorted data: 0.2655
# Precision at 10 (P@10) for unsorted data: 0.0450


##################### correct data ############################

#d1
# Mean Reciprocal Rank (MRR) for sorted data: 0.6087
# Mean Reciprocal Rank (MRR) for unsorted data: 0.5797

# Normalized Discounted Cumulative Gain (nDCG@28) for sorted data: 0.7200
# Normalized Discounted Cumulative Gain (nDCG@28) for unsorted data: 0.6857

# Precision at 28 (P@28) for sorted data: 0.0745
# Precision at 28 (P@28) for unsorted data: 0.0700

# Precision at 14 (P@14) for sorted data: 0.1479
# Precision at 14 (P@14) for unsorted data: 0.1307

# Precision at 7 (P@7) for sorted data: 0.2579
# Precision at 7 (P@7) for unsorted data: 0.2257

#d2
#Mean Reciprocal Rank (MRR) for sorted data: 0.5683
# Mean Reciprocal Rank (MRR) for unsorted data: 0.2587

# Normalized Discounted Cumulative Gain (nDCG@28) for sorted data: 0.6859
# Normalized Discounted Cumulative Gain (nDCG@28) for unsorted data: 0.4476

# Precision at 28 (P@28) for sorted data: 0.1298
# Precision at 28 (P@28) for unsorted data: 0.0620

# Precision at 14 (P@14) for sorted data: 0.2157
# Precision at 14 (P@14) for unsorted data: 0.0861

# Precision at 7 (P@7) for sorted data: 0.2736
# Precision at 7 (P@7) for unsorted data: 0.1171

#d3
# Mean Reciprocal Rank (MRR) for sorted data: 0.5512
# Mean Reciprocal Rank (MRR) for unsorted data: 0.2520

# Normalized Discounted Cumulative Gain (nDCG@28) for sorted data: 0.6793
# Normalized Discounted Cumulative Gain (nDCG@28) for unsorted data: 0.4342

# Precision at 28 (P@28) for sorted data: 0.1282
# Precision at 28 (P@28) for unsorted data: 0.0593

# Precision at 14 (P@14) for sorted data: 0.2111
# Precision at 14 (P@14) for unsorted data: 0.0807

# Precision at 7 (P@7) for sorted data: 0.2679
# Precision at 7 (P@7) for unsorted data: 0.1086

#d4
# Mean Reciprocal Rank (MRR) for sorted data: 0.5655
# Mean Reciprocal Rank (MRR) for unsorted data: 0.1932

# Normalized Discounted Cumulative Gain (nDCG@28) for sorted data: 0.6879
# Normalized Discounted Cumulative Gain (nDCG@28) for unsorted data: 0.3425

# Precision at 28 (P@28) for sorted data: 0.1221
# Precision at 28 (P@28) for unsorted data: 0.0375

# Precision at 14 (P@14) for sorted data: 0.2218
# Precision at 14 (P@14) for unsorted data: 0.0539

# Precision at 7 (P@7) for sorted data: 0.3150
# Precision at 7 (P@7) for unsorted data: 0.0764

#d5
# Mean Reciprocal Rank (MRR) for sorted data: 0.5931
# Mean Reciprocal Rank (MRR) for unsorted data: 0.1853

# Normalized Discounted Cumulative Gain (nDCG@28) for sorted data: 0.7198
# Normalized Discounted Cumulative Gain (nDCG@28) for unsorted data: 0.3316

# Precision at 28 (P@28) for sorted data: 0.1179
# Precision at 28 (P@28) for unsorted data: 0.0359

# Precision at 14 (P@14) for sorted data: 0.2214
# Precision at 14 (P@14) for unsorted data: 0.0493

# Precision at 7 (P@7) for sorted data: 0.3386
# Precision at 7 (P@7) for unsorted data: 0.0664

#d6
# Mean Reciprocal Rank (MRR) for sorted data: 0.5891
# Mean Reciprocal Rank (MRR) for unsorted data: 0.1697

# Normalized Discounted Cumulative Gain (nDCG@28) for sorted data: 0.7094
# Normalized Discounted Cumulative Gain (nDCG@28) for unsorted data: 0.2926

# Precision at 28 (P@28) for sorted data: 0.1063
# Precision at 28 (P@28) for unsorted data: 0.0295

# Precision at 14 (P@14) for sorted data: 0.2050
# Precision at 14 (P@14) for unsorted data: 0.0400

# Precision at 7 (P@7) for sorted data: 0.3314
# Precision at 7 (P@7) for unsorted data: 0.0550
# Out:
# Mean Reciprocal Rank (MRR) for sorted data: 0.5891
# Mean Reciprocal Rank (MRR) for unsorted data: 0.1697
#
# Normalized Discounted Cumulative Gain (nDCG@28) for sorted data: 0.7094
# Normalized Discounted Cumulative Gain (nDCG@28) for unsorted data: 0.2926
#
# Precision at 28 (P@28) for sorted data: 0.1063
# Precision at 28 (P@28) for unsorted data: 0.0295
#
# Precision at 14 (P@14) for sorted data: 0.2050
# Precision at 14 (P@14) for unsorted data: 0.0400
#
# Precision at 7 (P@7) for sorted data: 0.3314
# Precision at 7 (P@7) for unsorted data: 0.0550

# %%
import matplotlib.pyplot as plt

# Data for each metric including values for d=1 to d=6
d_values = [1, 2, 3, 4, 5, 6]
metrics_data = {
    "MRR": {
        "sorted": [0.5923, 0.5683, 0.5663, 0.5597, 0.5931, 0.5891],
        "unsorted": [0.5753, 0.2587, 0.2149, 0.1840, 0.1853, 0.1697]
    },
    "nDCG@30": {
        "sorted": [0.7057, 0.6859, 0.6948, 0.6873, 0.7198, 0.7094],
        "unsorted": [0.6789, 0.4495, 0.3801, 0.3655, 0.3345, 0.2935]
    },
    "P@10": {
        "sorted": [0.1970, 0.2425, 0.2715, 0.2680, 0.2775, 0.2655],
        "unsorted": [0.1725, 0.1040, 0.0775, 0.0720, 0.0555, 0.0450]
    }
}

# Colors for lines
sorted_color = '#1f77b4'  # Blue
unsorted_color = '#ff7f0e'  # Orange

# Create a figure with a 1x3 grid for the plots
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
fig.subplots_adjust(hspace=0.3, wspace=0.4)

# Plot each metric in a subplot
for ax, (metric, values) in zip(axes, metrics_data.items()):
    ax.plot(d_values, values["sorted"], marker='o', color=sorted_color, label="CSMR", linestyle="-")
    ax.plot(d_values, values["unsorted"], marker='o', color=unsorted_color, label="Original", linestyle="--")
    ax.set_title(f"{metric}", fontsize=14)
    ax.set_xlabel(r"Neighbor depth $\mathit{d}$", fontsize=12)
    ax.set_ylabel(metric, fontsize=12)
    ax.grid(True)
    
    # Add labels to each point
    for i, d in enumerate(d_values):
        ax.text(d, values["sorted"][i], f"{values['sorted'][i]:.4f}", ha="center", va="bottom", fontsize=10)
        ax.text(d, values["unsorted"][i], f"{values['unsorted'][i]:.4f}", ha="center", va="bottom", fontsize=10)

# Add a shared legend
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc="upper center", ncol=3, fontsize=12, title="Legend", title_fontsize=13, bbox_to_anchor=(0.5, 1.05))

plt.show()

# %%
import matplotlib.pyplot as plt

# Data for each metric including values for d=1 to d=6
d_values = [1, 2, 3, 4, 5, 6]
metrics_data = {
    "MRR": {
        "sorted": [0.6087, 0.5683, 0.5512, 0.5655, 0.5931, 0.5891],
        "unsorted": [0.5797, 0.2587, 0.2520, 0.1932, 0.1853, 0.1697]
    },
    "nDCG@28": {
        "sorted": [0.7200, 0.6859, 0.6793, 0.6879, 0.7198, 0.7094],
        "unsorted": [0.6857, 0.4476, 0.4342, 0.3425, 0.3316, 0.2926]
    },
    "P@28": {
        "sorted": [0.0745, 0.1298, 0.1282, 0.1221, 0.1179, 0.1063],
        "unsorted": [0.0700, 0.0620, 0.0593, 0.0375, 0.0359, 0.0295]
    },
    "P@14": {
        "sorted": [0.1479, 0.2157, 0.2111, 0.2218, 0.2214, 0.2050],
        "unsorted": [0.1307, 0.0861, 0.0807, 0.0539, 0.0493, 0.0400]
    },
    "P@7": {
        "sorted": [0.2579, 0.2736, 0.2679, 0.3150, 0.3386, 0.3314],
        "unsorted": [0.2257, 0.1171, 0.1086, 0.0764, 0.0664, 0.0550]
    }
}

# Colors for lines
sorted_color = '#1f77b4'  # Blue
unsorted_color = '#ff7f0e'  # Orange

# Update global font size
plt.rcParams.update({
    'font.size': 22,
    'axes.titlesize': 28,
    'axes.labelsize': 26,
    'xtick.labelsize': 22,
    'ytick.labelsize': 22,
    'legend.fontsize': 24,
    'legend.title_fontsize': 28
})

# Create a figure with a 2x3 grid for the plots
fig, axes = plt.subplots(2, 3, figsize=(30, 14))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

# Assign specific axes for each metric
mrr_ax = axes[0, 0]
ndcg_ax = axes[0, 1]
p28_ax = axes[1, 0]
p14_ax = axes[1, 1]
p7_ax = axes[1, 2]

# Define metrics and their corresponding axes
metric_axes = {
    "MRR": mrr_ax,
    "nDCG@28": ndcg_ax,
    "P@28": p28_ax,
    "P@14": p14_ax,
    "P@7": p7_ax
}

# Plot each metric in its assigned subplot
for metric, ax in metric_axes.items():
    values = metrics_data[metric]
    ax.plot(d_values, values["sorted"], marker='o', color=sorted_color, label="CSMR", linestyle="-")
    ax.plot(d_values, values["unsorted"], marker='o', color=unsorted_color, label="Original", linestyle="--")
    ax.set_title(f"{metric}", fontsize=28)
    ax.set_xlabel(r"Neighbor depth $\mathit{d}$", fontsize=26)
    ax.set_ylabel(metric, fontsize=26)
    ax.grid(True)
    ax.tick_params(axis='both', which='major', labelsize=22)

# Add a shared legend in the empty upper-right subplot space
handles, labels = mrr_ax.get_legend_handles_labels()
fig.legend(handles, labels, loc="center right", ncol=1, fontsize=24, title="SP-CoT - Node Retrieval Evaluation", title_fontsize=28, bbox_to_anchor=(0.88, 0.75))

# Hide the empty subplot in the top right (axes[0, 2])
fig.delaxes(axes[0, 2])

plt.show()

# %%
metrics_sorted = {
    'mrr': mrr_sorted_list,
    'ndcg': ndcg_sorted_list,
    'precision_at_28': precision_at_28_sorted_list,
    'precision_at_14': precision_at_14_sorted_list,
    'precision_at_7': precision_at_7_sorted_list
}

metrics_unsorted = {
    'mrr': mrr_unsorted_list,
    'ndcg': ndcg_unsorted_list,
    'precision_at_28': precision_at_28_unsorted_list,
    'precision_at_14': precision_at_14_unsorted_list,
    'precision_at_7': precision_at_7_unsorted_list
}

# Example: Saving to JSON for later use
import json

with open('metrics_sorted.json', 'w') as f:
    json.dump(metrics_sorted, f, indent=4)

with open('metrics_unsorted.json', 'w') as f:
    json.dump(metrics_unsorted, f, indent=4)

print("\nPer-entry metrics have been saved to 'metrics_sorted.json' and 'metrics_unsorted.json'.")
# Out:
# Per-entry metrics have been saved to 'metrics_sorted.json' and 'metrics_unsorted.json'.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming metrics_sorted and metrics_unsorted are dictionaries containing the per-query metrics
# Create DataFrames for each metric
df_mrr = pd.DataFrame({
    'Condition': ['Sorted'] * len(metrics_sorted['mrr']) + ['Unsorted'] * len(metrics_unsorted['mrr']),
    'MRR': metrics_sorted['mrr'] + metrics_unsorted['mrr']
})

df_ndcg = pd.DataFrame({
    'Condition': ['Sorted'] * len(metrics_sorted['ndcg']) + ['Unsorted'] * len(metrics_unsorted['ndcg']),
    'nDCG@30': metrics_sorted['ndcg'] + metrics_unsorted['ndcg']
})

df_p_at_k = pd.DataFrame({
    'Condition': ['Sorted'] * len(metrics_sorted['precision_at_10']) + ['Unsorted'] * len(metrics_unsorted['precision_at_10']),
    'P@10': metrics_sorted['precision_at_10'] + metrics_unsorted['precision_at_10']
})

# Create DataFrames for differences between sorted and unsorted for each metric
df_diff_mrr = pd.DataFrame({
    'Difference (MRR)': [sorted_val - unsorted_val for sorted_val, unsorted_val in zip(metrics_sorted['mrr'], metrics_unsorted['mrr'])]
})

df_diff_ndcg = pd.DataFrame({
    'Difference (nDCG@30)': [sorted_val - unsorted_val for sorted_val, unsorted_val in zip(metrics_sorted['ndcg'], metrics_unsorted['ndcg'])]
})

df_diff_p_at_k = pd.DataFrame({
    'Difference (P@10)': [sorted_val - unsorted_val for sorted_val, unsorted_val in zip(metrics_sorted['precision_at_10'], metrics_unsorted['precision_at_10'])]
})

# Set the aesthetic style of the plots
sns.set(style="whitegrid")

# Initialize the matplotlib figure with 2 rows and 3 columns
fig, axes = plt.subplots(2, 3, figsize=(21, 12))

# Define a color palette
palette = {"Sorted": "skyblue", "Unsorted": "salmon"}

# Plot MRR Histogram
sns.histplot(data=df_mrr, x='MRR', hue='Condition', element='step', stat='density',
             common_norm=False, palette=palette, ax=axes[0, 0])
axes[0, 0].set_title('Mean Reciprocal Rank (MRR)', fontsize=14)
axes[0, 0].set_xlabel('MRR', fontsize=12)
axes[0, 0].set_ylabel('Density', fontsize=12)

# Plot nDCG@30 Histogram
sns.histplot(data=df_ndcg, x='nDCG@30', hue='Condition', element='step', stat='density',
             common_norm=False, palette=palette, ax=axes[0, 1])
axes[0, 1].set_title('Normalized Discounted Cumulative Gain (nDCG@30)', fontsize=14)
axes[0, 1].set_xlabel('nDCG@30', fontsize=12)
axes[0, 1].set_ylabel('Density', fontsize=12)

# Plot Precision@10 Histogram
sns.histplot(data=df_p_at_k, x='P@10', hue='Condition', element='step', stat='density',
             common_norm=False, palette=palette, ax=axes[0, 2])
axes[0, 2].set_title('Precision at 10 (P@10)', fontsize=14)
axes[0, 2].set_xlabel('P@10', fontsize=12)
axes[0, 2].set_ylabel('Density', fontsize=12)

# Plot Differences MRR
sns.histplot(data=df_diff_mrr, x='Difference (MRR)', kde=True, color="purple", ax=axes[1, 0])
axes[1, 0].set_title('Difference (MRR)', fontsize=14)
axes[1, 0].set_xlabel('Difference (MRR)', fontsize=12)
axes[1, 0].set_ylabel('Density', fontsize=12)

# Plot Differences nDCG@30
sns.histplot(data=df_diff_ndcg, x='Difference (nDCG@30)', kde=True, color="green", ax=axes[1, 1])
axes[1, 1].set_title('Difference (nDCG@30)', fontsize=14)
axes[1, 1].set_xlabel('Difference (nDCG@30)', fontsize=12)
axes[1, 1].set_ylabel('Density', fontsize=12)

# Plot Differences P@10
sns.histplot(data=df_diff_p_at_k, x='Difference (P@10)', kde=True, color="orange", ax=axes[1, 2])
axes[1, 2].set_title('Difference (P@10)', fontsize=14)
axes[1, 2].set_xlabel('Difference (P@10)', fontsize=12)
axes[1, 2].set_ylabel('Density', fontsize=12)

# Adjust layout
plt.tight_layout()

# Display the plots
plt.show()

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt

# Calculate differences for each metric
differences_mrr = [sorted_val - unsorted_val for sorted_val, unsorted_val in zip(metrics_sorted['mrr'], metrics_unsorted['mrr'])]
differences_ndcg = [sorted_val - unsorted_val for sorted_val, unsorted_val in zip(metrics_sorted['ndcg'], metrics_unsorted['ndcg'])]
differences_p_at_28 = [sorted_val - unsorted_val for sorted_val, unsorted_val in zip(metrics_sorted['precision_at_28'], metrics_unsorted['precision_at_28'])]
differences_p_at_14 = [sorted_val - unsorted_val for sorted_val, unsorted_val in zip(metrics_sorted['precision_at_14'], metrics_unsorted['precision_at_14'])]
differences_p_at_7 = [sorted_val - unsorted_val for sorted_val, unsorted_val in zip(metrics_sorted['precision_at_7'], metrics_unsorted['precision_at_7'])]

# Perform Shapiro-Wilk test for each metric
shapiro_mrr = stats.shapiro(differences_mrr)
shapiro_ndcg = stats.shapiro(differences_ndcg)
shapiro_p_at_28 = stats.shapiro(differences_p_at_28)
shapiro_p_at_14 = stats.shapiro(differences_p_at_14)
shapiro_p_at_7 = stats.shapiro(differences_p_at_7)

print(f"Shapiro-Wilk test for MRR differences: p-value = {shapiro_mrr.pvalue:.4f}")
print(f"Shapiro-Wilk test for nDCG@28 differences: p-value = {shapiro_ndcg.pvalue:.4f}")
print(f"Shapiro-Wilk test for P@28 differences: p-value = {shapiro_p_at_28.pvalue:.4f}")
print(f"Shapiro-Wilk test for P@14 differences: p-value = {shapiro_p_at_14.pvalue:.4f}")
print(f"Shapiro-Wilk test for P@7 differences: p-value = {shapiro_p_at_7.pvalue:.4f}")


# Q-Q plot for MRR differences
plt.figure(figsize=(6, 6))
stats.probplot(differences_mrr, dist="norm", plot=plt)
plt.title("Q-Q Plot for MRR Differences")
plt.show()

# Q-Q plot for nDCG@28 differences
plt.figure(figsize=(6, 6))
stats.probplot(differences_ndcg, dist="norm", plot=plt)
plt.title("Q-Q Plot for nDCG@28 Differences")
plt.show()

# Q-Q plot for P@28 differences
plt.figure(figsize=(6, 6))
stats.probplot(differences_p_at_28, dist="norm", plot=plt)
plt.title("Q-Q Plot for P@28 Differences")
plt.show()

# Q-Q plot for P@14 differences
plt.figure(figsize=(6, 6))
stats.probplot(differences_p_at_14, dist="norm", plot=plt)
plt.title("Q-Q Plot for P@14 Differences")
plt.show()

# Q-Q plot for P@7 differences
plt.figure(figsize=(6, 6))
stats.probplot(differences_p_at_7, dist="norm", plot=plt)
plt.title("Q-Q Plot for P@7 Differences")

# d1
# Paired t-test Results:
# MRR: t-statistic = 0.9974, p-value = 3.1980e-01
# nDCG@30: t-statistic = 2.6132, p-value = 9.6552e-03
# P@10: t-statistic = 3.6739, p-value = 3.0705e-04


# Paired t-test Results:
# MRR: t-statistic = 10.4245, p-value = 1.3979e-20
# nDCG@30: t-statistic = 13.1206, p-value = 9.5977e-29
# P@10: t-statistic = 11.1749, p-value = 8.0973e-23


# d3
# Paired t-test Results:
# MRR: t-statistic = 10.9558, p-value = 3.6769e-22
# nDCG@30: t-statistic = 13.6501, p-value = 2.2568e-30
# P@10: t-statistic = 12.9061, p-value = 4.3718e-28


# d4
# Paired t-test Results:
# MRR: t-statistic = 11.6745, p-value = 2.5138e-24
# nDCG@30: t-statistic = 14.6297, p-value = 2.1803e-33
# P@10: t-statistic = 14.5756, p-value = 3.1980e-33
# Out:
# Shapiro-Wilk test for MRR differences: p-value = 0.0000
# Shapiro-Wilk test for nDCG@28 differences: p-value = 0.0000
# Shapiro-Wilk test for P@28 differences: p-value = 0.0000
# Shapiro-Wilk test for P@14 differences: p-value = 0.0001
# Shapiro-Wilk test for P@7 differences: p-value = 0.0000
# Text(0.5, 1.0, 'Q-Q Plot for P@7 Differences')

# %%
# Perform Wilcoxon signed-rank test for each metric
wilcoxon_mrr = stats.wilcoxon(differences_mrr)
wilcoxon_ndcg = stats.wilcoxon(differences_ndcg)
wilcoxon_p_at_k = stats.wilcoxon(differences_p_at_k)

print(f"Wilcoxon test for MRR differences: p-value = {wilcoxon_mrr.pvalue}")
print(f"Wilcoxon test for nDCG differences: p-value = {wilcoxon_ndcg.pvalue}")
print(f"Wilcoxon test for P@10 differences: p-value = {wilcoxon_p_at_k.pvalue}")





# d = 1
# Wilcoxon test for MRR differences: p-value = 0.25776114270546147
# Wilcoxon test for nDCG differences: p-value = 0.009598717670005258
# Wilcoxon test for P@10 differences: p-value = 5.519590807408112e-05


#d = 2
# Wilcoxon test for MRR differences: p-value = 2.3008233907792485e-20
# Wilcoxon test for nDCG differences: p-value = 7.517623405519623e-25
# Wilcoxon test for P@10 differences: p-value = 7.057605378057151e-20

# d = 3
# Wilcoxon test for MRR differences: p-value = 1.9948464223596646e-20
# Wilcoxon test for nDCG differences: p-value = 2.1420120757006535e-23
# Wilcoxon test for P@10 differences: p-value = 9.392735037703501e-24

# d = 4
# Wilcoxon test for MRR differences: p-value = 2.522620607031843e-21
# Wilcoxon test for nDCG differences: p-value = 1.8544844276013673e-24
# Wilcoxon test for P@10 differences: p-value = 1.9503554770175597e-23

# d = 5
# Wilcoxon test for MRR differences: p-value = 1.3553238960239724e-21
# Wilcoxon test for nDCG differences: p-value = 2.2546454406827187e-24
# Wilcoxon test for P@10 differences: p-value = 1.758440646133195e-27
# Out:
# Wilcoxon test for MRR differences: p-value = 7.967272959796052e-20
# Wilcoxon test for nDCG differences: p-value = 1.0986662154608753e-23
# Wilcoxon test for P@10 differences: p-value = 1.758440646133195e-27

# %%
# !pip install statsmodels
# Out:
# Collecting statsmodels
#   Using cached statsmodels-0.14.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in /opt/anaconda3/envs/ml/lib/python3.11/site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /opt/anaconda3/envs/ml/lib/python3.11/site-packages (from statsmodels) (1.13.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /opt/anaconda3/envs/ml/lib/python3.11/site-packages (from statsmodels) (2.2.2)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Using cached patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: packaging>=21.3 in /opt/anaconda3/envs/ml/lib/python3.11/site-packages (from statsmodels) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/ml/lib/python3.11/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/ml/lib/python3.11/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/ml/lib/python3.11/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2023.3)
# Requirement already satisfied: six in /opt/anaconda3/envs/ml/lib/python3.11/site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# Using cached statsmodels-0.14.4-cp311-cp311-macosx_11_0_arm64.whl (9.9 MB)
# Using cached patsy-0.5.6-py2.py3-none-any.whl (233 kB)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-0.5.6 statsmodels-0.14.4

# %%
from statsmodels.stats.descriptivestats import sign_test

# Perform Sign test for each metric
sign_test_mrr = sign_test(differences_mrr, mu0=0)
sign_test_ndcg = sign_test(differences_ndcg, mu0=0)
sign_test_p_at_28 = sign_test(differences_p_at_28, mu0=0)
sign_test_p_at_14 = sign_test(differences_p_at_14, mu0=0)
sign_test_p_at_7 = sign_test(differences_p_at_7, mu0=0)

# Print the results
print(f"Sign test for MRR differences: Test Statistic = {sign_test_mrr[0]:.4f}, p-value = {sign_test_mrr[1]:.4e}")
print(f"Sign test for nDCG@28 differences: Test Statistic = {sign_test_ndcg[0]:.4f}, p-value = {sign_test_ndcg[1]:.4e}")
print(f"Sign test for P@28 differences: Test Statistic = {sign_test_p_at_28[0]:.4f}, p-value = {sign_test_p_at_28[1]:.4e}")
print(f"Sign test for P@14 differences: Test Statistic = {sign_test_p_at_14[0]:.4f}, p-value = {sign_test_p_at_14[1]:.4e}")
print(f"Sign test for P@7 differences: Test Statistic = {sign_test_p_at_7[0]:.4f}, p-value = {sign_test_p_at_7[1]:.4e}")


# d = 1
# Sign test for MRR differences: Test Statistic = 9.0000, p-value = 1.5347e-02
# Sign test for nDCG@28 differences: Test Statistic = 14.5000, p-value = 1.2632e-03
# Sign test for P@28 differences: Test Statistic = 6.0000, p-value = 4.2774e-02
# Sign test for P@14 differences: Test Statistic = 10.0000, p-value = 8.2140e-04
# Sign test for P@7 differences: Test Statistic = 10.5000, p-value = 1.9220e-04

# d = 2
# Sign test for MRR differences: Test Statistic = 61.5000, p-value = 1.8644e-30
# Sign test for nDCG@28 differences: Test Statistic = 67.0000, p-value = 4.5017e-26
# Sign test for P@28 differences: Test Statistic = 62.0000, p-value = 8.4625e-27
# Sign test for P@14 differences: Test Statistic = 67.0000, p-value = 1.5748e-33
# Sign test for P@7 differences: Test Statistic = 49.5000, p-value = 7.9529e-24

# d = 3
# Sign test for MRR differences: Test Statistic = 61.0000, p-value = 3.5397e-30
# Sign test for nDCG@28 differences: Test Statistic = 69.0000, p-value = 4.6941e-29
# Sign test for P@28 differences: Test Statistic = 61.5000, p-value = 1.5378e-26
# Sign test for P@14 differences: Test Statistic = 64.0000, p-value = 3.5814e-31
# Sign test for P@7 differences: Test Statistic = 50.0000, p-value = 4.8957e-27

# d = 4
# Sign test for MRR differences: Test Statistic = 66.0000, p-value = 6.7033e-30
# Sign test for nDCG@28 differences: Test Statistic = 63.0000, p-value = 7.4011e-23
# Sign test for P@28 differences: Test Statistic = 73.5000, p-value = 6.3477e-34
# Sign test for P@14 differences: Test Statistic = 76.0000, p-value = 7.4721e-38
# Sign test for P@7 differences: Test Statistic = 67.5000, p-value = 1.8594e-32

# d = 5
# Sign test for MRR differences: Test Statistic = 65.0000, p-value = 1.7629e-30
# Sign test for nDCG@28 differences: Test Statistic = 60.5000, p-value = 1.0722e-21
# Sign test for P@28 differences: Test Statistic = 69.0000, p-value = 5.6974e-30
# Sign test for P@14 differences: Test Statistic = 74.0000, p-value = 4.7942e-36
# Sign test for P@7 differences: Test Statistic = 72.0000, p-value = 7.6929e-39

# d = 6
# Sign test for MRR differences: Test Statistic = 68.5000, p-value = 8.5284e-32
# Sign test for nDCG@28 differences: Test Statistic = 63.0000, p-value = 7.4011e-23
# Sign test for P@28 differences: Test Statistic = 72.5000, p-value = 2.1965e-33
# Sign test for P@14 differences: Test Statistic = 78.0000, p-value = 1.0026e-39
# Sign test for P@7 differences: Test Statistic = 76.0000, p-value = 3.6917e-41
# Out:
# Sign test for MRR differences: Test Statistic = 68.5000, p-value = 8.5284e-32
# Sign test for nDCG@28 differences: Test Statistic = 63.0000, p-value = 7.4011e-23
# Sign test for P@28 differences: Test Statistic = 72.5000, p-value = 2.1965e-33
# Sign test for P@14 differences: Test Statistic = 78.0000, p-value = 1.0026e-39
# Sign test for P@7 differences: Test Statistic = 76.0000, p-value = 3.6917e-41
